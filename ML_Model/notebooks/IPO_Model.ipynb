# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
import tensorflow as tf
import psycopg2

# %%
conn = psycopg2.connect("dbname=ipo-database user=postgres password=0nlineSQL")

# %%
master_df = pd.read_sql_query("SELECT * from master_data;", conn)
master_df.head()
# Out:
#    symbol  trade_date                         issuer  \
# 0   BSN.U  2020-09-11         Broadstone Acquisition
# 1  LEAP.U  2020-09-11                    Ribbit LEAP
# 2  SNPR.U  2020-09-11  Tortoise Acquisition Corp. II
# 3   TWCTU  2020-09-11           TWC Tech Holdings II
# 4   NSH.U  2020-09-10              NavSight Holdings
#
#                lead_jointlead_managers offer_price opening_price  \
# 0                            Citigroup      $10.00         $9.84
# 1                             JPMorgan      $10.00        $11.20
# 2              Barclays/ Goldman Sachs      $10.00        $10.35
# 3  Citigroup/ Deutsche Bank Securities      $10.00        $10.08
# 4                        Credit Suisse      $10.00        $10.00
#
#   firstday_close  firstday_percent_pxchng dollar_change_opening  \
# 0          $9.60                    -0.04                -$0.16
# 1         $11.55                     0.16                 $1.20
# 2         $10.51                     0.05                 $0.35
# 3         $10.07                     0.01                 $0.08
# 4         $10.00                     0.00                 $0.00
#
#   dollar_change_close  ...  div_payout div_payout_commonstock  \
# 0              -$0.40  ...         NaN                    NaN
# 1               $1.55  ...         NaN                    NaN
# 2               $0.51  ...         NaN                    NaN
# 3               $0.07  ...         NaN                    NaN
# 4               $0.00  ...         NaN                    NaN
#
#   div_payout_preferredstock proceeds_fromissuance_commonstock  \
# 0                       NaN                               NaN
# 1                       NaN                               NaN
# 2                       NaN                               NaN
# 3                       NaN                               NaN
# 4                       NaN                               NaN
#
#   proceeds_fromissuance_longterm_debtcapital_secnet  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   proceeds_fromissuance_preferredstock proceeds_fromrepurchase_equity  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
#
#   proceeds_fromsale_treasurystock changein_cash_cashequivalents  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
#
#   changein_exchangerate
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 113 columns]

# %%
list(master_df)
# Out:
# ['symbol',
#  'trade_date',
#  'issuer',
#  'lead_jointlead_managers',
#  'offer_price',
#  'opening_price',
#  'firstday_close',
#  'firstday_percent_pxchng',
#  'dollar_change_opening',
#  'dollar_change_close',
#  'star_ratings',
#  'performed',
#  'asset_type',
#  'company_name',
#  'exchange',
#  'currency',
#  'country',
#  'sector',
#  'industry',
#  'address',
#  'three_mth_date',
#  'three_mth_ipo',
#  'price_change',
#  'three_mth_return',
#  'price_gain_loss',
#  'fiscaldate_end',
#  'reported_currency',
#  'gross_profit',
#  'total_revenue',
#  'costof_revenue',
#  'costof_goodservices_sold',
#  'operating_income',
#  'selling_gen_admin',
#  'research_dev',
#  'operating_expenses',
#  'investment_income_net',
#  'net_interest_income',
#  'interest_income',
#  'interest_expense',
#  'noninterest_income',
#  'othernon_operatingincome',
#  'depreciation',
#  'dpr_and_amort',
#  'income_beforetax',
#  'incometax_expense',
#  'interest_debt_expense',
#  'netincome_cont_operations',
#  'comprehensive_income_netoftax',
#  'ebit',
#  'ebitda',
#  'netincome',
#  'total_assets',
#  'total_current_assets',
#  'cash_cashequivalent_carrvalue',
#  'cash_shortterm_investments',
#  'inventory',
#  'currentnet_receivables',
#  'total_noncurrent_assets',
#  'propertyplant_equip',
#  'acc_dpr_amort_ppe',
#  'intangible_assets',
#  'intangible_assets_exclgoodwill',
#  'goodwill',
#  'investments',
#  'longterm_investments',
#  'shortterm_investments',
#  'other_current_assets',
#  'other_noncurrrent_assets',
#  'total_liabilities',
#  'total_current_liabilities',
#  'current_acct_payable',
#  'deferred_revenue',
#  'current_debt',
#  'shortterm_debt',
#  'total_noncurrent_liabilities',
#  'capital_lease_obligations',
#  'longterm_debt',
#  'current_longterm_debt',
#  'longterm_debt_noncurrent',
#  'short_longterm_debt_total',
#  'other_current_liabilities',
#  'other_noncurrent_liabilities',
#  'total_shareholder_equity',
#  'treasury_stock',
#  'retained_earnings',
#  'common_stock',
#  'common_stockshares_outstanding',
#  'operating_cashflow',
#  'payments_foroperating_activities',
#  'proceeds_fromoperating_activities',
#  'changein_operating_liabilities',
#  'changein_operating_assets',
#  'dpr_depletion_amort',
#  'capital_expenditures',
#  'changein_receivables',
#  'changein_inventory',
#  'profit_loss',
#  'cashflow_frominvestment',
#  'cashflow_fromfinancing',
#  'proceeds_fromrepayment_shortterm_debt',
#  'payments_forrepurchase_commonstock',
#  'payments_forrepurchase_equity',
#  'payments_forrepurchase_preferredstock',
#  'div_payout',
#  'div_payout_commonstock',
#  'div_payout_preferredstock',
#  'proceeds_fromissuance_commonstock',
#  'proceeds_fromissuance_longterm_debtcapital_secnet',
#  'proceeds_fromissuance_preferredstock',
#  'proceeds_fromrepurchase_equity',
#  'proceeds_fromsale_treasurystock',
#  'changein_cash_cashequivalents',
#  'changein_exchangerate']

# %% [markdown]
# # Calculated Columns

# %%
# Net profit margin
master_df["net_profit_margin"] = master_df["netincome"]/master_df["total_revenue"]
master_df["net_profit_margin"]
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 3465   NaN
# 3466   NaN
# 3467   NaN
# 3468   NaN
# 3469   NaN
# Name: net_profit_margin, Length: 3470, dtype: float64

# %%
# Calculate Gross Profit Margin = gross_profit/total_revenue
master_df["gross_profit_margin"] = master_df["gross_profit"]/master_df["total_revenue"]
master_df["gross_profit_margin"]
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 3465   NaN
# 3466   NaN
# 3467   NaN
# 3468   NaN
# 3469   NaN
# Name: gross_profit_margin, Length: 3470, dtype: float64

# %% [markdown]
# ### Calculate Debt Asset Ratio:
#
# The formula for the debt to asset ratio is as follows: Debt/Asset = (Short-term Debt + Long-term Debt) / Total Assets. Where: Total Assets may include all current and non-current assets on the company's balance sheet, or may only include certain assets such as Property, Plant & Equipment (PP&E)

# %%
# Debt to Asset Ratio
master_df["debt_asset_ratio"] = master_df["short_longterm_debt_total"]/master_df["total_assets"]
master_df
# Out:
# C:\Users\death\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      symbol  trade_date                           issuer  \
# 15     AUVI  2020-08-31                       Applied UV
# 16     HCDI  2020-08-28        Harbor Custom Development
# 19     XPEV  2020-08-27                            XPeng
# 39     BEKE  2020-08-13                      KE Holdings
# 46     IBEX  2020-08-07                        IBEX Ltd.
# ...     ...         ...                              ...
# 2680   PCAP  2005-07-28          Patriot Capital Funding
# 2722   EVVV  2005-06-15                              ev3
# 2907   SRVY  2004-07-15                Greenfield Online
# 2932   LDIS  2004-06-15                Leadis Technology
# 3020    CVP  2003-12-04  Volume Service America Holdings
#
#                                 lead_jointlead_managers offer_price  \
# 15                      Network 1 Financial Securities,       $5.00
# 16    ThinkEquity (a division of Fordham Financial M...       $6.00
# 19          Credit Suisse/ J.P. Morgan/ BofA Securities      $15.00
# 39     Goldman Sachs/ Morgan Stanley/ China Renaissance      $20.00
# 46                Citigroup/ RBC Capital Markets/ Baird      $19.00
# ...                                                 ...         ...
# 2680                                         AG Edwards      $14.00
# 2722                      Piper Jaffray/Banc of America      $14.00
# 2907                                    Lehman Brothers      $13.00
# 2932                        Goldman Sachs/Merrill Lynch      $14.00
# 3020                 CIBC Worldwide/UBS Investment Bank      $15.00
#
#      opening_price firstday_close  firstday_percent_pxchng  \
# 15           $5.75         $11.60                     1.32
# 16           $5.50          $7.50                     0.25
# 19          $23.10         $21.22                     0.41
# 39          $35.06         $37.44                     0.87
# 46          $18.00         $15.40                    -0.19
# ...            ...            ...                      ...
# 2680        $14.75         $14.05                     0.00
# 2722        $13.50         $14.15                     0.01
# 2907        $16.00         $18.70                     0.44
# 2932        $14.27         $13.10                    -0.06
# 3020        $15.10         $15.26                     0.02
#
#      dollar_change_opening dollar_change_close  ...  \
# 15                   $0.75               $6.60  ...
# 16                  -$0.50               $1.50  ...
# 19                   $8.10               $6.22  ...
# 39                  $15.06              $17.44  ...
# 46                  -$1.00              -$3.60  ...
# ...                    ...                 ...  ...
# 2680                 $0.75               $0.05  ...
# 2722                -$0.50               $0.15  ...
# 2907                 $3.00               $5.70  ...
# 2932                 $0.27              -$0.90  ...
# 3020                 $0.10               $0.26  ...
#
#       proceeds_fromissuance_commonstock  \
# 15                                  0.0
# 16                                  0.0
# 19                                  0.0
# 39                                  0.0
# 46                                  0.0
# ...                                 ...
# 2680                                0.0
# 2722                                0.0
# 2907                                0.0
# 2932                                0.0
# 3020                                0.0
#
#      proceeds_fromissuance_longterm_debtcapital_secnet  \
# 15                                                 0.0
# 16                                                 0.0
# 19                                                 0.0
# 39                                                 0.0
# 46                                                 0.0
# ...                                                ...
# 2680                                               0.0
# 2722                                               0.0
# 2907                                               0.0
# 2932                                               0.0
# 3020                                               0.0
#
#      proceeds_fromissuance_preferredstock proceeds_fromrepurchase_equity  \
# 15                                    0.0                            0.0
# 16                                    0.0                            0.0
# 19                                    0.0                            0.0
# 39                                    0.0                            0.0
# 46                                    0.0                            0.0
# ...                                   ...                            ...
# 2680                                  0.0                            0.0
# 2722                                  0.0                            0.0
# 2907                                  0.0                            0.0
# 2932                                  0.0                            0.0
# 3020                                  0.0                            0.0
#
#      proceeds_fromsale_treasurystock changein_cash_cashequivalents  \
# 15                               0.0                           0.0
# 16                               0.0                           0.0
# 19                               0.0                           0.0
# 39                               0.0                           0.0
# 46                               0.0                           0.0
# ...                              ...                           ...
# 2680                             0.0                           0.0
# 2722                             0.0                           0.0
# 2907                             0.0                           0.0
# 2932                             0.0                           0.0
# 3020                             0.0                           0.0
#
#      changein_exchangerate gross_profit_margin net_profit_margin  \
# 15                     0.0            0.050094         -0.573314
# 16                     0.0            0.079754         -0.055992
# 19                     0.0            0.045998         -0.577232
# 39                     0.0            0.213307          0.138040
# 46                     0.0            0.315930         -0.037718
# ...                    ...                 ...               ...
# 2680                   0.0            0.000000          0.108949
# 2722                   0.0            0.000000          0.000000
# 2907                   0.0            0.000000          0.168834
# 2932                   0.0            0.000000          0.150321
# 3020                   0.0            0.000000          0.000000
#
#      debt_asset_ratio
# 15           0.053702
# 16           0.658664
# 19           0.000000
# 39           0.000000
# 46           0.160104
# ...               ...
# 2680         0.000000
# 2722         0.000000
# 2907         0.000000
# 2932         0.000000
# 3020         0.000000
#
# [517 rows x 116 columns]

# %% [markdown]
# ### Drop rows with N/As

# %%
master_df = master_df.dropna(subset=["gross_profit_margin"])
master_df
# Out:
#      symbol  trade_date                           issuer  \
# 15     AUVI  2020-08-31                       Applied UV
# 16     HCDI  2020-08-28        Harbor Custom Development
# 19     XPEV  2020-08-27                            XPeng
# 39     BEKE  2020-08-13                      KE Holdings
# 46     IBEX  2020-08-07                        IBEX Ltd.
# ...     ...         ...                              ...
# 2722   EVVV  2005-06-15                              ev3
# 2823    ATB  2004-11-04           Arlington Tankers Ltd.
# 2907   SRVY  2004-07-15                Greenfield Online
# 2932   LDIS  2004-06-15                Leadis Technology
# 3020    CVP  2003-12-04  Volume Service America Holdings
#
#                                 lead_jointlead_managers offer_price  \
# 15                      Network 1 Financial Securities,       $5.00
# 16    ThinkEquity (a division of Fordham Financial M...       $6.00
# 19          Credit Suisse/ J.P. Morgan/ BofA Securities      $15.00
# 39     Goldman Sachs/ Morgan Stanley/ China Renaissance      $20.00
# 46                Citigroup/ RBC Capital Markets/ Baird      $19.00
# ...                                                 ...         ...
# 2722                      Piper Jaffray/Banc of America      $14.00
# 2823                      UBS Investment Bank/Jefferies      $20.00
# 2907                                    Lehman Brothers      $13.00
# 2932                        Goldman Sachs/Merrill Lynch      $14.00
# 3020                 CIBC Worldwide/UBS Investment Bank      $15.00
#
#      opening_price firstday_close  firstday_percent_pxchng  \
# 15           $5.75         $11.60                     1.32
# 16           $5.50          $7.50                     0.25
# 19          $23.10         $21.22                     0.41
# 39          $35.06         $37.44                     0.87
# 46          $18.00         $15.40                    -0.19
# ...            ...            ...                      ...
# 2722        $13.50         $14.15                     0.01
# 2823        $22.30         $22.04                     0.10
# 2907        $16.00         $18.70                     0.44
# 2932        $14.27         $13.10                    -0.06
# 3020        $15.10         $15.26                     0.02
#
#      dollar_change_opening dollar_change_close  ...  \
# 15                   $0.75               $6.60  ...
# 16                  -$0.50               $1.50  ...
# 19                   $8.10               $6.22  ...
# 39                  $15.06              $17.44  ...
# 46                  -$1.00              -$3.60  ...
# ...                    ...                 ...  ...
# 2722                -$0.50               $0.15  ...
# 2823                 $2.30               $2.04  ...
# 2907                 $3.00               $5.70  ...
# 2932                 $0.27              -$0.90  ...
# 3020                 $0.10               $0.26  ...
#
#       proceeds_fromissuance_commonstock  \
# 15                                  0.0
# 16                                  0.0
# 19                                  0.0
# 39                                  0.0
# 46                                  0.0
# ...                                 ...
# 2722                                0.0
# 2823                                0.0
# 2907                                0.0
# 2932                                0.0
# 3020                                0.0
#
#      proceeds_fromissuance_longterm_debtcapital_secnet  \
# 15                                                 0.0
# 16                                                 0.0
# 19                                                 0.0
# 39                                                 0.0
# 46                                                 0.0
# ...                                                ...
# 2722                                               0.0
# 2823                                               0.0
# 2907                                               0.0
# 2932                                               0.0
# 3020                                               0.0
#
#      proceeds_fromissuance_preferredstock proceeds_fromrepurchase_equity  \
# 15                                    0.0                            0.0
# 16                                    0.0                            0.0
# 19                                    0.0                            0.0
# 39                                    0.0                            0.0
# 46                                    0.0                            0.0
# ...                                   ...                            ...
# 2722                                  0.0                            0.0
# 2823                                  0.0                            0.0
# 2907                                  0.0                            0.0
# 2932                                  0.0                            0.0
# 3020                                  0.0                            0.0
#
#      proceeds_fromsale_treasurystock changein_cash_cashequivalents  \
# 15                               0.0                           0.0
# 16                               0.0                           0.0
# 19                               0.0                           0.0
# 39                               0.0                           0.0
# 46                               0.0                           0.0
# ...                              ...                           ...
# 2722                             0.0                           0.0
# 2823                             0.0                           0.0
# 2907                             0.0                           0.0
# 2932                             0.0                           0.0
# 3020                             0.0                           0.0
#
#      changein_exchangerate gross_profit_margin net_profit_margin  \
# 15                     0.0            0.050094         -0.573314
# 16                     0.0            0.079754         -0.055992
# 19                     0.0            0.045998         -0.577232
# 39                     0.0            0.213307          0.138040
# 46                     0.0            0.315930         -0.037718
# ...                    ...                 ...               ...
# 2722                   0.0            0.000000          0.000000
# 2823                   0.0            0.000000          0.383139
# 2907                   0.0            0.000000          0.168834
# 2932                   0.0            0.000000          0.150321
# 3020                   0.0            0.000000          0.000000
#
#      debt_asset_ratio
# 15           0.053702
# 16           0.658664
# 19           0.000000
# 39           0.000000
# 46           0.160104
# ...               ...
# 2722         0.000000
# 2823              NaN
# 2907         0.000000
# 2932         0.000000
# 3020         0.000000
#
# [553 rows x 116 columns]

# %%
master_df = master_df.dropna(subset=["debt_asset_ratio"])
master_df
# Out:
#      symbol  trade_date                           issuer  \
# 15     AUVI  2020-08-31                       Applied UV
# 16     HCDI  2020-08-28        Harbor Custom Development
# 19     XPEV  2020-08-27                            XPeng
# 39     BEKE  2020-08-13                      KE Holdings
# 46     IBEX  2020-08-07                        IBEX Ltd.
# ...     ...         ...                              ...
# 2680   PCAP  2005-07-28          Patriot Capital Funding
# 2722   EVVV  2005-06-15                              ev3
# 2907   SRVY  2004-07-15                Greenfield Online
# 2932   LDIS  2004-06-15                Leadis Technology
# 3020    CVP  2003-12-04  Volume Service America Holdings
#
#                                 lead_jointlead_managers offer_price  \
# 15                      Network 1 Financial Securities,       $5.00
# 16    ThinkEquity (a division of Fordham Financial M...       $6.00
# 19          Credit Suisse/ J.P. Morgan/ BofA Securities      $15.00
# 39     Goldman Sachs/ Morgan Stanley/ China Renaissance      $20.00
# 46                Citigroup/ RBC Capital Markets/ Baird      $19.00
# ...                                                 ...         ...
# 2680                                         AG Edwards      $14.00
# 2722                      Piper Jaffray/Banc of America      $14.00
# 2907                                    Lehman Brothers      $13.00
# 2932                        Goldman Sachs/Merrill Lynch      $14.00
# 3020                 CIBC Worldwide/UBS Investment Bank      $15.00
#
#      opening_price firstday_close  firstday_percent_pxchng  \
# 15           $5.75         $11.60                     1.32
# 16           $5.50          $7.50                     0.25
# 19          $23.10         $21.22                     0.41
# 39          $35.06         $37.44                     0.87
# 46          $18.00         $15.40                    -0.19
# ...            ...            ...                      ...
# 2680        $14.75         $14.05                     0.00
# 2722        $13.50         $14.15                     0.01
# 2907        $16.00         $18.70                     0.44
# 2932        $14.27         $13.10                    -0.06
# 3020        $15.10         $15.26                     0.02
#
#      dollar_change_opening dollar_change_close  ...  \
# 15                   $0.75               $6.60  ...
# 16                  -$0.50               $1.50  ...
# 19                   $8.10               $6.22  ...
# 39                  $15.06              $17.44  ...
# 46                  -$1.00              -$3.60  ...
# ...                    ...                 ...  ...
# 2680                 $0.75               $0.05  ...
# 2722                -$0.50               $0.15  ...
# 2907                 $3.00               $5.70  ...
# 2932                 $0.27              -$0.90  ...
# 3020                 $0.10               $0.26  ...
#
#       proceeds_fromissuance_commonstock  \
# 15                                  0.0
# 16                                  0.0
# 19                                  0.0
# 39                                  0.0
# 46                                  0.0
# ...                                 ...
# 2680                                0.0
# 2722                                0.0
# 2907                                0.0
# 2932                                0.0
# 3020                                0.0
#
#      proceeds_fromissuance_longterm_debtcapital_secnet  \
# 15                                                 0.0
# 16                                                 0.0
# 19                                                 0.0
# 39                                                 0.0
# 46                                                 0.0
# ...                                                ...
# 2680                                               0.0
# 2722                                               0.0
# 2907                                               0.0
# 2932                                               0.0
# 3020                                               0.0
#
#      proceeds_fromissuance_preferredstock proceeds_fromrepurchase_equity  \
# 15                                    0.0                            0.0
# 16                                    0.0                            0.0
# 19                                    0.0                            0.0
# 39                                    0.0                            0.0
# 46                                    0.0                            0.0
# ...                                   ...                            ...
# 2680                                  0.0                            0.0
# 2722                                  0.0                            0.0
# 2907                                  0.0                            0.0
# 2932                                  0.0                            0.0
# 3020                                  0.0                            0.0
#
#      proceeds_fromsale_treasurystock changein_cash_cashequivalents  \
# 15                               0.0                           0.0
# 16                               0.0                           0.0
# 19                               0.0                           0.0
# 39                               0.0                           0.0
# 46                               0.0                           0.0
# ...                              ...                           ...
# 2680                             0.0                           0.0
# 2722                             0.0                           0.0
# 2907                             0.0                           0.0
# 2932                             0.0                           0.0
# 3020                             0.0                           0.0
#
#      changein_exchangerate gross_profit_margin net_profit_margin  \
# 15                     0.0            0.050094         -0.573314
# 16                     0.0            0.079754         -0.055992
# 19                     0.0            0.045998         -0.577232
# 39                     0.0            0.213307          0.138040
# 46                     0.0            0.315930         -0.037718
# ...                    ...                 ...               ...
# 2680                   0.0            0.000000          0.108949
# 2722                   0.0            0.000000          0.000000
# 2907                   0.0            0.000000          0.168834
# 2932                   0.0            0.000000          0.150321
# 3020                   0.0            0.000000          0.000000
#
#      debt_asset_ratio
# 15           0.053702
# 16           0.658664
# 19           0.000000
# 39           0.000000
# 46           0.160104
# ...               ...
# 2680         0.000000
# 2722         0.000000
# 2907         0.000000
# 2932         0.000000
# 3020         0.000000
#
# [517 rows x 116 columns]

# %%
master_df.replace([np.inf, -np.inf], np.nan)
# Out:
#      symbol  trade_date                           issuer  \
# 15     AUVI  2020-08-31                       Applied UV
# 16     HCDI  2020-08-28        Harbor Custom Development
# 19     XPEV  2020-08-27                            XPeng
# 39     BEKE  2020-08-13                      KE Holdings
# 46     IBEX  2020-08-07                        IBEX Ltd.
# ...     ...         ...                              ...
# 2680   PCAP  2005-07-28          Patriot Capital Funding
# 2722   EVVV  2005-06-15                              ev3
# 2907   SRVY  2004-07-15                Greenfield Online
# 2932   LDIS  2004-06-15                Leadis Technology
# 3020    CVP  2003-12-04  Volume Service America Holdings
#
#                                 lead_jointlead_managers offer_price  \
# 15                      Network 1 Financial Securities,       $5.00
# 16    ThinkEquity (a division of Fordham Financial M...       $6.00
# 19          Credit Suisse/ J.P. Morgan/ BofA Securities      $15.00
# 39     Goldman Sachs/ Morgan Stanley/ China Renaissance      $20.00
# 46                Citigroup/ RBC Capital Markets/ Baird      $19.00
# ...                                                 ...         ...
# 2680                                         AG Edwards      $14.00
# 2722                      Piper Jaffray/Banc of America      $14.00
# 2907                                    Lehman Brothers      $13.00
# 2932                        Goldman Sachs/Merrill Lynch      $14.00
# 3020                 CIBC Worldwide/UBS Investment Bank      $15.00
#
#      opening_price firstday_close  firstday_percent_pxchng  \
# 15           $5.75         $11.60                     1.32
# 16           $5.50          $7.50                     0.25
# 19          $23.10         $21.22                     0.41
# 39          $35.06         $37.44                     0.87
# 46          $18.00         $15.40                    -0.19
# ...            ...            ...                      ...
# 2680        $14.75         $14.05                     0.00
# 2722        $13.50         $14.15                     0.01
# 2907        $16.00         $18.70                     0.44
# 2932        $14.27         $13.10                    -0.06
# 3020        $15.10         $15.26                     0.02
#
#      dollar_change_opening dollar_change_close  ...  \
# 15                   $0.75               $6.60  ...
# 16                  -$0.50               $1.50  ...
# 19                   $8.10               $6.22  ...
# 39                  $15.06              $17.44  ...
# 46                  -$1.00              -$3.60  ...
# ...                    ...                 ...  ...
# 2680                 $0.75               $0.05  ...
# 2722                -$0.50               $0.15  ...
# 2907                 $3.00               $5.70  ...
# 2932                 $0.27              -$0.90  ...
# 3020                 $0.10               $0.26  ...
#
#       proceeds_fromissuance_commonstock  \
# 15                                  0.0
# 16                                  0.0
# 19                                  0.0
# 39                                  0.0
# 46                                  0.0
# ...                                 ...
# 2680                                0.0
# 2722                                0.0
# 2907                                0.0
# 2932                                0.0
# 3020                                0.0
#
#      proceeds_fromissuance_longterm_debtcapital_secnet  \
# 15                                                 0.0
# 16                                                 0.0
# 19                                                 0.0
# 39                                                 0.0
# 46                                                 0.0
# ...                                                ...
# 2680                                               0.0
# 2722                                               0.0
# 2907                                               0.0
# 2932                                               0.0
# 3020                                               0.0
#
#      proceeds_fromissuance_preferredstock proceeds_fromrepurchase_equity  \
# 15                                    0.0                            0.0
# 16                                    0.0                            0.0
# 19                                    0.0                            0.0
# 39                                    0.0                            0.0
# 46                                    0.0                            0.0
# ...                                   ...                            ...
# 2680                                  0.0                            0.0
# 2722                                  0.0                            0.0
# 2907                                  0.0                            0.0
# 2932                                  0.0                            0.0
# 3020                                  0.0                            0.0
#
#      proceeds_fromsale_treasurystock changein_cash_cashequivalents  \
# 15                               0.0                           0.0
# 16                               0.0                           0.0
# 19                               0.0                           0.0
# 39                               0.0                           0.0
# 46                               0.0                           0.0
# ...                              ...                           ...
# 2680                             0.0                           0.0
# 2722                             0.0                           0.0
# 2907                             0.0                           0.0
# 2932                             0.0                           0.0
# 3020                             0.0                           0.0
#
#      changein_exchangerate gross_profit_margin net_profit_margin  \
# 15                     0.0            0.050094         -0.573314
# 16                     0.0            0.079754         -0.055992
# 19                     0.0            0.045998         -0.577232
# 39                     0.0            0.213307          0.138040
# 46                     0.0            0.315930         -0.037718
# ...                    ...                 ...               ...
# 2680                   0.0            0.000000          0.108949
# 2722                   0.0            0.000000          0.000000
# 2907                   0.0            0.000000          0.168834
# 2932                   0.0            0.000000          0.150321
# 3020                   0.0            0.000000          0.000000
#
#      debt_asset_ratio
# 15           0.053702
# 16           0.658664
# 19           0.000000
# 39           0.000000
# 46           0.160104
# ...               ...
# 2680         0.000000
# 2722         0.000000
# 2907         0.000000
# 2932         0.000000
# 3020         0.000000
#
# [517 rows x 116 columns]

# %% [markdown]
# # Preprocess

# %%
IPO_df = master_df[["exchange","sector","industry","price_gain_loss","debt_asset_ratio", "gross_profit_margin","net_profit_margin"]]
IPO_df
# Out:
#      exchange             sector                            industry  \
# 15     NASDAQ  Consumer Cyclical  Furnishings, Fixtures & Appliances
# 16     NASDAQ        Real Estate             Real Estate-Development
# 19       NYSE  Consumer Cyclical                  Auto Manufacturers
# 39       NYSE        Real Estate                Real Estate Services
# 46     NASDAQ         Technology                Software-Application
# ...       ...                ...                                 ...
# 2680   NASDAQ              Other                               Other
# 2722   NASDAQ              Other                               Other
# 2907   NASDAQ              Other                               Other
# 2932   NASDAQ              Other                               Other
# 3020     AMEX              Other                               Other
#
#      price_gain_loss  debt_asset_ratio  gross_profit_margin  net_profit_margin
# 15              Loss          0.053702             0.050094          -0.573314
# 16              None          0.658664             0.079754          -0.055992
# 19              Gain          0.000000             0.045998          -0.577232
# 39              Gain          0.000000             0.213307           0.138040
# 46              None          0.160104             0.315930          -0.037718
# ...              ...               ...                  ...                ...
# 2680            Loss          0.000000             0.000000           0.108949
# 2722            Gain          0.000000             0.000000           0.000000
# 2907            Gain          0.000000             0.000000           0.168834
# 2932            Loss          0.000000             0.000000           0.150321
# 3020            Gain          0.000000             0.000000           0.000000
#
# [517 rows x 7 columns]

# %%
IPO_df.nunique()
# Out:
# exchange                 7
# sector                  12
# industry                81
# price_gain_loss          2
# debt_asset_ratio       143
# gross_profit_margin    331
# net_profit_margin      444
# dtype: int64

# %% [markdown]
# # Encoding

# %%
# Binary encode
IPO_df_encoded = pd.get_dummies(IPO_df, columns=["exchange","sector","industry","price_gain_loss"])
IPO_df_encoded.head()
# Out:
#     debt_asset_ratio  gross_profit_margin  net_profit_margin  exchange_AMEX  \
# 15          0.053702             0.050094          -0.573314              0
# 16          0.658664             0.079754          -0.055992              0
# 19          0.000000             0.045998          -0.577232              0
# 39          0.000000             0.213307           0.138040              0
# 46          0.160104             0.315930          -0.037718              0
#
#     exchange_BATS  exchange_NASDAQ  exchange_NYSE  exchange_NYSE MKT  \
# 15              0                1              0                  0
# 16              0                1              0                  0
# 19              0                0              1                  0
# 39              0                0              1                  0
# 46              0                1              0                  0
#
#     exchange_None  exchange_PINK  ...  \
# 15              0              0  ...
# 16              0              0  ...
# 19              0              0  ...
# 39              0              0  ...
# 46              0              0  ...
#
#     industry_Staffing & Employment Services  industry_Telecom Services  \
# 15                                        0                          0
# 16                                        0                          0
# 19                                        0                          0
# 39                                        0                          0
# 46                                        0                          0
#
#     industry_Travel Services  industry_Trucking  \
# 15                         0                  0
# 16                         0                  0
# 19                         0                  0
# 39                         0                  0
# 46                         0                  0
#
#     industry_Utilities-Regulated Gas  industry_Utilities-Regulated Water  \
# 15                                 0                                   0
# 16                                 0                                   0
# 19                                 0                                   0
# 39                                 0                                   0
# 46                                 0                                   0
#
#     industry_Utilities-Renewable  industry_Waste Management  \
# 15                             0                          0
# 16                             0                          0
# 19                             0                          0
# 39                             0                          0
# 46                             0                          0
#
#     price_gain_loss_Gain  price_gain_loss_Loss
# 15                     0                     1
# 16                     0                     0
# 19                     1                     0
# 39                     1                     0
# 46                     0                     0
#
# [5 rows x 105 columns]

# %% [markdown]
# # Target Feature

# %%
y = IPO_df_encoded.price_gain_loss_Gain
X = IPO_df_encoded.drop(columns=["price_gain_loss_Gain","price_gain_loss_Loss"])

# %%
y
# Out:
# 15      0
# 16      0
# 19      1
# 39      1
# 46      0
#        ..
# 2680    0
# 2722    1
# 2907    1
# 2932    0
# 3020    1
# Name: price_gain_loss_Gain, Length: 517, dtype: uint8

# %%
X
# Out:
#       debt_asset_ratio  gross_profit_margin  net_profit_margin  exchange_AMEX  \
# 15            0.053702             0.050094          -0.573314              0
# 16            0.658664             0.079754          -0.055992              0
# 19            0.000000             0.045998          -0.577232              0
# 39            0.000000             0.213307           0.138040              0
# 46            0.160104             0.315930          -0.037718              0
# ...                ...                  ...                ...            ...
# 2680          0.000000             0.000000           0.108949              0
# 2722          0.000000             0.000000           0.000000              0
# 2907          0.000000             0.000000           0.168834              0
# 2932          0.000000             0.000000           0.150321              0
# 3020          0.000000             0.000000           0.000000              1
#
#       exchange_BATS  exchange_NASDAQ  exchange_NYSE  exchange_NYSE MKT  \
# 15                0                1              0                  0
# 16                0                1              0                  0
# 19                0                0              1                  0
# 39                0                0              1                  0
# 46                0                1              0                  0
# ...             ...              ...            ...                ...
# 2680              0                1              0                  0
# 2722              0                1              0                  0
# 2907              0                1              0                  0
# 2932              0                1              0                  0
# 3020              0                0              0                  0
#
#       exchange_None  exchange_PINK  ...  \
# 15                0              0  ...
# 16                0              0  ...
# 19                0              0  ...
# 39                0              0  ...
# 46                0              0  ...
# ...             ...            ...  ...
# 2680              0              0  ...
# 2722              0              0  ...
# 2907              0              0  ...
# 2932              0              0  ...
# 3020              0              0  ...
#
#       industry_Specialty Industrial Machinery  industry_Specialty Retail  \
# 15                                          0                          0
# 16                                          0                          0
# 19                                          0                          0
# 39                                          0                          0
# 46                                          0                          0
# ...                                       ...                        ...
# 2680                                        0                          0
# 2722                                        0                          0
# 2907                                        0                          0
# 2932                                        0                          0
# 3020                                        0                          0
#
#       industry_Staffing & Employment Services  industry_Telecom Services  \
# 15                                          0                          0
# 16                                          0                          0
# 19                                          0                          0
# 39                                          0                          0
# 46                                          0                          0
# ...                                       ...                        ...
# 2680                                        0                          0
# 2722                                        0                          0
# 2907                                        0                          0
# 2932                                        0                          0
# 3020                                        0                          0
#
#       industry_Travel Services  industry_Trucking  \
# 15                           0                  0
# 16                           0                  0
# 19                           0                  0
# 39                           0                  0
# 46                           0                  0
# ...                        ...                ...
# 2680                         0                  0
# 2722                         0                  0
# 2907                         0                  0
# 2932                         0                  0
# 3020                         0                  0
#
#       industry_Utilities-Regulated Gas  industry_Utilities-Regulated Water  \
# 15                                   0                                   0
# 16                                   0                                   0
# 19                                   0                                   0
# 39                                   0                                   0
# 46                                   0                                   0
# ...                                ...                                 ...
# 2680                                 0                                   0
# 2722                                 0                                   0
# 2907                                 0                                   0
# 2932                                 0                                   0
# 3020                                 0                                   0
#
#       industry_Utilities-Renewable  industry_Waste Management
# 15                               0                          0
# 16                               0                          0
# 19                               0                          0
# 39                               0                          0
# 46                               0                          0
# ...                            ...                        ...
# 2680                             0                          0
# 2722                             0                          0
# 2907                             0                          0
# 2932                             0                          0
# 3020                             0                          0
#
# [517 rows x 103 columns]

# %%
import numpy as np

X.describe()
# Out:
#        debt_asset_ratio  gross_profit_margin  net_profit_margin  \
# count        517.000000           517.000000         517.000000
# mean           0.176888                  NaN               -inf
# std            1.229985                  NaN                NaN
# min           -0.004233                 -inf               -inf
# 25%            0.000000             0.000000          -0.265776
# 50%            0.000000             0.313444           0.000000
# 75%            0.016516             0.719412           0.073274
# max           25.932920                  inf          68.089193
#
#        exchange_AMEX  exchange_BATS  exchange_NASDAQ  exchange_NYSE  \
# count     517.000000     517.000000       517.000000     517.000000
# mean        0.001934       0.001934         0.545455       0.442940
# std         0.043980       0.043980         0.498412       0.497215
# min         0.000000       0.000000         0.000000       0.000000
# 25%         0.000000       0.000000         0.000000       0.000000
# 50%         0.000000       0.000000         1.000000       0.000000
# 75%         0.000000       0.000000         1.000000       1.000000
# max         1.000000       1.000000         1.000000       1.000000
#
#        exchange_NYSE MKT  exchange_None  exchange_PINK  ...  \
# count         517.000000     517.000000     517.000000  ...
# mean            0.003868       0.001934       0.001934  ...
# std             0.062137       0.043980       0.043980  ...
# min             0.000000       0.000000       0.000000  ...
# 25%             0.000000       0.000000       0.000000  ...
# 50%             0.000000       0.000000       0.000000  ...
# 75%             0.000000       0.000000       0.000000  ...
# max             1.000000       1.000000       1.000000  ...
#
#        industry_Specialty Industrial Machinery  industry_Specialty Retail  \
# count                               517.000000                 517.000000
# mean                                  0.003868                   0.005803
# std                                   0.062137                   0.076028
# min                                   0.000000                   0.000000
# 25%                                   0.000000                   0.000000
# 50%                                   0.000000                   0.000000
# 75%                                   0.000000                   0.000000
# max                                   1.000000                   1.000000
#
#        industry_Staffing & Employment Services  industry_Telecom Services  \
# count                               517.000000                 517.000000
# mean                                  0.001934                   0.003868
# std                                   0.043980                   0.062137
# min                                   0.000000                   0.000000
# 25%                                   0.000000                   0.000000
# 50%                                   0.000000                   0.000000
# 75%                                   0.000000                   0.000000
# max                                   1.000000                   1.000000
#
#        industry_Travel Services  industry_Trucking  \
# count                517.000000         517.000000
# mean                   0.001934           0.001934
# std                    0.043980           0.043980
# min                    0.000000           0.000000
# 25%                    0.000000           0.000000
# 50%                    0.000000           0.000000
# 75%                    0.000000           0.000000
# max                    1.000000           1.000000
#
#        industry_Utilities-Regulated Gas  industry_Utilities-Regulated Water  \
# count                        517.000000                          517.000000
# mean                           0.001934                            0.001934
# std                            0.043980                            0.043980
# min                            0.000000                            0.000000
# 25%                            0.000000                            0.000000
# 50%                            0.000000                            0.000000
# 75%                            0.000000                            0.000000
# max                            1.000000                            1.000000
#
#        industry_Utilities-Renewable  industry_Waste Management
# count                    517.000000                 517.000000
# mean                       0.001934                   0.005803
# std                        0.043980                   0.076028
# min                        0.000000                   0.000000
# 25%                        0.000000                   0.000000
# 50%                        0.000000                   0.000000
# 75%                        0.000000                   0.000000
# max                        1.000000                   1.000000
#
# [8 rows x 103 columns]

# %% [markdown]
# # Split Training and Testing sets

# %%
# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-17832012e2aa> in <module>
#       6
#       7 # Fit the StandardScaler
# ----> 8 X_scaler = scaler.fit(X_train)
#       9
#      10 # Scale the data
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
#     732     def partial_fit(self, X, y=None, sample_weight=None):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y, sample_weight)
#     766         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     767                                 estimator=self, dtype=FLOAT_DTYPES,
# --> 768                                 force_all_finite='allow-nan', reset=first_call)
#     769         n_features = X.shape[1]
#     770
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     662         if force_all_finite:
#     663             _assert_all_finite(array,
# --> 664                                allow_nan=force_all_finite == 'allow-nan')
#     665
#     666     if ensure_min_samples > 0:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     104                     msg_err.format
#     105                     (type_err,
# --> 106                      msg_dtype if msg_dtype is not None else X.dtype)
#     107             )
#     108     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains infinity or a value too large for dtype('float64').

# %% [markdown]
# # Logistic Regression
# our basic logistic regression parameters, which include:
#
# - The solver parameter is set to 'lbfgs', which is an algorithm for learning and optimization. The particular solver isn't very important in this example, but note that a number of optimizers exist.
# - The max_iter parameter will be set to 200 iterations, which will give the model sufficient opportunity to converge on effective weights

# %%
from sklearn.linear_model import LogisticRegression

# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.554

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Create a random forest classifier.
rf_model = RandomForestClassifier(n_estimators=128, random_state=78)

# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# Evaluate the model
y_pred = rf_model.predict(X_test_scaled)
print(f" Random forest predictive accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Random forest predictive accuracy: 0.570

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

# Create the SVM model
svm = SVC(kernel='linear')

# Train the model
svm.fit(X_train, y_train)

# Evaluate the model
y_pred = svm.predict(X_test_scaled)
print(f" SVM model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  SVM model accuracy: 0.438

# %% [markdown]
# # Deep Learning

# %%
len(X_train_scaled[0])
# Out:
# 85

# %%
# Define the model - deep neural net
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 =  number_input_features*2
hidden_nodes_layer2 = number_input_features

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model 
fit_model = nn.fit(X_train_scaled, y_train, epochs=100) 
# Evaluate the model using the test data 
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 12/12 [==============================] - 2s 3ms/step - loss: 0.6961 - accuracy: 0.5451
# Epoch 2/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6061 - accuracy: 0.6837
# Epoch 3/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5787 - accuracy: 0.6982
# Epoch 4/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5418 - accuracy: 0.7127
# Epoch 5/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5490 - accuracy: 0.7122
# Epoch 6/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5469 - accuracy: 0.7152
# Epoch 7/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5614 - accuracy: 0.6916
# Epoch 8/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5389 - accuracy: 0.7134
# Epoch 9/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5147 - accuracy: 0.7191
# Epoch 10/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5306 - accuracy: 0.7011
# Epoch 11/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5341 - accuracy: 0.6993
# Epoch 12/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5144 - accuracy: 0.7379
# Epoch 13/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5415 - accuracy: 0.7008
# Epoch 14/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5316 - accuracy: 0.7117
# Epoch 15/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5406 - accuracy: 0.6808
# Epoch 16/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5267 - accuracy: 0.7037
# Epoch 17/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5217 - accuracy: 0.7092
# Epoch 18/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5240 - accuracy: 0.7130
# Epoch 19/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5402 - accuracy: 0.7032
# Epoch 20/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5598 - accuracy: 0.6546
# Epoch 21/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5346 - accuracy: 0.6910
# Epoch 22/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5473 - accuracy: 0.7317
# Epoch 23/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5262 - accuracy: 0.7174
# Epoch 24/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5380 - accuracy: 0.7259
# Epoch 25/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5182 - accuracy: 0.7116
# Epoch 26/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5341 - accuracy: 0.6923
# Epoch 27/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5252 - accuracy: 0.7078
# Epoch 28/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5413 - accuracy: 0.6797
# Epoch 29/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5493 - accuracy: 0.6870
# Epoch 30/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4902 - accuracy: 0.7512
# Epoch 31/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5101 - accuracy: 0.7339
# Epoch 32/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5249 - accuracy: 0.7206
# Epoch 33/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5121 - accuracy: 0.7224
# Epoch 34/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4924 - accuracy: 0.7503
# Epoch 35/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5520 - accuracy: 0.6908
# Epoch 36/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5305 - accuracy: 0.7039
# Epoch 37/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5420 - accuracy: 0.6821
# Epoch 38/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5283 - accuracy: 0.7146
# Epoch 39/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5114 - accuracy: 0.7067
# Epoch 40/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5173 - accuracy: 0.7211
# Epoch 41/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5448 - accuracy: 0.6909
# Epoch 42/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5084 - accuracy: 0.7156
# Epoch 43/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5175 - accuracy: 0.7098
# Epoch 44/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5141 - accuracy: 0.7073
# Epoch 45/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5076 - accuracy: 0.7184
# Epoch 46/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5224 - accuracy: 0.7066
# Epoch 47/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5285 - accuracy: 0.7116
# Epoch 48/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5185 - accuracy: 0.7233
# Epoch 49/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5666 - accuracy: 0.6551
# Epoch 50/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5258 - accuracy: 0.7254
# Epoch 51/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5173 - accuracy: 0.7252
# Epoch 52/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5206 - accuracy: 0.7127
# Epoch 53/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5003 - accuracy: 0.7241
# Epoch 54/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5379 - accuracy: 0.6996
# Epoch 55/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5417 - accuracy: 0.6937
# Epoch 56/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5164 - accuracy: 0.7126
# Epoch 57/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5301 - accuracy: 0.7098
# Epoch 58/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5231 - accuracy: 0.7152
# Epoch 59/100
# 12/12 [==============================] - 0s 997us/step - loss: 0.5220 - accuracy: 0.7133
# Epoch 60/100
# 12/12 [==============================] - 0s 997us/step - loss: 0.5378 - accuracy: 0.6983
# Epoch 61/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5337 - accuracy: 0.7190
# Epoch 62/100
# 12/12 [==============================] - 0s 997us/step - loss: 0.5335 - accuracy: 0.7085
# Epoch 63/100
# 12/12 [==============================] - 0s 997us/step - loss: 0.5129 - accuracy: 0.7047
# Epoch 64/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5162 - accuracy: 0.7000
# Epoch 65/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5269 - accuracy: 0.6906
# Epoch 66/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5499 - accuracy: 0.6801
# Epoch 67/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5123 - accuracy: 0.7099
# Epoch 68/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5131 - accuracy: 0.7245
# Epoch 69/100
# 12/12 [==============================] - 0s 907us/step - loss: 0.5288 - accuracy: 0.6856
# Epoch 70/100
# 12/12 [==============================] - 0s 997us/step - loss: 0.5157 - accuracy: 0.7105
# Epoch 71/100
# 12/12 [==============================] - 0s 997us/step - loss: 0.5068 - accuracy: 0.7092
# Epoch 72/100
# 12/12 [==============================] - 0s 997us/step - loss: 0.5609 - accuracy: 0.6680
# Epoch 73/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5305 - accuracy: 0.6991
# Epoch 74/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5112 - accuracy: 0.7365
# Epoch 75/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5422 - accuracy: 0.6817
# Epoch 76/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5153 - accuracy: 0.7055
# Epoch 77/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5205 - accuracy: 0.7143
# Epoch 78/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5279 - accuracy: 0.7033
# Epoch 79/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4970 - accuracy: 0.7490
# Epoch 80/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5148 - accuracy: 0.7183
# Epoch 81/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5223 - accuracy: 0.7132
# Epoch 82/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5137 - accuracy: 0.7197
# Epoch 83/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5178 - accuracy: 0.7166
# Epoch 84/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5540 - accuracy: 0.6823
# Epoch 85/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5420 - accuracy: 0.7109
# Epoch 86/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5022 - accuracy: 0.7094
# Epoch 87/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4981 - accuracy: 0.7408
# Epoch 88/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5139 - accuracy: 0.7067
# Epoch 89/100
# 12/12 [==============================] - 0s 997us/step - loss: 0.5296 - accuracy: 0.6949
# Epoch 90/100
# 12/12 [==============================] - 0s 997us/step - loss: 0.5161 - accuracy: 0.7223
# Epoch 91/100
# 12/12 [==============================] - 0s 997us/step - loss: 0.5048 - accuracy: 0.7303
# Epoch 92/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5303 - accuracy: 0.6945
# Epoch 93/100
# 12/12 [==============================] - 0s 907us/step - loss: 0.5309 - accuracy: 0.6823
# Epoch 94/100
# 12/12 [==============================] - 0s 725us/step - loss: 0.5166 - accuracy: 0.7026
# Epoch 95/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5231 - accuracy: 0.7217
# Epoch 96/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5313 - accuracy: 0.6994
# Epoch 97/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4998 - accuracy: 0.7325
# Epoch 98/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5230 - accuracy: 0.6960
# Epoch 99/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5176 - accuracy: 0.7023
# Epoch 100/100
# 12/12 [==============================] - 0s 997us/step - loss: 0.5059 - accuracy: 0.7186
# 4/4 - 0s - loss: 1.1976 - accuracy: 0.5950
# Loss: 1.1976313591003418, Accuracy: 0.5950413346290588
