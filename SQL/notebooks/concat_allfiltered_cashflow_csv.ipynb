# %% [markdown]
# ## Grabbing all filtered cash_flow CSV's to put into 1 file.

# %%
# Importing dependencies.
from glob import glob
import pandas as pd

# %%
# Creating a list of all the balance_sheet files.
cash_flow_files = sorted(glob('C:\\Users\\Lora B\\Documents\\Development\\FinalProject_IPO\\DataExtraction\\raw_dataset\\filtered_cash_flow\\*filtered_cash_flow.csv'))
cash_flow_files
# Out:
# ['C:\\Users\\Lora B\\Documents\\Development\\FinalProject_IPO\\DataExtraction\\raw_dataset\\filtered_cash_flow\\AAAP_filtered_cash_flow.csv',
#  'C:\\Users\\Lora B\\Documents\\Development\\FinalProject_IPO\\DataExtraction\\raw_dataset\\filtered_cash_flow\\AACC_filtered_cash_flow.csv',
#  'C:\\Users\\Lora B\\Documents\\Development\\FinalProject_IPO\\DataExtraction\\raw_dataset\\filtered_cash_flow\\AAC_filtered_cash_flow.csv',
#  'C:\\Users\\Lora B\\Documents\\Development\\FinalProject_IPO\\DataExtraction\\raw_dataset\\filtered_cash_flow\\AAOI_filtered_cash_flow.csv',
#  'C:\\Users\\Lora B\\Documents\\Development\\FinalProject_IPO\\DataExtraction\\raw_dataset\\filtered_cash_flow\\AAPC_filtered_cash_flow.csv',
#  'C:\\Users\\Lora B\\Documents\\Development\\FinalProject_IPO\\DataExtraction\\raw_dataset\\filtered_cash_flow\\AATI_filtered_cash_flow.csv',
# ...

# %%
# Create a dataframe to house all concatenated files.
df = pd.concat((pd.read_csv(file).assign(filename = file)
          for file in cash_flow_files), ignore_index = True)
df
# Out:
#     SYMBOL fiscalDateEnding reportedCurrency operatingCashflow  \
# 0     AAAP       2015-09-30              USD              None
# 1      AAC       2014-09-30              USD           5796000
# 2    ACAMU       2019-03-31              USD           -168680
# 3     ACIU       2016-09-30              USD         8.474e+06
# 4      ACI       2020-06-20              USD        2091900000
# ..     ...              ...              ...               ...
# 698   ZPIN       2014-06-30              USD          52141000
# 699   ZSPH       2014-06-30              USD              None
# 700    ZTO       2016-09-30              USD         214235000
# 701   ZYME       2017-03-31              USD         -12697000
# 702    RUE       2009-10-31              USD          25511000
#
#     paymentsForOperatingActivities proceedsFromOperatingActivities  \
# 0                             None                            None
# 1                             None                            None
# ...

# %%
# Dropping unwanted columns.
cleaned_df = df.drop(['filename'],axis=1)
cleaned_df
# Out:
#     SYMBOL fiscalDateEnding reportedCurrency operatingCashflow  \
# 0     AAAP       2015-09-30              USD              None
# 1      AAC       2014-09-30              USD           5796000
# 2    ACAMU       2019-03-31              USD           -168680
# 3     ACIU       2016-09-30              USD         8.474e+06
# 4      ACI       2020-06-20              USD        2091900000
# ..     ...              ...              ...               ...
# 698   ZPIN       2014-06-30              USD          52141000
# 699   ZSPH       2014-06-30              USD              None
# 700    ZTO       2016-09-30              USD         214235000
# 701   ZYME       2017-03-31              USD         -12697000
# 702    RUE       2009-10-31              USD          25511000
#
#     paymentsForOperatingActivities proceedsFromOperatingActivities  \
# 0                             None                            None
# 1                             None                            None
# ...

# %%
# Count of missing values of the entire dataframe. If any drop.
cleaned_df.isnull().sum().sum()
# Out:
# 0

# %%
# Replacing the None values with 0.
filtered_cash_flow_df = cleaned_df.replace('None', 0)
filtered_cash_flow_df
# Out:
#     SYMBOL fiscalDateEnding reportedCurrency  operatingCashflow  \
# 0     AAAP       2015-09-30              USD       0.000000e+00
# 1      AAC       2014-09-30              USD       5.796000e+06
# 2    ACAMU       2019-03-31              USD      -1.686800e+05
# 3     ACIU       2016-09-30              USD       8.474000e+06
# 4      ACI       2020-06-20              USD       2.091900e+09
# ..     ...              ...              ...                ...
# 698   ZPIN       2014-06-30              USD       5.214100e+07
# 699   ZSPH       2014-06-30              USD       0.000000e+00
# 700    ZTO       2016-09-30              USD       2.142350e+08
# 701   ZYME       2017-03-31              USD      -1.269700e+07
# 702    RUE       2009-10-31              USD       2.551100e+07
#
#      paymentsForOperatingActivities  proceedsFromOperatingActivities  \
# 0                                 0                                0
# ...

# %%
# Renaming column names.

filtered_cash_flow_df = filtered_cash_flow_df.rename(columns = {
    'SYMBOL': 'symbol', 
    'fiscalDateEnding': 'fiscaldate_end', 
    'reportedCurrency': 'reported_currency',
    'operatingCashflow': 'operating_cashflow',
    'paymentsForOperatingActivities': 'payments_foroperating_activities', 
    'proceedsFromOperatingActivities': 'proceeds_fromoperating_activities', 
    'changeInOperatingLiabilities': 'changein_operating_liabilities',
    'changeInOperatingAssets': 'changein_operating_assets',
    'depreciationDepletionAndAmortization': 'dpr_depletion_amort', 
    'capitalExpenditures': 'capital_expenditures', 
    'changeInReceivables': 'changein_receivables',
    'changeInInventory': 'changein_inventory',
    'profitLoss': 'profit_loss', 
    'cashflowFromInvestment': 'cashflow_frominvestment', 
    'cashflowFromFinancing': 'cashflow_fromfinancing',
    'proceedsFromRepaymentsOfShortTermDebt': 'proceeds_fromrepayment_shortterm_debt',
    'paymentsForRepurchaseOfCommonStock': 'payments_forrepurchase_commonstock', 
    'paymentsForRepurchaseOfEquity': 'payments_forrepurchase_equity', 
    'paymentsForRepurchaseOfPreferredStock': 'payments_forrepurchase_preferredstock',
    'dividendPayout': 'div_payout',
    'dividendPayoutCommonStock': 'div_payout_commonstock', 
    'dividendPayoutPreferredStock': 'div_payout_preferredstock', 
    'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': 'proceeds_fromissuance_longterm_debtcapital_secnet',
    'proceedsFromIssuanceOfPreferredStock': 'proceeds_fromissuance_preferredstock',
    'proceedsFromRepurchaseOfEquity': 'proceeds_fromrepurchase_equity', 
    'proceedsFromSaleOfTreasuryStock': 'proceeds_fromsale_treasurystock',
    'changeInCashAndCashEquivalents': 'changein_cash_cashequivalents',
    'changeInExchangeRate': 'changein_exchangerate',
    'netIncome': 'netincome',
    })
filtered_cash_flow_df
# Out:
#     symbol fiscaldate_end reported_currency  operating_cashflow  \
# 0     AAAP     2015-09-30               USD        0.000000e+00
# 1      AAC     2014-09-30               USD        5.796000e+06
# 2    ACAMU     2019-03-31               USD       -1.686800e+05
# 3     ACIU     2016-09-30               USD        8.474000e+06
# 4      ACI     2020-06-20               USD        2.091900e+09
# ..     ...            ...               ...                 ...
# 698   ZPIN     2014-06-30               USD        5.214100e+07
# 699   ZSPH     2014-06-30               USD        0.000000e+00
# 700    ZTO     2016-09-30               USD        2.142350e+08
# 701   ZYME     2017-03-31               USD       -1.269700e+07
# 702    RUE     2009-10-31               USD        2.551100e+07
#
#      payments_foroperating_activities  proceeds_fromoperating_activities  \
# 0                                   0                                  0
# ...

# %%
# Exporting balance_sheet dataframe to csv file without the index.
filtered_cash_flow_df.to_csv('C:\\Users\\Lora B\\Documents\\Development\\FinalProject_IPO\\DataExtraction\\raw_dataset\\combined_filtered_cash_flow.csv', index = False)
