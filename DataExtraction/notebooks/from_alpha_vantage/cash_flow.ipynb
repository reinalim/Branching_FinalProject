# %% [markdown]
# ### Alpha Vantage Cash Flow Data Request
#
# https://www.alphavantage.co/

# %%
# Import dependancies
import pandas as pd
import requests
import json
import sys
import time
import csv
import os

# Import the API key.
from config2 import stocks_p_api_key

# %%
company_overview_df = pd.read_csv('raw_dataset/company_overview.csv')
company_overview_df.head()
# Out:
#   SYMBOL    ASSET_TYPE                               NAME EXCHANGE CURRENCY  \
# 0  TWCTU  Common Stock          TWC Tech Holdings II Corp   NASDAQ      USD
# 1  SVACU  Common Stock   Starboard Value Acquisition Corp   NASDAQ      USD
# 2  ITACU  Common Stock  Industrial Tech Acquisitions, Inc   NASDAQ      USD
# 3   BCTG  Common Stock              BCTG Acquisition Corp   NASDAQ      USD
# 4  INAQU  Common Stock          INSU Acquisition Corp. II   NASDAQ      USD
#
#   COUNTRY              SECTOR         INDUSTRY  \
# 0     USA                 NaN              NaN
# 1     USA  Financial Services  Shell Companies
# 2     USA  Financial Services  Shell Companies
# 3     USA  Financial Services  Shell Companies
# 4     USA  Financial Services  Shell Companies
#
#                                              ADDRESS
# 0  Four Embarcadero Center, San Francisco, CA, Un...
# 1  777 Third Avenue, New York, NY, United States,...
# 2  5090 Richmond Avenue, Houston, TX, United Stat...
# 3  11682 El Camino Real, San Diego, CA, United St...
# 4  2929 Arch Street, Philadelphia, PA, United Sta...

# %%
company_overview_df.shape
# Out:
# (2685, 9)

# %%
company_overview_df.dtypes
# Out:
# SYMBOL        object
# ASSET_TYPE    object
# NAME          object
# EXCHANGE      object
# CURRENCY      object
# COUNTRY       object
# SECTOR        object
# INDUSTRY      object
# ADDRESS       object
# dtype: object

# %%
# Create a list of IPO symbols from the company_overview_df
IPO_list = company_overview_df['SYMBOL'].tolist()
IPO_list
# Out:
# ['TWCTU',
#  'SVACU',
#  'ITACU',
#  'BCTG',
#  'INAQU',
#  'CAPAU',
#  'PRFX',
#  'AUVI',
#  'HCDI',
#  'BTAQU',
#  'CFIIU',
#  'XPEV',
#  'FTOCU',
#  'KYMR',
#  'NNOX',
#  'HRMY',
#  'CVAC',
#  'LCAPU',
#  'BEKE',
#  'NTST',
#  'ARYA',
#  'CMPI',
#  'FRLN',
#  'IBEX',
#  'VMACU',
#  'GRSVU',
#  'KSMTU',
#  'AFIB',
#  'OSH',
#  'RKT',
#  'BIGC',
#  'RXT',
#  'BOWXU',
#  'HOLUU',
#  'HSAQ',
#  'GOED',
#  'NHICU',
#  'ETACU',
#  'FTHM',
#  'VITL',
#  'ALVR',
#  'LI',
#  'VERX',
#  'ACEVU',
#  'ANNX',
#  'GRCYU',
#  'INZY',
#  'ITOS',
#  'NRIX',
#  'ERESU',
#  'MEG',
#  'EDTK',
#  'JAMF',
#  'PSACU',
#  'ALXO',
#  'BLI',
#  'DFHTU',
#  'PAND',
#  'RLAY',
#  'TIG',
#  'GOCO',
#  'NCNO',
#  'NKTX',
#  'PSTX',
#  'QH',
#  'BLCT',
#  'LMND',
#  'DNB',
#  'API',
#  'AKUS',
#  'ACI',
#  'EBON',
#  'FUSN',
#  'PYPD',
#  'BRLIU',
#  'FMTX',
#  'GTH',
#  'PROG',
#  'RPTX',
#  'RPRX',
#  'AZEK',
#  'BNR',
#  'GBIO',
#  'PCVX',
#  'LTRN',
#  'UCL',
#  'HECCU',
#  'VRM',
#  'AMTI',
#  'ARYBU',
#  'DADA',
#  'LEGN',
#  'MCACU',
#  'FOUR',
#  'ZI',
#  'PLRX',
#  'SLQT',
#  'NOVSU',
#  'AYLA',
#  'CLEU',
#  'KC',
#  'CGROU',
#  'LYRA',
#  'ORIC',
#  'KROS',
#  'ZNTL',
#  'WIMI',
#  'IMRA',
#  'DFPHU',
#  'GFL',
#  'PASG',
#  'ZCMD',
#  'ESSCU',
#  'NBACU',
#  'ZGYHU',
#  'GRIL',
#  'RVMD',
#  'HUIZ',
#  'GNRSU',
#  'NREF',
#  'ONEW',
#  'PFHD',
#  'BEAM',
#  'CSPR',
#  'PPD',
#  'SDGR',
#  'ARQT',
#  'REYN',
#  'ANVS',
#  'BDTX',
#  'ANPC',
#  'GHIVU',
#  'SCVXU',
#  'IMAB',
#  'LIZI',
#  'DNK',
#  'VEL',
#  'MKD',
#  'INDO',
#  'MNPR',
#  'CIICU',
#  'HCCOU',
#  'OCFT',
#  'SPT',
#  'BILL',
#  'EH',
#  'LIVKU',
#  'XP',
#  'LMPX',
#  'PINE',
#  'CHPMU',
#  'PTACU',
#  'CAN',
#  'SITM',
#  'AMHCU',
#  'SAQNU',
#  'GRNVU',
#  'ETNB',
#  'KRKR',
#  'CNSP',
#  'MOHO',
#  'SRACU',
#  'TELA',
#  'CNTG',
#  'GRTX',
#  'SI',
#  'MCMJU',
#  'QK',
#  'DUO',
#  'FSRVU',
#  'OYST',
#  'RAPT',
#  'AIH',
#  'CABA',
#  'HAPP',
#  'PHAT',
#  'PGNY',
#  'TFFP',
#  'DAO',
#  'BRP',
#  'LATNU',
#  'BRBR',
#  'HBT',
#  'VIR',
#  'BNTX',
#  'APRE',
#  'FREQ',
#  'VIE',
#  'OPRT',
#  'PTON',
#  'DDOG',
#  'XGN',
#  'PING',
#  'NVST',
#  'IGMS',
#  'APXTU',
#  'NET',
#  'EXPCU',
#  'STSA',
#  'SWTX',
#  'TXG',
#  'SDC',
#  'NPAUU',
#  'JFU',
#  'THBRU',
#  'INMD',
#  'SSPKU',
#  'HKIB',
#  'ORSNU',
#  'DT',
#  'KRUS',
#  'SNDL',
#  'BORR',
#  'BHAT',
#  'VIST',
#  'WSG',
#  'CSTL',
#  'FLLCU',
#  'HCAT',
#  'LVGO',
#  'NOVA',
#  'AFYA',
#  'MDLA',
#  'AMK',
#  'FULC',
#  'GMAB',
#  'MIRM',
#  'ORCC',
#  'PHR',
#  'DOYU',
#  'THCAU',
#  'KRTX',
#  'REAL',
#  'BBIO',
#  'CHNG',
#  'MORF',
#  'CMBM',
#  'LINX',
#  'AKRO',
#  'BCEL',
#  'GO',
#  'PSNL',
#  'PRVL',
#  'WORK',
#  'SMMCU',
#  'STOK',
#  'CHWY',
#  'FVRR',
#  'CRWD',
#  'MWK',
#  'RVLV',
#  'GSX',
#  'BCYC',
#  'IDYA',
#  'RTLR',
#  'GXGXU',
#  'AVTR',
#  'FSLY',
#  'PSTL',
#  'AGBAU',
#  'APLT',
#  'DEACU',
#  'JFIN',
#  'SONM',
#  'UBER',
#  'AXLA',
#  'HHR',
#  'MEC',
#  'MIST',
#  'NXTC',
#  'SPFI',
#  'PSN',
#  'TRVI',
#  'RRBI',
#  'SCPL',
#  'YJ',
#  'BYND',
#  'SY',
#  'TMDX',
#  'ACTTU',
#  'MNRL',
#  'GNLN',
#  'HOOK',
#  'PINS',
#  'ZM',
#  'PLMR',
#  'TPTX',
#  'JMIA',
#  'PD',
#  'TUFN',
#  'GHSI',
#  'NGM',
#  'SILK',
#  'TW',
#  'RUHN',
#  'PBTS',
#  'LYFT',
#  'DTIL',
#  'JFKKU',
#  'LEVI',
#  'INSUU',
#  'TIGR',
#  'TRNEU',
#  'CRSAU',
#  'FUTU',
#  'SWAV',
#  'THCBU',
#  'DPHCU',
#  'KLDO',
#  'SHLLU',
#  'SLGG',
#  'TCRR',
#  'ACAMU',
#  'HOTH',
#  'MITO',
#  'GOSS',
#  'HARP',
#  'ALEC',
#  'MNCLU',
#  'HHHHU',
#  'GMHIU',
#  'NFE',
#  'MTC',
#  'QFIN',
#  'LEGH',
#  'CFFAU',
#  'TME',
#  'SAMAU',
#  'MRNA',
#  'THOR',
#  'MOGU',
#  'MDRR',
#  'TC',
#  'AMCIU',
#  'BWMCU',
#  'FTACU',
#  'BCSF',
#  'WEI',
#  'VAPO',
#  'ETON',
#  'TBLTU',
#  'CNF',
#  'AXNX',
#  'ORTX',
#  'TWST',
#  'GMDA',
#  'PT',
#  'STNE',
#  'YETI',
#  'ALACU',
#  'LOGC',
#  'NIU',
#  'OSMT',
#  'PHAS',
#  'MSC',
#  'SIBN',
#  'PLAN',
#  'DDMXU',
#  'EQ',
#  'ALLO',
#  'LTHM',
#  'ARYAU',
#  'CTACU',
#  'EDTXU',
#  'ESTC',
#  'GH',
#  'KOD',
#  'UPWK',
#  'CTK',
#  'GRTS',
#  'ARVN',
#  'LAIX',
#  'STRO',
#  'UROV',
#  'ARCE',
#  'CBNK',
#  'ETTX',
#  'SVMK',
#  'FTCH',
#  'YMAB',
#  'BSVN',
#  'ELAN',
#  'EB',
#  'XYF',
#  'FVCB',
#  'PRNB',
#  'QTT',
#  'YI',
#  'NIO',
#  'LOACU',
#  'BNGOU',
#  'TZACU',
#  'TKKSU',
#  'ARDS',
#  'MESA',
#  'VCNX',
#  'ARLO',
#  'CWK',
#  'SONO',
#  'TOTAU',
#  'ADIL',
#  'ADILW',
#  'DAVA',
#  'OPRA',
#  'CANG',
#  'FOCS',
#  'LQDA',
#  'PDD',
#  'TENB',
#  'AQST',
#  'BE',
#  'GLACU',
#  'JG',
#  'REPL',
#  'ALLK',
#  'ESTA',
#  'MYFW',
#  'TLRY',
#  'CCB',
#  'CRNX',
#  'RUBY',
#  'ALGRU',
#  'DOMO',
#  'BJ',
#  'ENTX',
#  'ENTXW',
#  'FTSV',
#  'HCCHU',
#  'STIM',
#  'TCDA',
#  'HYRE',
#  'LOVE',
#  'NTGN',
#  'UXIN',
#  'AUTL',
#  'ECOR',
#  'APTX',
#  'AVRO',
#  'EPRT',
#  'IIIV',
#  'KZR',
#  'MGTA',
#  'XERS',
#  'EIDX',
#  'LFACU',
#  'TWLVU',
#  'TBRGU',
#  'AVLR',
#  'NEW',
#  'VRCA',
#  'CHRA',
#  'USX',
#  'MGTX',
#  'TDACU',
#  'ITRM',
#  'CLPS',
#  'GSKY',
#  'KNSA',
#  'SRRK',
#  'EVOP',
#  'PS',
#  'VTIQU',
#  'TMCXU',
#  'HUYA',
#  'EQH',
#  'EVLO',
#  'OBNK',
#  'CBLK',
#  'ROAD',
#  'STXB',
#  'INSP',
#  'UBX',
#  'PRT',
#  'DOCU',
#  'GSHD',
#  'SMAR',
#  'CDAY',
#  'LASR',
#  'LEVL',
#  'PVTL',
#  'EAF',
#  'SURF',
#  'ZUO',
#  'GNPX',
#  'IQ',
#  'BILI',
#  'FIXX',
#  'GHG',
#  'DBX',
#  'STG',
#  'DNJR',
#  'AIHS',
#  'TIBRU',
#  'ZS',
#  'RCUS',
#  'BWB',
#  'OPESU',
#  'BTAI',
#  'DFBHU',
#  'FAMI',
#  'MOTS',
#  'CDLX',
#  'QES',
#  'WHD',
#  'EOLS',
#  'MUDSU',
#  'VCTR',
#  'FTSI',
#  'OSS',
#  'CAAP',
#  'HUD',
#  'SLGL',
#  'MTECU',
#  'ARMO',
#  'AGS',
#  'SLDB',
#  'EYEN',
#  'GTES',
#  'GPAQU',
#  'PAGS',
#  'ILPT',
#  'LBRT',
#  'NEBUU',
#  'ICLK',
#  'LX',
#  'CASA',
#  'NMRK',
#  'DNLI',
#  'LBC',
#  'CURO',
#  'ODT',
#  'QTRX',
#  'LACQU',
#  'RETO',
#  'BRPAU',
#  'BXG',
#  'SAIL',
#  'SCPH',
#  'SFIX',
#  'SBT',
#  'ASNS',
#  'JT',
#  'SEND',
#  'BAND',
#  'APLS',
#  'SOGO',
#  'CBTX',
#  'IFRX',
#  'FEDU',
#  'MCB',
#  'ACMR',
#  'STNLU',
#  'ALNA',
#  'AQUA',
#  'FNKO',
#  'SPRO',
#  'ALTR',
#  'LOMA',
#  'MBIN',
#  'NEXA',
#  'FSCT',
#  'BPMP',
#  'CMSSU',
#  'EYE',
#  'SE',
#  'REDU',
#  'MDB',
#  'QD',
#  'OPTN',
#  'CARG',
#  'KIDS',
#  'SWCH',
#  'BRACU',
#  'NITE',
#  'NCNA',
#  'ROKU',
#  'RYB',
#  'SECO',
#  'OMP',
#  'PETZ',
#  'CELC',
#  'DESP',
#  'KRYS',
#  'ZLAB',
#  'DOTAU',
#  'TRMT',
#  'ATACU',
#  'RNGR',
#  'IAMXU',
#  'VNTR',
#  'CMTA',
#  'NEWA',
#  'RDFN',
#  'INDUU',
#  'WRLSU',
#  'SNNA',
#  'RBB',
#  'PETQ',
#  'CLXT',
#  'KALA',
#  'TRTX',
#  'FSACU',
#  'AKCA',
#  'CODX',
#  'BY',
#  'TNTR',
#  'ALRN',
#  'APRN',
#  'DOVA',
#  'MRSN',
#  'ATXI',
#  'ESQ',
#  'GPMT',
#  'ATUS',
#  'SAFE',
#  'BCACU',
#  'CNACU',
#  'ATNX',
#  'CGBD',
#  'PLYM',
#  'SSTI',
#  'KBLMU',
#  'APPN',
#  'WOW',
#  'SGH',
#  'BEDU',
#  'GTHX',
#  'ASV',
#  'MMDMU',
#  'NESRU',
#  'SOI',
#  'VERI',
#  'FPH',
#  'NDRAU',
#  'GNTY',
#  'KREF',
#  'OVID',
#  'BHVN',
#  'URGN',
#  'CVNA',
#  'CLDR',
#  'EEX',
#  'NCSM',
#  'ZYME',
#  'FND',
#  'WTTR',
#  'CADE',
#  'HCC',
#  'YEXT',
#  'NETS',
#  'AZUL',
#  'VEACU',
#  'OKTA',
#  'SNDR',
#  'ELVT',
#  'KAACU',
#  'AYX',
#  'SRUNU',
#  'MULE',
#  'GOOS',
#  'ARD',
#  'PSDO',
#  'MPACU',
#  'JILL',
#  'BYSI',
#  'SNAP',
#  'HLNE',
#  'DCPH',
#  'FBM',
#  'SACH',
#  'KRP',
#  'METC',
#  'INVH',
#  'LAUR',
#  'JNCE',
#  'ANAB',
#  'FNTEU',
#  'GSHTU',
#  'TRVG',
#  'WRD',
#  'ICHR',
#  'SNES',
#  'POLA',
#  'IIPR',
#  'SND',
#  'GDS',
#  'BL',
#  'QTNA',
#  'GTYHU',
#  'MYOV',
#  'ZTO',
#  'RARX',
#  'FRTA',
#  'IRTC',
#  'CRSP',
#  'TUSK',
#  'AZRE',
#  'XOG',
#  'AHPAU',
#  'AZRX',
#  'CWH',
#  'MRAM',
#  'ADSW',
#  'WAAS',
#  'OBLN',
#  'NTNX',
#  'FLGT',
#  'TRHC',
#  'ACIU',
#  'GSUM',
#  'VVV',
#  'CSTR',
#  'ELF',
#  'NOVN',
#  'TTD',
#  'EVBG',
#  'FBK',
#  'SCACU',
#  'NBLX',
#  'MACQU',
#  'AIRG',
#  'MEDP',
#  'PTGX',
#  'HOME',
#  'FHB',
#  'TLND',
#  'KNSL',
#  'TCMD',
#  'KDMN',
#  'TPIC',
#  'PI',
#  'PTHN',
#  'BOLD',
#  'APFH',
#  'CPAAU',
#  'LN',
#  'MSDI',
#  'MIIIU',
#  'TWLO',
#  'SELB',
#  'ATKR',
#  'SRTSU',
#  'CLSD',
#  'NH',
#  'COTV',
#  'GMS',
#  'RETA',
#  'USFD',
#  'MSBI',
#  'CFCOU',
#  'SUPV',
#  'MRUS',
#  'PZRX',
#  'ACIA',
#  'ONSIU',
#  'SITE',
#  'NTLA',
#  'YIN',
#  'SCWX',
#  'ARA',
#  'MGP',
#  'BATS',
#  'AGLE',
#  'CRVS',
#  'KLREU',
#  'JSYNU',
#  'SNDX',
#  'SRAQU',
#  'AVXS',
#  'BGNE',
#  'EDIT',
#  'YRD',
#  'TEAM',
#  'DLTH',
#  'AXSM',
#  'MIME',
#  'SQ',
#  'MTCH',
#  'INST',
#  'AAAP',
#  'EQBK',
#  'VYGR',
#  'WVE',
#  'MYOK',
#  'IOTS',
#  'DMTX',
#  'RACE',
#  'MPSX',
#  'AFCO',
#  'CERCU',
#  'FDC',
#  'ABTX',
#  'CTMX',
#  'ACRS',
#  'PSTG',
#  'NVCR',
#  'PFGC',
#  'SGRY',
#  'NBRV',
#  'PEN',
#  'RGNX',
#  'PACEU',
#  'CNFR',
#  'ECACU',
#  'HLI',
#  'GBT',
#  'AIMT',
#  'PLNT',
#  'BETR',
#  'RUN',
#  'ZYNE',
#  'GLBL',
#  'AQMS',
#  'EACQU',
#  'GPACU',
#  'WYIGU',
#  'LOB',
#  'NEOS',
#  'BUFF',
#  'MCFT',
#  'OOMA',
#  'RPD',
#  'CHMA',
#  'JP',
#  'OLLI',
#  'NTRA',
#  'CNXC',
#  'CFMS',
#  'TDOC',
#  'UFAB',
#  'ALRM',
#  'APPF',
#  'MCRB',
#  'XTLY',
#  'YECO',
#  'CATB',
#  'GNRT',
#  'GKOS',
#  'LNTH',
#  'MCRN',
#  'TRU',
#  'CAFD',
#  'FOGO',
#  'MB',
#  'FIT',
#  'UNVR',
#  'NVLS',
#  'IVTY',
#  'WING',
#  'AXON',
#  'ELECU',
#  'PUB',
#  'DTEA',
#  'GI',
#  'PTXP',
#  'PGND',
#  'GPIAU',
#  'BKFS',
#  'RKDA',
#  'FTAI',
#  'JAGX',
#  'EQGP',
#  'BOJA',
#  'LIFE',
#  'COLL',
#  'TEGP',
#  'ADAP',
#  'CLCD',
#  'HTGM',
#  'OPGN',
#  'ARWAU',
#  'BSM',
#  'BPMC',
#  'AAPC',
#  'EVA',
#  'VKTX',
#  'APIC',
#  'NSA',
#  'ETSY',
#  'KMPH',
#  'PRTY',
#  'VIRT',
#  'CDTX',
#  'ADRO',
#  'CBYL',
#  'KRNT',
#  'GDDY',
#  'JCAP',
#  'SEDG',
#  'HRMNU',
#  'STDY',
#  'NCOM',
#  'GSBD',
#  'SUM',
#  'MXPT',
#  'BZUN',
#  'CHCT',
#  'ITEK',
#  'BLPH',
#  'EYEG',
#  'AJX',
#  'FNTCU',
#  'INOV',
#  'NVTA',
#  'AVNU',
#  'CPPL',
#  'DEA',
#  'NVET',
#  'AVGR',
#  'HIFR',
#  'ONCE',
#  'TCON',
#  'SHAK',
#  'ENTL',
#  'ASND',
#  'ZSAN',
#  'PN',
#  'ICBK',
#  'JUNO',
#  'BLCM',
#  'ONDK',
#  'RMP',
#  'AVOL',
#  'CNXR',
#  'HDP',
#  'NEWR',
#  'WK',
#  'LC',
#  'MOMO',
#  'NEFF',
#  'SKIS',
#  'CNV',
#  'HABT',
#  'NEOT',
#  'PGRE',
#  'EHIC',
#  'FGEN',
#  'LMRK',
#  'NDRM',
#  'VA',
#  'NAP',
#  'PRAH',
#  'SKYS',
#  'AXTA',
#  'JYNT',
#  'FRPT',
#  'INCR',
#  'TBK',
#  'CHRS',
#  'NVRO',
#  'UPLD',
#  'AM',
#  'XENE',
#  'BOOT',
#  'SHLX',
#  'SIEN',
#  'HDRAU',
#  'ZAYO',
#  'ATRA',
#  'FWP',
#  'GWB',
#  'DPLO',
#  'HUBS',
#  'OMAM',
#  'USDP',
#  'VBTX',
#  'DERM',
#  'FMSA',
#  'YDLE',
#  'AAC',
#  'ATTO',
#  'CALA',
#  'JPEP',
#  'VWR',
#  'W',
#  'CADTU',
#  'VBLT',
#  'VSLR',
#  'CNNX',
#  'TVPT',
#  'CYBR',
#  'MDLY',
#  'SFS',
#  'VTAE',
#  'BABA',
#  'FOMX',
#  'PRQR',
#  'CIVI',
#  'TKAI',
#  'AFMD',
#  'RWLK',
#  'SMACU',
#  'BNK',
#  'GNBC',
#  'ICD',
#  'RYI',
#  'HMLP',
#  'DSKY',
#  'TTOO',
#  'EARS',
#  ...]

# %%
# Check length of IPO_list
len(IPO_list)
# Out:
# 2685

# %% [markdown]
# ### Request Cash Flow from Alpha Vantage
#
# Create a loop to retreive Cash Flow for each symbol in the IPO_list

# %%
# Create For loop to fetch responses from Alpha Vantage

KEY_ERROR_List = []
index = 0

for symbol in IPO_list:
    
    # Define url
    base_income_statement_url = "https://www.alphavantage.co/query?function=CASH_FLOW&symbol="    
    
    Q_fiscalDateEnding_List = []
    Q_reportedCurrency_List = []
    Q_operatingCashflow_List = []
    Q_paymentsForOperatingActivities_List = []
    Q_proceedsFromOperatingActivities_List = []
    Q_changeInOperatingLiabilities_List = []
    Q_changeInOperatingAssets_List = []
    Q_depreciationDepletionAndAmortization_List = []
    Q_capitalExpenditures_List = []
    Q_changeInReceivables_List = []
    Q_changeInInventory_List = []
    Q_profitLoss_List = []
    Q_cashflowFromInvestment_List = []
    Q_cashflowFromFinancing_List = []
    Q_proceedsFromRepaymentsOfShortTermDebt_List = []
    Q_paymentsForRepurchaseOfCommonStock_List = []
    Q_paymentsForRepurchaseOfEquity_List = []
    Q_paymentsForRepurchaseOfPreferredStock_List = []
    Q_dividendPayout_List = []
    Q_dividendPayoutCommonStock_List = []
    Q_dividendPayoutPreferredStock_List = []
    Q_proceedsFromIssuanceOfCommonStock_List = []
    Q_proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet_List = []
    Q_proceedsFromIssuanceOfPreferredStock_List = []
    Q_proceedsFromRepurchaseOfEquity_List = []
    Q_proceedsFromSaleOfTreasuryStock_List = []
    Q_changeInCashAndCashEquivalents_List = []
    Q_changeInExchangeRate_List = []
    Q_netIncome_List = []

    
    symbol_parameter = symbol

    full_url = f'{base_income_statement_url}{symbol_parameter}&apikey={stocks_p_api_key}'

    # Make an API call to the API and get the JSON object
    response = requests.get(full_url).json()

    try:
    
        for i in range(len(response['quarterlyReports'])):

            Q_fiscalDateEnding_response = response['quarterlyReports'][i]['fiscalDateEnding']
            Q_reportedCurrency_response = response['quarterlyReports'][i]['reportedCurrency']
            Q_operatingCashflow_response = response['quarterlyReports'][i]['operatingCashflow']
            Q_paymentsForOperatingActivities_response = response['quarterlyReports'][i]['paymentsForOperatingActivities']
            Q_proceedsFromOperatingActivities_response = response['quarterlyReports'][i]['proceedsFromOperatingActivities']
            Q_changeInOperatingLiabilities_response = response['quarterlyReports'][i]['changeInOperatingLiabilities']
            Q_changeInOperatingAssets_response = response['quarterlyReports'][i]['changeInOperatingAssets']
            Q_depreciationDepletionAndAmortization_response = response['quarterlyReports'][i]['depreciationDepletionAndAmortization']
            Q_capitalExpenditures_response = response['quarterlyReports'][i]['capitalExpenditures']
            Q_changeInReceivables_response = response['quarterlyReports'][i]['changeInReceivables']
            Q_changeInInventory_response = response['quarterlyReports'][i]['changeInInventory']
            Q_profitLoss_response = response['quarterlyReports'][i]['profitLoss']
            Q_cashflowFromInvestment_response = response['quarterlyReports'][i]['cashflowFromInvestment']
            Q_cashflowFromFinancing_response = response['quarterlyReports'][i]['cashflowFromFinancing']
            Q_proceedsFromRepaymentsOfShortTermDebt_response = response['quarterlyReports'][i]['proceedsFromRepaymentsOfShortTermDebt']
            Q_paymentsForRepurchaseOfCommonStock_response = response['quarterlyReports'][i]['paymentsForRepurchaseOfCommonStock']
            Q_paymentsForRepurchaseOfEquity_response = response['quarterlyReports'][i]['paymentsForRepurchaseOfEquity']
            Q_paymentsForRepurchaseOfPreferredStock_response = response['quarterlyReports'][i]['paymentsForRepurchaseOfPreferredStock']
            Q_dividendPayout_response = response['quarterlyReports'][i]['dividendPayout']
            Q_dividendPayoutCommonStock_response = response['quarterlyReports'][i]['dividendPayoutCommonStock']
            Q_dividendPayoutPreferredStock_response = response['quarterlyReports'][i]['dividendPayoutPreferredStock']
            Q_proceedsFromIssuanceOfCommonStock_response = response['quarterlyReports'][i]['proceedsFromIssuanceOfCommonStock']
            Q_proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet_response = response['quarterlyReports'][i]['proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet']
            Q_proceedsFromIssuanceOfPreferredStock_response = response['quarterlyReports'][i]['proceedsFromIssuanceOfPreferredStock']
            Q_proceedsFromRepurchaseOfEquity_response = response['quarterlyReports'][i]['proceedsFromRepurchaseOfEquity']
            Q_proceedsFromSaleOfTreasuryStock_response = response['quarterlyReports'][i]['proceedsFromSaleOfTreasuryStock']
            Q_changeInCashAndCashEquivalents_response = response['quarterlyReports'][i]['changeInCashAndCashEquivalents']
            Q_changeInExchangeRate_response = response['quarterlyReports'][i]['changeInExchangeRate']
            Q_netIncome_response = response['quarterlyReports'][i]['netIncome']


            Q_fiscalDateEnding_List.append(Q_fiscalDateEnding_response)
            Q_reportedCurrency_List.append(Q_reportedCurrency_response)
            Q_operatingCashflow_List.append(Q_operatingCashflow_response)
            Q_paymentsForOperatingActivities_List.append(Q_paymentsForOperatingActivities_response)
            Q_proceedsFromOperatingActivities_List.append(Q_proceedsFromOperatingActivities_response)
            Q_changeInOperatingLiabilities_List.append(Q_changeInOperatingLiabilities_response)
            Q_changeInOperatingAssets_List.append(Q_changeInOperatingAssets_response)
            Q_depreciationDepletionAndAmortization_List.append(Q_depreciationDepletionAndAmortization_response)
            Q_capitalExpenditures_List.append(Q_capitalExpenditures_response)
            Q_changeInReceivables_List.append(Q_changeInReceivables_response)
            Q_changeInInventory_List.append(Q_changeInInventory_response)
            Q_profitLoss_List.append(Q_profitLoss_response)
            Q_cashflowFromInvestment_List.append(Q_cashflowFromInvestment_response)
            Q_cashflowFromFinancing_List.append(Q_cashflowFromFinancing_response)
            Q_proceedsFromRepaymentsOfShortTermDebt_List.append(Q_proceedsFromRepaymentsOfShortTermDebt_response)
            Q_paymentsForRepurchaseOfCommonStock_List.append(Q_paymentsForRepurchaseOfCommonStock_response)
            Q_paymentsForRepurchaseOfEquity_List.append(Q_paymentsForRepurchaseOfEquity_response)
            Q_paymentsForRepurchaseOfPreferredStock_List.append(Q_paymentsForRepurchaseOfPreferredStock_response)
            Q_dividendPayout_List.append(Q_dividendPayout_response)
            Q_dividendPayoutCommonStock_List.append(Q_dividendPayoutCommonStock_response)
            Q_dividendPayoutPreferredStock_List.append(Q_dividendPayoutPreferredStock_response)
            Q_proceedsFromIssuanceOfCommonStock_List.append(Q_proceedsFromIssuanceOfCommonStock_response)
            Q_proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet_List.append(Q_proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet_response)
            Q_proceedsFromIssuanceOfPreferredStock_List.append(Q_proceedsFromIssuanceOfPreferredStock_response)
            Q_proceedsFromRepurchaseOfEquity_List.append(Q_proceedsFromRepurchaseOfEquity_response)
            Q_proceedsFromSaleOfTreasuryStock_List.append(Q_proceedsFromSaleOfTreasuryStock_response)
            Q_changeInCashAndCashEquivalents_List.append(Q_changeInCashAndCashEquivalents_response)
            Q_changeInExchangeRate_List.append(Q_changeInExchangeRate_response)
            Q_netIncome_List.append(Q_netIncome_response)


        # Transform each list into a series

        Q_fiscalDateEnding_Series = pd.Series(Q_fiscalDateEnding_List)
        Q_reportedCurrency_Series = pd.Series(Q_reportedCurrency_List)
        Q_operatingCashflow_Series = pd.Series(Q_operatingCashflow_List)
        Q_paymentsForOperatingActivities_Series = pd.Series(Q_paymentsForOperatingActivities_List)
        Q_proceedsFromOperatingActivities_Series = pd.Series(Q_proceedsFromOperatingActivities_List)
        Q_changeInOperatingLiabilities_Series = pd.Series(Q_changeInOperatingLiabilities_List)
        Q_changeInOperatingAssets_Series = pd.Series(Q_changeInOperatingAssets_List)
        Q_depreciationDepletionAndAmortization_Series = pd.Series(Q_depreciationDepletionAndAmortization_List)
        Q_capitalExpenditures_Series = pd.Series(Q_capitalExpenditures_List)
        Q_changeInReceivables_Series = pd.Series(Q_changeInReceivables_List)
        Q_changeInInventory_Series = pd.Series(Q_changeInInventory_List)
        Q_profitLoss_Series = pd.Series(Q_profitLoss_List)
        Q_cashflowFromInvestment_Series = pd.Series(Q_cashflowFromInvestment_List)
        Q_cashflowFromFinancing_Series = pd.Series(Q_cashflowFromFinancing_List)
        Q_proceedsFromRepaymentsOfShortTermDebt_Series = pd.Series(Q_proceedsFromRepaymentsOfShortTermDebt_List)
        Q_paymentsForRepurchaseOfCommonStock_Series = pd.Series(Q_paymentsForRepurchaseOfCommonStock_List)
        Q_paymentsForRepurchaseOfEquity_Series = pd.Series(Q_paymentsForRepurchaseOfEquity_List)
        Q_paymentsForRepurchaseOfPreferredStock_Series = pd.Series(Q_paymentsForRepurchaseOfPreferredStock_List)
        Q_dividendPayout_Series = pd.Series(Q_dividendPayout_List)
        Q_dividendPayoutCommonStock_Series = pd.Series(Q_dividendPayoutCommonStock_List)
        Q_dividendPayoutPreferredStock_Series = pd.Series(Q_dividendPayoutPreferredStock_List)
        Q_proceedsFromIssuanceOfCommonStock_Series = pd.Series(Q_proceedsFromIssuanceOfCommonStock_List)
        Q_proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet_Series = pd.Series(Q_proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet_List)
        Q_proceedsFromIssuanceOfPreferredStock_Series = pd.Series(Q_proceedsFromIssuanceOfPreferredStock_List)
        Q_proceedsFromRepurchaseOfEquity_Series = pd.Series(Q_proceedsFromRepurchaseOfEquity_List)
        Q_proceedsFromSaleOfTreasuryStock_Series = pd.Series(Q_proceedsFromSaleOfTreasuryStock_List)
        Q_changeInCashAndCashEquivalents_Series = pd.Series(Q_changeInCashAndCashEquivalents_List)
        Q_changeInExchangeRate_Series = pd.Series(Q_changeInExchangeRate_List)
        Q_netIncome_Series = pd.Series(Q_netIncome_List)

        frame = {
            'SYMBOL':symbol_parameter,
            'fiscalDateEnding' : Q_fiscalDateEnding_Series,
            'reportedCurrency' : Q_reportedCurrency_Series,
            'operatingCashflow' : Q_operatingCashflow_Series,
            'paymentsForOperatingActivities' : Q_paymentsForOperatingActivities_Series,
            'proceedsFromOperatingActivities' : Q_proceedsFromOperatingActivities_Series,
            'changeInOperatingLiabilities' : Q_changeInOperatingLiabilities_Series,
            'changeInOperatingAssets' : Q_changeInOperatingAssets_Series,
            'depreciationDepletionAndAmortization' : Q_depreciationDepletionAndAmortization_Series,
            'capitalExpenditures' : Q_capitalExpenditures_Series,
            'changeInReceivables' : Q_changeInReceivables_Series,
            'changeInInventory' : Q_changeInInventory_Series,
            'profitLoss' : Q_profitLoss_Series,
            'cashflowFromInvestment' : Q_cashflowFromInvestment_Series,
            'cashflowFromFinancing' : Q_cashflowFromFinancing_Series,
            'proceedsFromRepaymentsOfShortTermDebt' : Q_proceedsFromRepaymentsOfShortTermDebt_Series,
            'paymentsForRepurchaseOfCommonStock' : Q_paymentsForRepurchaseOfCommonStock_Series,
            'paymentsForRepurchaseOfEquity' : Q_paymentsForRepurchaseOfEquity_Series,
            'paymentsForRepurchaseOfPreferredStock' : Q_paymentsForRepurchaseOfPreferredStock_Series,
            'dividendPayout' : Q_dividendPayout_Series,
            'dividendPayoutCommonStock' : Q_dividendPayoutCommonStock_Series,
            'dividendPayoutPreferredStock' : Q_dividendPayoutPreferredStock_Series,
            'proceedsFromIssuanceOfCommonStock' : Q_proceedsFromIssuanceOfCommonStock_Series,
            'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet' : Q_proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet_Series,
            'proceedsFromIssuanceOfPreferredStock' : Q_proceedsFromIssuanceOfPreferredStock_Series,
            'proceedsFromRepurchaseOfEquity' : Q_proceedsFromRepurchaseOfEquity_Series,
            'proceedsFromSaleOfTreasuryStock' : Q_proceedsFromSaleOfTreasuryStock_Series,
            'changeInCashAndCashEquivalents' : Q_changeInCashAndCashEquivalents_Series,
            'changeInExchangeRate' : Q_changeInExchangeRate_Series,
            'netIncome' : Q_netIncome_Series
        }

        q_cash_flow_df = pd.DataFrame(frame)

        # Exporting test income statement dataframe to csv file
        save_file_path = f'raw_dataset/cash_flow/{symbol}_cash_flow.csv'
        q_cash_flow_df.to_csv(save_file_path,index=False)
        
    except KeyError:
        print(f"KeyError occured on {symbol}")
        KEY_ERROR_List.append(symbol)
        
    print(index, symbol)
    index += 1

print(len(ERROR_List))
# Out:
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:117: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:118: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:119: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:120: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:121: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:122: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:123: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:124: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:125: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:126: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:127: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:128: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:129: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:130: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:131: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:132: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:133: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:134: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:135: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:136: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:137: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:138: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:139: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:140: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:141: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:142: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:143: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:144: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:145: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# 0 TWCTU
# 1 SVACU
# 2 ITACU
# 3 BCTG
# 4 INAQU
# 5 CAPAU
# 6 PRFX
# 7 AUVI
# 8 HCDI
# 9 BTAQU
# 10 CFIIU
# 11 XPEV
# 12 FTOCU
# 13 KYMR
# 14 NNOX
# 15 HRMY
# 16 CVAC
# 17 LCAPU
# 18 BEKE
# 19 NTST
# 20 ARYA
# 21 CMPI
# 22 FRLN
# 23 IBEX
# 24 VMACU
# 25 GRSVU
# 26 KSMTU
# 27 AFIB
# 28 OSH
# 29 RKT
# 30 BIGC
# 31 RXT
# 32 BOWXU
# 33 HOLUU
# 34 HSAQ
# 35 GOED
# 36 NHICU
# 37 ETACU
# 38 FTHM
# 39 VITL
# 40 ALVR
# 41 LI
# 42 VERX
# 43 ACEVU
# 44 ANNX
# 45 GRCYU
# 46 INZY
# 47 ITOS
# 48 NRIX
# 49 ERESU
# 50 MEG
# 51 EDTK
# 52 JAMF
# 53 PSACU
# 54 ALXO
# 55 BLI
# 56 DFHTU
# 57 PAND
# 58 RLAY
# 59 TIG
# 60 GOCO
# 61 NCNO
# 62 NKTX
# 63 PSTX
# 64 QH
# 65 BLCT
# 66 LMND
# 67 DNB
# 68 API
# 69 AKUS
# 70 ACI
# 71 EBON
# 72 FUSN
# 73 PYPD
# 74 BRLIU
# 75 FMTX
# 76 GTH
# 77 PROG
# 78 RPTX
# 79 RPRX
# 80 AZEK
# 81 BNR
# 82 GBIO
# 83 PCVX
# 84 LTRN
# 85 UCL
# 86 HECCU
# 87 VRM
# 88 AMTI
# 89 ARYBU
# 90 DADA
# 91 LEGN
# 92 MCACU
# 93 FOUR
# 94 ZI
# 95 PLRX
# 96 SLQT
# 97 NOVSU
# 98 AYLA
# 99 CLEU
# 100 KC
# 101 CGROU
# 102 LYRA
# 103 ORIC
# 104 KROS
# 105 ZNTL
# 106 WIMI
# 107 IMRA
# 108 DFPHU
# 109 GFL
# 110 PASG
# 111 ZCMD
# 112 ESSCU
# 113 NBACU
# 114 ZGYHU
# 115 GRIL
# 116 RVMD
# 117 HUIZ
# 118 GNRSU
# 119 NREF
# 120 ONEW
# 121 PFHD
# 122 BEAM
# 123 CSPR
# 124 PPD
# 125 SDGR
# 126 ARQT
# 127 REYN
# 128 ANVS
# 129 BDTX
# 130 ANPC
# 131 GHIVU
# 132 SCVXU
# 133 IMAB
# 134 LIZI
# 135 DNK
# 136 VEL
# 137 MKD
# 138 INDO
# 139 MNPR
# 140 CIICU
# 141 HCCOU
# 142 OCFT
# 143 SPT
# 144 BILL
# 145 EH
# 146 LIVKU
# 147 XP
# 148 LMPX
# 149 PINE
# 150 CHPMU
# 151 PTACU
# 152 CAN
# 153 SITM
# 154 AMHCU
# 155 SAQNU
# 156 GRNVU
# 157 ETNB
# 158 KRKR
# 159 CNSP
# 160 MOHO
# 161 SRACU
# 162 TELA
# 163 CNTG
# 164 GRTX
# 165 SI
# 166 MCMJU
# 167 QK
# 168 DUO
# 169 FSRVU
# 170 OYST
# 171 RAPT
# 172 AIH
# 173 CABA
# 174 HAPP
# 175 PHAT
# 176 PGNY
# 177 TFFP
# 178 DAO
# 179 BRP
# 180 LATNU
# 181 BRBR
# 182 HBT
# 183 VIR
# 184 BNTX
# 185 APRE
# 186 FREQ
# 187 VIE
# 188 OPRT
# 189 PTON
# 190 DDOG
# 191 XGN
# 192 PING
# 193 NVST
# 194 IGMS
# 195 APXTU
# 196 NET
# 197 EXPCU
# 198 STSA
# 199 SWTX
# 200 TXG
# 201 SDC
# 202 NPAUU
# 203 JFU
# 204 THBRU
# 205 INMD
# 206 SSPKU
# 207 HKIB
# 208 ORSNU
# 209 DT
# 210 KRUS
# 211 SNDL
# 212 BORR
# 213 BHAT
# 214 VIST
# 215 WSG
# 216 CSTL
# 217 FLLCU
# 218 HCAT
# 219 LVGO
# 220 NOVA
# 221 AFYA
# 222 MDLA
# 223 AMK
# 224 FULC
# 225 GMAB
# 226 MIRM
# 227 ORCC
# 228 PHR
# 229 DOYU
# 230 THCAU
# 231 KRTX
# 232 REAL
# 233 BBIO
# 234 CHNG
# 235 MORF
# 236 CMBM
# 237 LINX
# 238 AKRO
# 239 BCEL
# 240 GO
# 241 PSNL
# 242 PRVL
# 243 WORK
# 244 SMMCU
# 245 STOK
# 246 CHWY
# 247 FVRR
# 248 CRWD
# 249 MWK
# 250 RVLV
# 251 GSX
# 252 BCYC
# 253 IDYA
# 254 RTLR
# 255 GXGXU
# 256 AVTR
# 257 FSLY
# 258 PSTL
# 259 AGBAU
# 260 APLT
# 261 DEACU
# 262 JFIN
# 263 SONM
# 264 UBER
# 265 AXLA
# 266 HHR
# 267 MEC
# 268 MIST
# 269 NXTC
# 270 SPFI
# 271 PSN
# 272 TRVI
# 273 RRBI
# 274 SCPL
# 275 YJ
# 276 BYND
# 277 SY
# 278 TMDX
# 279 ACTTU
# 280 MNRL
# 281 GNLN
# 282 HOOK
# 283 PINS
# 284 ZM
# 285 PLMR
# 286 TPTX
# 287 JMIA
# 288 PD
# 289 TUFN
# 290 GHSI
# 291 NGM
# 292 SILK
# 293 TW
# 294 RUHN
# 295 PBTS
# 296 LYFT
# 297 DTIL
# 298 JFKKU
# 299 LEVI
# 300 INSUU
# 301 TIGR
# 302 TRNEU
# 303 CRSAU
# 304 FUTU
# 305 SWAV
# 306 THCBU
# 307 DPHCU
# 308 KLDO
# 309 SHLLU
# 310 SLGG
# 311 TCRR
# 312 ACAMU
# 313 HOTH
# 314 MITO
# 315 GOSS
# 316 HARP
# 317 ALEC
# 318 MNCLU
# 319 HHHHU
# 320 GMHIU
# 321 NFE
# 322 MTC
# 323 QFIN
# 324 LEGH
# 325 CFFAU
# 326 TME
# 327 SAMAU
# 328 MRNA
# 329 THOR
# 330 MOGU
# 331 MDRR
# 332 TC
# 333 AMCIU
# 334 BWMCU
# 335 FTACU
# 336 BCSF
# 337 WEI
# 338 VAPO
# 339 ETON
# 340 TBLTU
# 341 CNF
# 342 AXNX
# 343 ORTX
# 344 TWST
# 345 GMDA
# 346 PT
# 347 STNE
# 348 YETI
# 349 ALACU
# 350 LOGC
# 351 NIU
# 352 OSMT
# 353 PHAS
# 354 MSC
# 355 SIBN
# 356 PLAN
# 357 DDMXU
# 358 EQ
# 359 ALLO
# 360 LTHM
# 361 ARYAU
# 362 CTACU
# 363 EDTXU
# 364 ESTC
# 365 GH
# 366 KOD
# 367 UPWK
# 368 CTK
# 369 GRTS
# 370 ARVN
# 371 LAIX
# 372 STRO
# 373 UROV
# 374 ARCE
# 375 CBNK
# 376 ETTX
# 377 SVMK
# 378 FTCH
# 379 YMAB
# 380 BSVN
# 381 ELAN
# 382 EB
# 383 XYF
# 384 FVCB
# 385 PRNB
# 386 QTT
# 387 YI
# 388 NIO
# 389 LOACU
# 390 BNGOU
# 391 TZACU
# 392 TKKSU
# 393 ARDS
# 394 MESA
# 395 VCNX
# 396 ARLO
# 397 CWK
# 398 SONO
# 399 TOTAU
# 400 ADIL
# 401 ADILW
# 402 DAVA
# 403 OPRA
# 404 CANG
# 405 FOCS
# 406 LQDA
# 407 PDD
# 408 TENB
# 409 AQST
# 410 BE
# 411 GLACU
# 412 JG
# 413 REPL
# 414 ALLK
# 415 ESTA
# 416 MYFW
# 417 TLRY
# 418 CCB
# 419 CRNX
# 420 RUBY
# 421 ALGRU
# 422 DOMO
# 423 BJ
# 424 ENTX
# 425 ENTXW
# 426 FTSV
# 427 HCCHU
# 428 STIM
# 429 TCDA
# 430 HYRE
# 431 LOVE
# 432 NTGN
# 433 UXIN
# 434 AUTL
# 435 ECOR
# 436 APTX
# 437 AVRO
# 438 EPRT
# 439 IIIV
# 440 KZR
# 441 MGTA
# 442 XERS
# 443 EIDX
# 444 LFACU
# 445 TWLVU
# 446 TBRGU
# 447 AVLR
# 448 NEW
# 449 VRCA
# 450 CHRA
# 451 USX
# 452 MGTX
# 453 TDACU
# 454 ITRM
# 455 CLPS
# 456 GSKY
# 457 KNSA
# 458 SRRK
# 459 EVOP
# 460 PS
# 461 VTIQU
# 462 TMCXU
# 463 HUYA
# 464 EQH
# 465 EVLO
# 466 OBNK
# 467 CBLK
# 468 ROAD
# 469 STXB
# 470 INSP
# 471 UBX
# 472 PRT
# 473 DOCU
# 474 GSHD
# 475 SMAR
# 476 CDAY
# 477 LASR
# 478 LEVL
# 479 PVTL
# 480 EAF
# 481 SURF
# 482 ZUO
# 483 GNPX
# 484 IQ
# 485 BILI
# 486 FIXX
# 487 GHG
# 488 DBX
# 489 STG
# 490 DNJR
# 491 AIHS
# 492 TIBRU
# 493 ZS
# 494 RCUS
# 495 BWB
# 496 OPESU
# 497 BTAI
# 498 DFBHU
# 499 FAMI
# 500 MOTS
# 501 CDLX
# 502 QES
# 503 WHD
# 504 EOLS
# 505 MUDSU
# 506 VCTR
# 507 FTSI
# 508 OSS
# 509 CAAP
# 510 HUD
# 511 SLGL
# 512 MTECU
# 513 ARMO
# 514 AGS
# 515 SLDB
# 516 EYEN
# 517 GTES
# 518 GPAQU
# 519 PAGS
# 520 ILPT
# 521 LBRT
# 522 NEBUU
# 523 ICLK
# 524 LX
# 525 CASA
# 526 NMRK
# 527 DNLI
# 528 LBC
# 529 CURO
# 530 ODT
# 531 QTRX
# 532 LACQU
# 533 RETO
# 534 BRPAU
# 535 BXG
# 536 SAIL
# 537 SCPH
# 538 SFIX
# 539 SBT
# 540 ASNS
# 541 JT
# 542 SEND
# 543 BAND
# 544 APLS
# 545 SOGO
# 546 CBTX
# 547 IFRX
# 548 FEDU
# 549 MCB
# 550 ACMR
# 551 STNLU
# 552 ALNA
# 553 AQUA
# 554 FNKO
# 555 SPRO
# 556 ALTR
# 557 LOMA
# 558 MBIN
# 559 NEXA
# 560 FSCT
# 561 BPMP
# 562 CMSSU
# 563 EYE
# 564 SE
# 565 REDU
# 566 MDB
# 567 QD
# 568 OPTN
# 569 CARG
# 570 KIDS
# 571 SWCH
# 572 BRACU
# 573 NITE
# 574 NCNA
# 575 ROKU
# 576 RYB
# 577 SECO
# 578 OMP
# 579 PETZ
# 580 CELC
# 581 DESP
# 582 KRYS
# 583 ZLAB
# 584 DOTAU
# 585 TRMT
# 586 ATACU
# 587 RNGR
# 588 IAMXU
# 589 VNTR
# 590 CMTA
# 591 NEWA
# 592 RDFN
# 593 INDUU
# 594 WRLSU
# 595 SNNA
# 596 RBB
# 597 PETQ
# 598 CLXT
# 599 KALA
# 600 TRTX
# 601 FSACU
# 602 AKCA
# 603 CODX
# 604 BY
# 605 TNTR
# 606 ALRN
# 607 APRN
# 608 DOVA
# 609 MRSN
# 610 ATXI
# 611 ESQ
# 612 GPMT
# 613 ATUS
# 614 SAFE
# 615 BCACU
# 616 CNACU
# 617 ATNX
# 618 CGBD
# 619 PLYM
# 620 SSTI
# 621 KBLMU
# 622 APPN
# 623 WOW
# 624 SGH
# 625 BEDU
# 626 GTHX
# 627 ASV
# 628 MMDMU
# 629 NESRU
# 630 SOI
# 631 VERI
# 632 FPH
# 633 NDRAU
# 634 GNTY
# 635 KREF
# 636 OVID
# 637 BHVN
# 638 URGN
# 639 CVNA
# 640 CLDR
# 641 EEX
# 642 NCSM
# 643 ZYME
# 644 FND
# 645 WTTR
# 646 CADE
# 647 HCC
# 648 YEXT
# 649 NETS
# 650 AZUL
# 651 VEACU
# 652 OKTA
# 653 SNDR
# 654 ELVT
# 655 KAACU
# 656 AYX
# 657 SRUNU
# 658 MULE
# 659 GOOS
# 660 ARD
# 661 PSDO
# 662 MPACU
# 663 JILL
# 664 BYSI
# 665 SNAP
# 666 HLNE
# 667 DCPH
# 668 FBM
# 669 SACH
# 670 KRP
# 671 METC
# 672 INVH
# 673 LAUR
# 674 JNCE
# 675 ANAB
# 676 FNTEU
# 677 GSHTU
# 678 TRVG
# 679 WRD
# 680 ICHR
# 681 SNES
# 682 POLA
# 683 IIPR
# 684 SND
# 685 GDS
# 686 BL
# 687 QTNA
# 688 GTYHU
# 689 MYOV
# 690 ZTO
# 691 RARX
# 692 FRTA
# 693 IRTC
# 694 CRSP
# 695 TUSK
# 696 AZRE
# 697 XOG
# 698 AHPAU
# 699 AZRX
# 700 CWH
# 701 MRAM
# 702 ADSW
# 703 WAAS
# 704 OBLN
# 705 NTNX
# 706 FLGT
# 707 TRHC
# 708 ACIU
# 709 GSUM
# 710 VVV
# 711 CSTR
# 712 ELF
# 713 NOVN
# 714 TTD
# 715 EVBG
# 716 FBK
# 717 SCACU
# 718 NBLX
# 719 MACQU
# 720 AIRG
# 721 MEDP
# 722 PTGX
# 723 HOME
# 724 FHB
# 725 TLND
# 726 KNSL
# 727 TCMD
# 728 KDMN
# 729 TPIC
# 730 PI
# 731 PTHN
# 732 BOLD
# 733 APFH
# 734 CPAAU
# 735 LN
# 736 MSDI
# 737 MIIIU
# 738 TWLO
# 739 SELB
# 740 ATKR
# 741 SRTSU
# 742 CLSD
# 743 NH
# 744 COTV
# 745 GMS
# 746 RETA
# 747 USFD
# 748 MSBI
# 749 CFCOU
# 750 SUPV
# 751 MRUS
# 752 PZRX
# 753 ACIA
# 754 ONSIU
# 755 SITE
# 756 NTLA
# 757 YIN
# 758 SCWX
# 759 ARA
# 760 MGP
# 761 BATS
# 762 AGLE
# 763 CRVS
# 764 KLREU
# 765 JSYNU
# 766 SNDX
# 767 SRAQU
# 768 AVXS
# 769 BGNE
# 770 EDIT
# 771 YRD
# 772 TEAM
# 773 DLTH
# 774 AXSM
# 775 MIME
# 776 SQ
# 777 MTCH
# 778 INST
# 779 AAAP
# 780 EQBK
# 781 VYGR
# 782 WVE
# 783 MYOK
# 784 IOTS
# 785 DMTX
# 786 RACE
# 787 MPSX
# 788 AFCO
# 789 CERCU
# 790 FDC
# 791 ABTX
# 792 CTMX
# 793 ACRS
# 794 PSTG
# 795 NVCR
# 796 PFGC
# 797 SGRY
# 798 NBRV
# 799 PEN
# 800 RGNX
# 801 PACEU
# 802 CNFR
# 803 ECACU
# 804 HLI
# 805 GBT
# 806 AIMT
# 807 PLNT
# 808 BETR
# 809 RUN
# 810 ZYNE
# 811 GLBL
# 812 AQMS
# 813 EACQU
# 814 GPACU
# 815 WYIGU
# 816 LOB
# 817 NEOS
# 818 BUFF
# 819 MCFT
# 820 OOMA
# 821 RPD
# 822 CHMA
# 823 JP
# 824 OLLI
# 825 NTRA
# 826 CNXC
# 827 CFMS
# 828 TDOC
# 829 UFAB
# 830 ALRM
# 831 APPF
# 832 MCRB
# 833 XTLY
# 834 YECO
# 835 CATB
# 836 GNRT
# 837 GKOS
# 838 LNTH
# 839 MCRN
# 840 TRU
# 841 CAFD
# 842 FOGO
# 843 MB
# 844 FIT
# 845 UNVR
# 846 NVLS
# 847 IVTY
# 848 WING
# 849 AXON
# 850 ELECU
# 851 PUB
# 852 DTEA
# 853 GI
# 854 PTXP
# 855 PGND
# 856 GPIAU
# 857 BKFS
# 858 RKDA
# 859 FTAI
# 860 JAGX
# 861 EQGP
# 862 BOJA
# 863 LIFE
# 864 COLL
# 865 TEGP
# 866 ADAP
# 867 CLCD
# 868 HTGM
# 869 OPGN
# 870 ARWAU
# 871 BSM
# 872 BPMC
# 873 AAPC
# 874 EVA
# 875 VKTX
# 876 APIC
# 877 NSA
# 878 ETSY
# 879 KMPH
# 880 PRTY
# 881 VIRT
# 882 CDTX
# 883 ADRO
# 884 CBYL
# 885 KRNT
# 886 GDDY
# 887 JCAP
# 888 SEDG
# 889 HRMNU
# 890 STDY
# 891 NCOM
# 892 GSBD
# 893 SUM
# 894 MXPT
# 895 BZUN
# 896 CHCT
# 897 ITEK
# 898 BLPH
# 899 EYEG
# 900 AJX
# 901 FNTCU
# 902 INOV
# 903 NVTA
# 904 AVNU
# 905 CPPL
# 906 DEA
# 907 NVET
# 908 AVGR
# 909 HIFR
# 910 ONCE
# 911 TCON
# 912 SHAK
# 913 ENTL
# 914 ASND
# 915 ZSAN
# 916 PN
# 917 ICBK
# 918 JUNO
# 919 BLCM
# 920 ONDK
# 921 RMP
# 922 AVOL
# 923 CNXR
# 924 HDP
# 925 NEWR
# 926 WK
# 927 LC
# 928 MOMO
# 929 NEFF
# 930 SKIS
# 931 CNV
# 932 HABT
# 933 NEOT
# 934 PGRE
# 935 EHIC
# 936 FGEN
# 937 LMRK
# 938 NDRM
# 939 VA
# 940 NAP
# 941 PRAH
# 942 SKYS
# 943 AXTA
# 944 JYNT
# 945 FRPT
# 946 INCR
# 947 TBK
# 948 CHRS
# 949 NVRO
# 950 UPLD
# 951 AM
# 952 XENE
# 953 BOOT
# 954 SHLX
# 955 SIEN
# 956 HDRAU
# 957 ZAYO
# 958 ATRA
# 959 FWP
# 960 GWB
# 961 DPLO
# 962 HUBS
# 963 OMAM
# 964 USDP
# 965 VBTX
# 966 DERM
# 967 FMSA
# 968 YDLE
# 969 AAC
# 970 ATTO
# 971 CALA
# 972 JPEP
# 973 VWR
# 974 W
# 975 CADTU
# 976 VBLT
# 977 VSLR
# 978 CNNX
# 979 TVPT
# 980 CYBR
# 981 MDLY
# 982 SFS
# 983 VTAE
# 984 BABA
# 985 FOMX
# 986 PRQR
# 987 CIVI
# 988 TKAI
# 989 AFMD
# 990 RWLK
# 991 SMACU
# 992 BNK
# 993 GNBC
# 994 ICD
# 995 RYI
# 996 HMLP
# 997 DSKY
# 998 TTOO
# 999 EARS
# 1000 FCB
# 1001 LOXO
# 1002 MBLY
# 1003 VTTI
# 1004 CTLT
# 1005 HQY
# 1006 MCUR
# 1007 MRNS
# 1008 SYF
# 1009 RIGP
# 1010 WLKP
# 1011 SPKE
# 1012 WMS
# 1013 LOCO
# 1014 INNL
# 1015 OCUL
# 1016 OEC
# 1017 IMDZ
# 1018 XENT
# 1019 PFNX
# 1020 TSQ
# 1021 MTBC
# 1022 GLOB
# 1023 SAGE
# 1024 TERP
# 1025 TRUP
# 1026 TUBE
# 1027 CDNA
# 1028 ROKA
# 1029 TRTLU
# 1030 TFSCU
# 1031 IRMD
# 1032 ISTR
# 1033 NERV
# 1034 MIK
# 1035 GGACU
# 1036 GPRO
# 1037 TCPI
# 1038 IMPR
# 1039 MTLS
# 1040 AMPH
# 1041 XNET
# 1042 KITE
# 1043 ARDX
# 1044 CCS
# 1045 FELP
# 1046 PARN
# 1047 SGNL
# 1048 VNOM
# 1049 ZSPH
# 1050 ABY
# 1051 ASPN
# 1052 MRD
# 1053 MOBL
# 1054 TSE
# 2041 CLAY
# 2042 GNET
# 2043 THI
# 2044 NEXT
# 2045 TDG
# 2046 ALXA
# 2047 PAC
# 2048 LQDT
# 2049 MHGC
# 2050 AMCP
# 2051 ACOR
# 2052 MGG
# 2053 XCO
# 2054 NTLS
# 2055 NHWK
# 2056 CROX
# 2057 RSO
# 2058 ETE
# 2059 HS
# 2060 SMOD
# 2061 IOMI
# 2062 VLRX
# 2063 TWPG
# 2064 FNET
# 2065 KOP
# 2066 SGXP
# 2067 TX
# 2068 HEES
# 2069 CLMT
# 2070 ALTU
# 2071 TRFC
# 2072 CMG
# 2073 ARII
# 2074 WNR
# 2075 LINE
# 2076 NCST
# 2077 EMS
# 2078 SPSN
# 2079 RPB
# 2080 SOMX
# 2081 CNCP
# 2082 CPA
# 2083 SCOP
# 2084 TRAK
# 2085 WTHN
# 2086 BAS
# 2087 CYNO
# 2088 VOCS
# 2089 DPM
# 2090 ACTS
# 2091 TRX
# 2092 UDRL
# 2093 BKD
# 2094 AMSF
# 2095 DOVR
# 2096 SPWR
# 2097 ICE
# 2098 VIMC
# 2099 CCO
# 2100 BWP
# 2101 IRBT
# 2102 CBEY
# 2103 MELA
# 2104 ABPI
# 2105 NXTM
# 2106 NCIT
# 2107 PTEK
# 2108 DHT
# 2109 TAL
# 2110 ACLI
# 2111 GASS
# 2112 SNBI
# 2113 VPRT
# 2114 GHDX
# 2115 TLEO
# 2116 CBOU
# 2117 GLP
# 2118 WBMD
# 2119 TRXI
# 2120 SNSS
# 2121 NPTE
# 2122 GCA
# 2123 IKAN
# 2124 WPZ
# 2125 ROC
# 2126 BRNC
# 2127 CF
# 2128 HPY
# 2129 FSGI
# 2130 CMED
# 2131 COLY
# 2132 ROLL
# 2133 KFI
# 2134 RUTH
# 2135 SSW
# 2136 ATRC
# 2137 HOKU
# 2138 BIDU
# 2139 DRC
# 2140 ESCH
# 2141 WRSP
# 2142 AATI
# 2143 UNCA
# 2144 RUTX
# 2145 MWIV
# 2146 PCAP
# 2147 GGXY
# 2148 SWSI
# 2149 ALJ
# 2150 ITC
# 2151 CNSL
# 2152 HITT
# 2153 MFB
# 2154 ARXT
# 2155 DMND
# 2156 QMAR
# 2157 FMCN
# 2158 MPW
# 2159 SIMO
# 2160 VLCM
# 2161 WAL
# 2162 HEM
# 2163 NSR
# 2164 KFN
# 2165 KNXA
# 2166 LINC
# 2167 EGLE
# 2168 BLDR
# 2169 ALLI
# 2170 NRGP
# 2171 EVVV
# 2172 MEND
# 2173 LHCG
# 2174 XNPT
# 2175 DRH
# 2176 TLP
# 2177 CTRN
# 2178 XRM
# 2179 BDE
# 2180 CNTF
# 2181 ZUMZ
# 2182 LAZ
# 2183 TGP
# 2184 MORN
# 2185 PAY
# 2186 ACW
# 2187 NAHC
# 2188 JOR
# 2189 DXCM
# 2190 RAIL
# 2191 DSX
# 2192 BOFI
# 2193 SHMR
# 2194 ISE
# 2195 ASPV
# 2196 DLB
# 2197 ANR
# 2198 HUN
# 2199 UACL
# 2200 SVR
# 2201 PBH
# 2202 GRVY
# 2203 FRP
# 2204 DRYS
# 2205 ICGN
# 2206 DLLR
# 2207 NATL
# 2208 WTI
# 2209 OXPS
# 2210 EDR
# 2211 GFIG
# 2212 CE
# 2213 VIAC
# 2214 WRES
# 2215 MDH
# 2216 SFC
# 2217 HLF
# 2218 IBI
# 2219 OTT
# 2220 OLED
# 2221 AEA
# 2222 KMA
# 2223 CSCD
# 2224 WOLF
# 2225 LVS
# 2226 NCTY
# 2227 CONR
# 2228 CHCI
# 2229 BXC
# 2230 KNL
# 2231 BBG
# 2232 ADZA
# 2233 SMA
# 2234 NINE
# 2235 UAPH
# 2236 MPWR
# 2237 SUAI
# 2238 IWA
# 2239 ORA
# 2240 NLC
# 2241 ZIPR
# 2242 CPNO
# 2243 ATB
# 2244 MKTX
# 2245 AIC
# 2246 MTL
# 2247 DLR
# 2248 FOXH
# 2249 GCT
# 2250 CLMS
# 2251 LONG
# 2252 DWA
# 2253 BBW
# 2254 NRF
# 2255 SHO
# 2256 TWGP
# 2257 VNUS
# 2258 BDAY
# 2259 CTRX
# 2260 JRJC
# 2261 HURN
# 2262 TPGI
# 2263 ILSE
# 2264 TXRH
# 2265 THRX
# 2266 PSPT
# 2267 EHP
# 2268 PRS
# 2269 NSTC
# 2270 CALL
# 2271 CPL
# 2272 JMDT
# 2273 JOBS
# 2274 COGT
# 2275 EEEE
# 2276 BECN
# 2277 VLLY
# 2278 STON
# 2279 ECST
# 2280 GOOG
# 2281 CNS
# 2282 EXR
# 2283 ACC
# 2284 AX
# 2285 STXS
# 2286 EUBK
# 2287 KRG
# 2288 WLK
# 2289 ELOS
# 2290 NVT
# 2291 BMR
# 2292 RNOW
# 2293 NRPH
# 2294 CVGI
# 2295 MHL
# 2296 ENS
# 2297 VLTR
# 2298 MNKD
# 2299 AUXL
# 2300 BUCY
# 2301 IDIX
# 2302 BLKB
# 2303 NURO
# 2304 MSSR
# 2305 CFSI
# 2306 LPL
# 2307 SRVY
# 2308 PFWD
# 2309 HMB
# 2310 DPZ
# 2311 HEP
# 2312 WCG
# 2313 LTM
# 2314 DWRI
# 2315 MOTV
# 2316 MFLX
# 2317 CAB
# 2318 NTR
# 2319 GOL
# 2320 XRTX
# 2321 WCAA
# 2322 CRM
# 2323 CLRK
# 2324 JTX
# 2325 MNTA
# 2326 SNMX
# 2327 BBBB
# 2328 LDIS
# 2329 MBRX
# 2330 PDSN
# 2331 CBG
# 2332 INHX
# 2333 GSL
# 2334 ALNY
# 2335 ACAD
# 2336 ANGO
# 2337 RJET
# 2338 GNW
# 2339 NILE
# 2340 NUVA
# 2341 SNDA
# 2342 GHL
# 2343 INTX
# 2344 CYTK
# 2345 BTRX
# 2346 AGO
# 2347 SIRF
# 2348 CORT
# 2349 ABR
# 2350 MEMY
# 2351 SNTS
# 2352 CUTR
# 2353 MCHX
# 2354 HOS
# 2355 ANDS
# 2356 UCTT
# 2357 SBNY
# 2358 LSE
# 2359 TRCA
# 2360 TNS
# 2361 TOMO
# 2362 KCI
# 2363 CHRK
# 2364 DVAX
# 2365 ARC
# 2366 ATHR
# 2367 ALSM
# 2368 AACC
# 2369 AIZ
# 2370 RNVS
# 2371 THE
# 2372 TRW
# 2373 TBBK
# 2374 EYET
# 2375 PRPX
# 2376 KSP
# 2377 KNTA
# 2378 KNOL
# 2379 TPX
# 2380 PRVD
# 2381 ORBZ
# 2382 UTI
# 2383 CMP
# 2384 CENF
# 2385 LFC
# 2386 ISG
# 2387 NPTT
# 2388 NNI
# 2389 CVP
# 2390 AHL
# 2391 AEL
# 2392 NXST
# 2393 SNX
# 2394 CONN
# 2395 BWLD
# 2396 WLL
# 2397 CALD
# 2398 TSRA
# 2399 MRLN
# 2400 QLTY
# 2401 NTMD
# 2402 PHRM
# 2403 FMD
# 2404 MYOG
# 2405 FPO
# 2406 CRI
# 2407 DNET
# 2408 REDE
# 2409 JRN
# 2410 NFP
# 2411 AHT
# 2412 TCBI
# 2413 GOOD
# 2414 CSE
# 2415 NTGR
# 2416 IASG
# 2417 IPAS
# 2418 IVII
# 2419 DTSI
# 2420 MOH
# 2421 AXS
# 2422 FORM
# 2423 ENH
# 2424 IPCC
# 2425 CCBI
# 2426 STX
# 2427 CME
# 2428 COSI
# 2429 SAFT
# 2430 CHA
# 2431 SINT
# 2432 PRAA
# 2433 MMLP
# 2434 PTP
# 2435 WYNN
# 2436 DKS
# 2437 TAYC
# 2438 NRP
# 2439 EEQ
# 2440 MRH
# 2441 NCT
# 2442 WRS
# 2443 LF
# 2444 PPX
# 2445 RRGB
# 2446 HETC
# 2447 KIRK
# 2448 CIT
# 2449 MTCT
# 2450 IRGI
# 2451 HEW
# 2452 BGFV
# 2453 PCAF
# 2454 PACR
# 2455 PLUM
# 2456 OSTK
# 2457 SRX
# 2458 ATRS
# 2459 NFLX
# 2460 MWE
# 2461 CPSI
# 2462 VRNT
# 2463 ARO
# 2464 RGC
# 2465 QUIN
# 2466 TVL
# 2467 PCO
# 2468 DOVP
# 2469 XJT
# 2470 JBLU
# 2471 ABG
# 2472 TNP
# 2473 PYPL
# 2474 GME
# 2475 WBD
# 2476 MANT
# 2477 SXL
# 2478 ZGEN
# 2479 SYNA
# 2480 BAXS
# 2481 APPX
# 2482 PRU
# 2483 NSDA
# 2484 NSCN
# 2485 LWSN
# 2486 ACH
# 2487 MCGC
# 2488 WOOF
# 2489 LAVA
# 2490 BFUN
# 2491 ABCO
# 2492 AHS
# 2493 LGVN
# 2494 ODSY
# 2495 PVR
# 2496 CCRN
# 2497 PFG
# 2498 THER
# 2499 GIVN
# 2500 MYK
# 2501 OMCL
# 2502 BG
# 2503 HPLA
# 2504 PDFS
# 2505 MDTH
# 2506 ACN
# 2507 WMGI
# 2508 MOSY
# 2509 PNX
# 2510 REVU
# 2511 STO
# 2512 ORH
# 2513 FTI
# 2514 GMR
# 2515 WSH
# 2516 ADS
# 2517 ULAB
# 2518 SWRG
# 2519 BTU
# 2520 GEG
# 2521 TELM
# 2522 KMR
# 2523 AGR
# 2524 SGEN
# 2525 CEO
# 2526 RSTN
# 2527 OIS
# 2528 EXAS
# 2529 ALGN
# 2530 PEET
# 2531 GNVC
# 2532 GRMN
# 2533 SP
# 2534 HBIO
# 2535 RIGL
# 2536 AFOP
# 2537 ARRY
# 2538 DNCR
# 2539 ORN
# 2540 ADLR
# 2541 SYT
# 2542 CATZ
# 2543 AEGN
# 2544 LMNE
# 2545 IFCN
# 2546 TMTA
# 2547 OCPI
# 2548 EPL
# 2549 UTIW
# 2550 HYGS
# 2551 MCLS
# 2552 WRC
# 2553 SNP
# 2554 MON
# 2555 XXIA
# 2556 ENWV
# 2557 SYNP
# 2558 POZN
# 2559 WW
# 2560 AGCX
# 2561 KOSN
# 2562 ASCX
# 2563 COH
# 2564 NSK
# 2565 OPLK
# 2566 INMX
# 2567 ARDI
# 2568 STEC
# 2569 ELAS
# 2570 DCNT
# 2571 GB
# 2572 ASR
# 2573 DRRX
# 2574 VAST
# 2575 COSN
# 2576 INRG
# 2577 TTMI
# 2578 OMNY
# 2579 ZNGN
# 2580 VRYA
# 2581 COD
# 2582 OIIM
# 2583 ISTA
# 2584 VVVV
# 2585 ITXI
# 2586 PIII
# 2587 WJCI
# 2588 OTWO
# 2589 PEOP
# 2590 SYNQ
# 2591 DYAX
# 2592 AMMD
# 2593 CGEN
# 2594 EQIX
# 2595 RTIX
# 2596 VINA
# 2597 LSBC
# 2598 TVIA
# 2599 RPTR
# 2600 PHST
# 2601 MDCO
# 2602 MNDO
# 2603 ACPW
# 2604 TSYS
# 2605 EXEE
# 2606 ISSC
# 2607 LTRX
# 2608 DDDP
# 2609 TUNE
# 2610 CRNT
# 2611 IAWK
# 2612 RSTA
# 2613 ISPH
# 2614 RSNT
# 2615 SGSF
# 2616 GNSC
# 2617 OPNT
# 2618 CPKI
# 2619 EVC
# 2620 VIRL
# 2621 CVGP
# 2622 TRPH
# 2623 SPWX
# 2624 KERX
# 2625 CAMT
# 2626 VLCT
# 2627 ARNA
# 2628 CORV
# 2629 ILMN
# 2630 LXNT
# 2631 WEBX
# 2632 MSPR
# 2633 AMEV
# 2634 RITA
# 2635 ILND
# 2636 CRIO
# 2637 SMTX
# 2638 VASC
# 2639 AGNT
# 2640 SPRT
# 2641 OVTI
# 2642 IMNY
# 2643 TNSI
# 2644 SOHU
# 2645 ACLS
# 2646 ENTG
# 2647 TKC
# 2648 NTES
# 2649 MBT
# 2650 EXFO
# 2651 PRSE
# 2652 CARE
# 2653 CPST
# 2654 VRGE
# 2655 CKCM
# 2656 MRVL
# 2657 STLW
# 2658 CRL
# 2659 ACCL
# 2660 CKSW
# 2661 CHU
# 2662 CPHD
# 2663 HAND
# 2664 DNDN
# 2665 OSCA
# 2666 AUGT
# 2667 REDF
# 2668 ISRG
# 2669 CYH
# 2670 UPCS
# 2671 CWLD
# 2672 ONIS
# 2673 NRG
# 2674 SMDI
# 2675 SONS
# 2676 CTLM
# 2677 ICST
# 2678 CSAV
# 2679 PXLW
# 2680 PRTH
# 2681 NGTC
# 2682 IBEM
# 2683 NUFO
# 2684 SQSW
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-cc463eb1253a> in <module>
#     191     index += 1
#     192
# --> 193 print(len(ERROR_List))
#
# NameError: name 'ERROR_List' is not defined

# %%
# Print length of Key Error List
len(KEY_ERROR_List)
# Out:
# 0
