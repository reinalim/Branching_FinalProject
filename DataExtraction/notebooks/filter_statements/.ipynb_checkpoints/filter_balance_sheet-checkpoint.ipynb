# %% [markdown]
# ##### To filter the balance sheet of each stock for the record closest to the IPO date.

# %%
import pandas as pd
import datetime
from datetime import timedelta

# %%
d_parser = lambda x: pd.datetime.strptime(x,'%Y-%m-%d')
IPO_df = pd.read_csv('../../raw_dataset/IPO_SCOOP_Listing.csv', parse_dates = ['Trade Date'], date_parser = d_parser)
IPO_df
# Out:
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   """Entry point for launching an IPython kernel.
#      Trade Date                         Issuer  Symbol  \
# 0    2020-09-11         Broadstone Acquisition   BSN.U
# 1    2020-09-11                    Ribbit LEAP  LEAP.U
# 2    2020-09-11  Tortoise Acquisition Corp. II  SNPR.U
# 3    2020-09-11           TWC Tech Holdings II   TWCTU
# 4    2020-09-10              NavSight Holdings   NSH.U
# ...         ...                            ...     ...
# 3465 2000-05-18                     US Unwired    UNWR
# 3466 2000-05-18                       Nogatech    NGTC
# 3467 2000-05-18             iBEAM Broadcasting    IBEM
# 3468 2000-05-18                      New Focus    NUFO
# 3469 2000-05-12               Sequoia Software    SQSW
#
#                  Lead/Joint-Lead Managers  Offer Price  Opening Price  \
# 0                               Citigroup         10.0           9.84
# 1                                JPMorgan         10.0          11.20
# 2                 Barclays/ Goldman Sachs         10.0          10.35
# 3     Citigroup/ Deutsche Bank Securities         10.0          10.08
# 4                           Credit Suisse         10.0          10.00
# ...                                   ...          ...            ...
# 3465          Donaldson Lufkin & Jenrette         11.0          11.03
# 3466                    W.R. Hambrecht+Co         12.0          11.88
# 3467           Morgan Stanley Dean Witter         10.0          11.50
# 3468           Credit Suisse First Boston         20.0          40.00
# 3469                      Lehman Brothers          8.0          10.25
#
#       1st Day Close  1st Day % Px Chng   $ Change Opening  $ Change Close  \
# 0              9.60               -0.04             -0.16           -0.40
# 1             11.55                0.16              1.20            1.55
# 2             10.51                0.05              0.35            0.51
# 3             10.07                0.01              0.08            0.07
# 4             10.00                0.00              0.00            0.00
# ...             ...                 ...               ...             ...
# 3465          11.06                0.01              0.03            0.06
# 3466           9.41               -0.22             -0.13           -2.59
# 3467          14.00                0.40              1.50            4.00
# 3468          51.00                1.55             20.00           31.00
# 3469          10.06                0.26              2.25            2.06
#
#      Star Ratings Performed
# 0               1       NaN
# 1               1    Missed
# 2               1       NaN
# 3               1       NaN
# 4               1       NaN
# ...           ...       ...
# 3465            1       NaN
# 3466            1       NaN
# 3467            2       NaN
# 3468            3       NaN
# 3469            2       NaN
#
# [3470 rows x 12 columns]

# %%
IPO_df.dtypes
# Out:
# Trade Date                  datetime64[ns]
# Issuer                              object
# Symbol                              object
# Lead/Joint-Lead Managers            object
# Offer Price                        float64
# Opening Price                      float64
# 1st Day Close                      float64
# 1st Day % Px Chng                  float64
# $ Change Opening                   float64
# $ Change Close                     float64
# Star Ratings                        object
# Performed                           object
# dtype: object

# %%
IPO_list = IPO_df['Symbol'].tolist()
IPO_list
# Out:
# ['BSN.U',
#  'LEAP.U',
#  'SNPR.U',
#  'TWCTU',
#  'NSH.U',
#  'PIAI.U',
#  'SVACU',
#  'CRHCU',
#  'ITACU',
#  'BCTG',
#  'CNLFU',
#  'INAQU',
#  'CAPAU',
#  'TWND.U',
#  'PRFX',
#  'AUVI',
#  'HCDI',
#  'BTAQU',
#  'CFIIU',
#  'XPEV',
#  'FTOCU',
#  'CLA.U',
#  'FST.U',
#  'BFT.U',
#  'FIII.U',
#  'HZAC.U',
#  'KYMR',
#  'NNOX',
#  'HRMY',
#  'IBNX',
#  'NGA.U',
#  'AONE.U',
#  'STPK.U',
#  'RBAC.U',
#  'CVAC',
#  'DYM.U',
#  'DGNR.U',
#  'LCAPU',
#  'FSDC',
#  'BEKE',
#  'NTST',
#  'FAII.U',
#  'KBNT/KBnth',
#  'ARYA',
#  'CMPI',
#  'FRLN',
#  'IBEX',
#  'VMACU',
#  'GRSVU',
#  'KSMTU',
#  'AFIB',
#  'OSH',
#  'RKT',
#  'BIGC',
#  'RXT',
#  'GOAC.U',
#  'BOWXU',
#  'HOLUU',
#  'HSAQ',
#  'YAC,U',
#  'GOED',
#  'NHICU',
#  'ETACU',
#  'FTHM',
#  'PRPB.U',
#  'VITL',
#  'ALVR',
#  'CCIV.U',
#  'LI',
#  'VERX',
#  'ACEVU',
#  'ANNX',
#  'ACND.U',
#  'GRCYU',
#  'INZY',
#  'ITOS',
#  'NRIX',
#  'ERESU',
#  'MEG',
#  'EDTK',
#  'JAMF',
#  'PTH.U',
#  'PSACU',
#  'ALXO',
#  'BLI',
#  'DFHTU',
#  'PAND',
#  'HPX.U',
#  'RLAY',
#  'TIG',
#  'DEH.U',
#  'GOCO',
#  'MLCU',
#  'NCNO',
#  'PTK.U',
#  'NKTX',
#  'PSTX',
#  'QH',
#  'BLCT',
#  'TXAC',
#  'CPSR.U',
#  'LMND',
#  'DNB',
#  'PANA.U',
#  'GSAH.U',
#  'API',
#  'AKUS',
#  'ACI',
#  'EBON',
#  'FUSE.U',
#  'FUSN',
#  'KCAC.U',
#  'PYPD',
#  'BRLIU',
#  'FMTX',
#  'GTH',
#  'PROG',
#  'RPTX',
#  'TRE.U',
#  'RPRX',
#  'AZEK',
#  'BNR',
#  'GBIO',
#  'PCVX',
#  'LTRN',
#  'UCL',
#  'HECCU',
#  'VRM',
#  'AMTI',
#  'ARYBU',
#  'DADA',
#  'LEGN',
#  'MCACU',
#  'FOUR',
#  'ZI',
#  'PLRX',
#  'WPF.U',
#  'NRAI',
#  'LGVW.U',
#  'SLQT',
#  'BMRG.U',
#  'ADCI',
#  'NOVSU',
#  'GIK.U',
#  'JWS.U',
#  'AYLA',
#  'CLEU',
#  'KC',
#  'LOAK.U',
#  'SOAC.U',
#  'ROCHU',
#  'CGROU',
#  'LYRA',
#  'FVAC.U',
#  'IPOB.U',
#  'PCPL.U',
#  'CHAQ.U',
#  'ORIC',
#  'IPOC.U',
#  'KROS',
#  'ZNTL',
#  'WIMI',
#  'IMRA',
#  'DFPHU',
#  'FEAC.U',
#  'LSACU',
#  'GFL',
#  'PASG',
#  'ZCMD',
#  'DMYT.U',
#  'ESSCU',
#  'CCXX.U',
#  'NBACU',
#  'ZGYHU',
#  'GRIL',
#  'RVMD',
#  'HUIZ',
#  'CCAC.U',
#  'GNRSU',
#  'NREF',
#  'ONEW',
#  'PFHD',
#  'BEAM',
#  'CSPR',
#  'PPD',
#  'SDGR',
#  'IPV.U',
#  'OWEM',
#  'ARQT',
#  'REYN',
#  'ANVS',
#  'BDTX',
#  'ANPC',
#  'GHIVU',
#  'SCVXU',
#  'IMAB',
#  'LIZI',
#  'DNK',
#  'VEL',
#  'MKD',
#  'INDO',
#  'MNPR',
#  'CIICU',
#  'HCCOU',
#  'OCFT',
#  'SPT',
#  'BILL',
#  'EH',
#  'LIVKU',
#  'XP',
#  'LMPX',
#  'ALUS.U',
#  'PINE',
#  'CHPMU',
#  'PTACU',
#  'CAN',
#  'SITM',
#  'AMHCU',
#  'SAQNU',
#  'GRNVU',
#  'YAYO',
#  'ETNB',
#  'KRKR',
#  'CNSP',
#  'MOHO',
#  'JIH.U',
#  'SRACU',
#  'TELA',
#  'CNTG',
#  'GRTX',
#  'DFNSU',
#  'SI',
#  'MCMJU',
#  'QK',
#  'DUO',
#  'FSRVU',
#  'SFTW.U',
#  'OYST',
#  'RAPT',
#  'AIH',
#  'CABA',
#  'HAPP',
#  'PHAT',
#  'PGNY',
#  'TFFP',
#  'DAO',
#  'BRP',
#  'GLEO.U',
#  'LATNU',
#  'BRBR',
#  'HBT',
#  'VIR',
#  'BNTX',
#  'APRE',
#  'FREQ',
#  'VIE',
#  'OPRT',
#  'PTON',
#  'DDOG',
#  'XGN',
#  'PING',
#  'NVST',
#  'IGMS',
#  'APXTU',
#  'NET',
#  'EXPCU',
#  'STSA',
#  'SWTX',
#  'TXG',
#  'SDC',
#  'NPAUU',
#  'JFU',
#  'THBRU',
#  'INMD',
#  'SSPKU',
#  'HKIB',
#  'ORSNU',
#  'DT',
#  'KRUS',
#  'SNDL',
#  'NFINU',
#  'BORR',
#  'BHAT',
#  'SBE.U',
#  'VIST',
#  'WSG',
#  'CSTL',
#  'FLLCU',
#  'HCAT',
#  'LVGO',
#  'NOVA',
#  'AFYA',
#  'MDLA',
#  'AMK',
#  'CPAA.U',
#  'FULC',
#  'GMAB',
#  'MIRM',
#  'OAC.U',
#  'ORCC',
#  'PHR',
#  'DOYU',
#  'PIC.U',
#  'SCPE.U',
#  'THCAU',
#  'KRTX',
#  'REAL',
#  'CCX.U',
#  'BBIO',
#  'CHNG',
#  'MORF',
#  'CMBM',
#  'LINX',
#  'AKRO',
#  'BCEL',
#  'GO',
#  'PSNL',
#  'PRVL',
#  'WORK',
#  'SMMCU',
#  'STOK',
#  'CHWY',
#  'FVRR',
#  'CRWD',
#  'MWK',
#  'RVLV',
#  'GIX.U',
#  'GSX',
#  'BCYC',
#  'IDYA',
#  'RTLR',
#  'GXGXU',
#  'AVTR',
#  'FSLY',
#  'LK',
#  'PSTL',
#  'AGBAU',
#  'APLT',
#  'DEACU',
#  'HSACU',
#  'JFIN',
#  'SONM',
#  'UBER',
#  'AXLA',
#  'HHR',
#  'MEC',
#  'MIST',
#  'NXTC',
#  'SPFI',
#  'PSN',
#  'TRVI',
#  'RRBI',
#  'SCPL',
#  'YJ',
#  'BYND',
#  'SY',
#  'TMDX',
#  'ACTTU',
#  'MNRL',
#  'GNLN',
#  'HOOK',
#  'PINS',
#  'ZM',
#  'PLMR',
#  'TPTX',
#  'JMIA',
#  'PD',
#  'TUFN',
#  'BRPM.U',
#  'GHSI',
#  'NGM',
#  'RPLA.U',
#  'SILK',
#  'TW',
#  'RUHN',
#  'PBTS',
#  'LYFT',
#  'DTIL',
#  'JFKKU',
#  'LEVI',
#  'INSUU',
#  'TIGR',
#  'TRNEU',
#  'CRSAU',
#  'FUTU',
#  'SWAV',
#  'THCBU',
#  'DPHCU',
#  'KLDO',
#  'SHLLU',
#  'SLGG',
#  'TCRR',
#  'ACAMU',
#  'HOTH',
#  'MITO',
#  'AVDR',
#  'IMAC/IMACW',
#  'GOSS',
#  'HARP',
#  'RMG.U',
#  'ALEC',
#  'MNCLU',
#  'HHHHU',
#  'GMHIU',
#  'NFE',
#  'PVT.U',
#  'NRGX',
#  'MTC',
#  'QFIN',
#  'CHACU',
#  'LEGH',
#  'CFFAU',
#  'TME',
#  'SAMAU',
#  'MRNA',
#  'THOR',
#  'MOGU',
#  'MDRR',
#  'TC',
#  'AMCIU',
#  'BWMCU',
#  'FTACU',
#  'BCSF',
#  'WEI',
#  'VAPO',
#  'ETON',
#  'TBLTU',
#  'CNF',
#  'AXNX',
#  'ORTX',
#  'TWST',
#  'GMDA',
#  'PT',
#  'STNE',
#  'YETI',
#  'ALACU',
#  'LOGC',
#  'NIU',
#  'OSMT',
#  'PHAS',
#  'MSC',
#  'SIBN',
#  'GRAF.U',
#  'PLAN',
#  'DDMXU',
#  'EQ',
#  'ALLO',
#  'LTHM',
#  'ARYAU',
#  'CTACU',
#  'CCH.U',
#  'EDTXU',
#  'ESTC',
#  'GH',
#  'KOD',
#  'UPWK',
#  'CTK',
#  'GRTS',
#  'ARVN',
#  'LAIX',
#  'REMED',
#  'STRO',
#  'UROV',
#  'ARCE',
#  'CBNK',
#  'ETTX',
#  'SVMK',
#  'FTCH',
#  'YMAB',
#  'BSVN',
#  'ELAN',
#  'EB',
#  'XYF',
#  'FVCB',
#  'PRNB',
#  'QTT',
#  'YI',
#  'NIO',
#  'CCC.U',
#  'LOACU',
#  'MFACU',
#  'BNGOU',
#  'TZACU',
#  'TKKSU',
#  'ARDS',
#  'MESA',
#  'SPAQ.U',
#  'VCNX',
#  'ARLO',
#  'CWK',
#  'SONO',
#  'TOTAU',
#  'ADIL',
#  'ADILW',
#  'DAVA',
#  'OPRA',
#  'CANG',
#  'FOCS',
#  'LQDA',
#  'PDD',
#  'TENB',
#  'AQST',
#  'BE',
#  'GLACU',
#  'JG',
#  'REPL',
#  'ALLK',
#  'ESTA',
#  'MYFW',
#  'TLRY',
#  'CCB',
#  'CRNX',
#  'RUBY',
#  'ALGRU',
#  'DOMO',
#  'BJ',
#  'ENTX',
#  'ENTXW',
#  'FTSV',
#  'HCCHU',
#  'STIM',
#  'NFC.U',
#  'TCDA',
#  'HYRE',
#  'LOVE',
#  'NTGN',
#  'UXIN',
#  'AUTL',
#  'ECOR',
#  'APTX',
#  'AVRO',
#  'EPRT',
#  'IIIV',
#  'KZR',
#  'MGTA',
#  'XERS',
#  'EIDX',
#  'LFACU',
#  'TWLVU',
#  'TBRGU',
#  'AVLR',
#  'NEW',
#  'VRCA',
#  'CHRA',
#  'USX',
#  'FPAC.U',
#  'MGTX',
#  'TDACU',
#  'ITRM',
#  'CLPS',
#  'GSKY',
#  'KNSA',
#  'SRRK',
#  'EVOP',
#  'PS',
#  'VTIQU',
#  'TMCXU',
#  'HUYA',
#  'EQH',
#  'EVLO',
#  'OBNK',
#  'CBLK',
#  'ROAD',
#  'STXB',
#  'INSP',
#  'UBX',
#  'PRT',
#  'DOCU',
#  'GSHD',
#  'SMAR',
#  'CDAY',
#  'LASR',
#  'LEVL',
#  'PVTL',
#  'EAF',
#  'SURF',
#  'ZUO',
#  'GNPX',
#  'IQ',
#  'UMRX',
#  'BILI',
#  'FIXX',
#  'GHG',
#  'DBX',
#  'STG',
#  'DNJR',
#  'AIHS',
#  'TIBRU',
#  'ZS',
#  'RCUS',
#  'BWB',
#  'OPESU',
#  'BTAI',
#  'LTN.U',
#  'DFBHU',
#  'FAMI',
#  'MOTS',
#  'LHC.U',
#  'CDLX',
#  'QES',
#  'WHD',
#  'EOLS',
#  'HMI',
#  'MUDSU',
#  'VCTR',
#  'FTSI',
#  'OSS',
#  'CAAP',
#  'HUD',
#  'SLGL',
#  'MTECU',
#  'ARMO',
#  'AGS',
#  'SLDB',
#  'EYEN',
#  'GTES',
#  'GPAQU',
#  'MNLO',
#  'PAGS',
#  'ILPT',
#  'LBRT',
#  'NEBUU',
#  'ICLK',
#  'LX',
#  'CASA',
#  'NMRK',
#  'DNLI',
#  'GIG.U',
#  'LBC',
#  'CURO',
#  'ODT',
#  'QTRX',
#  'LACQU',
#  'RWGE.U',
#  'RETO',
#  'BRPAU',
#  'BXG',
#  'LGCU',
#  'SAIL',
#  'SCPH',
#  'SFIX',
#  'SBT',
#  'ASNS',
#  'JT',
#  'SEND',
#  'BAND',
#  'PPDF',
#  'APLS',
#  'SOGO',
#  'CBTX',
#  'IFRX',
#  'FEDU',
#  'MCB',
#  'ACMR',
#  'STNLU',
#  'ALNA',
#  'AQUA',
#  'FNKO',
#  'SPRO',
#  'ALTR',
#  'LOMA',
#  'MBIN',
#  'NEXA',
#  'FSCT',
#  'BPMP',
#  'CMSSU',
#  'EYE',
#  'SE',
#  'REDU',
#  'MDB',
#  'MOSC.U',
#  'QD',
#  'OPTN',
#  'CARG',
#  'KIDS',
#  'HAIR',
#  'SWCH',
#  'BRACU',
#  'RYTH',
#  'PGQ',
#  'NITE',
#  'NCNA',
#  'ROKU',
#  'RYB',
#  'SECO',
#  'OMP',
#  'PETZ',
#  'BSTI',
#  'CELC',
#  'DESP',
#  'KRYS',
#  'ZLAB',
#  'DOTAU',
#  'IPOA.U',
#  'TRMT',
#  'ATACU',
#  'CIC.U',
#  'RNGR',
#  'YOGA',
#  'IAMXU',
#  'VNTR',
#  'CMTA',
#  'NEWA',
#  'RDFN',
#  'INDUU',
#  'WRLSU',
#  'SNNA',
#  'RBB',
#  'PETQ',
#  'CLXT',
#  'KALA',
#  'TRTX',
#  'FSACU',
#  'AKCA',
#  'CODX',
#  'BY',
#  'TNTR',
#  'ALRN',
#  'APRN',
#  'DOVA',
#  'MRSN',
#  'TPGH.U',
#  'ATXI',
#  'ESQ',
#  'GPMT',
#  'HCAC.U',
#  'ATUS',
#  'SAFE',
#  'SBGX',
#  'BCACU',
#  'CNACU',
#  'ATNX',
#  'CGBD',
#  'PLYM',
#  'SSTI',
#  'KBLMU',
#  'APPN',
#  'WOW',
#  'SGH',
#  'BEDU',
#  'GTHX',
#  'ASV',
#  'GDI',
#  'MMDMU',
#  'NESRU',
#  'SOI',
#  'VERI',
#  'FPH',
#  'NDRAU',
#  'GNTY',
#  'KREF',
#  'OVID',
#  'TPGEU',
#  'BHVN',
#  'URGN',
#  'CVNA',
#  'XRF',
#  'CLDR',
#  'EEX',
#  'NCSM',
#  'ZYME',
#  'FND',
#  'WTTR',
#  'CADE',
#  'TOCA',
#  'HCC',
#  'YEXT',
#  'NETS',
#  'AZUL',
#  'VEACU',
#  'OKTA',
#  'SNDR',
#  'ELVT',
#  'MESM',
#  'KAACU',
#  'AYX',
#  'SRUNU',
#  'MULE',
#  'GOOS',
#  'ARD',
#  'PSDO',
#  'MPACU',
#  'JILL',
#  'BYSI',
#  'SNAP',
#  'HLNE',
#  'DCPH',
#  'FBM',
#  'SACH',
#  'KRP',
#  'METC',
#  'INVH',
#  'LAUR',
#  'JNCE',
#  'ANAB',
#  'FNTEU',
#  'FRAC',
#  'GSHTU',
#  'TRVG',
#  'WRD',
#  'ICHR',
#  'SNES',
#  'POLA',
#  'IIPR',
#  'SND',
#  'GDS',
#  'BL',
#  'QTNA',
#  'GTYHU',
#  'MYOV',
#  'ZTO',
#  'RARX',
#  'FRTA',
#  'IRTC',
#  'CRSP',
#  'TUSK',
#  'AZRE',
#  'XOG',
#  'AHPAU',
#  'AZRX',
#  'CWH',
#  'MRAM',
#  'ADSW',
#  'WAAS',
#  'OBLN',
#  'NTNX',
#  'FLGT',
#  'TRHC',
#  'ACIU',
#  'GSUM',
#  'VVV',
#  'CSTR',
#  'ELF',
#  'NOVN',
#  'TTD',
#  'EVBG',
#  'FBK',
#  'SCACU',
#  'NBLX',
#  'MACQU',
#  'STRU',
#  'AIRG',
#  'MEDP',
#  'PTGX',
#  'ATMR',
#  'HOME',
#  'FHB',
#  'TLND',
#  'KNSL',
#  'TCMD',
#  'KDMN',
#  'TPIC',
#  'PI',
#  'PTHN',
#  'BOLD',
#  'APFH',
#  'CPAAU',
#  'LN',
#  'MSDI',
#  'MIIIU',
#  'TWLO',
#  'SELB',
#  'ATKR',
#  'SRTSU',
#  'CLSD',
#  'NH',
#  'COTV',
#  'GMS',
#  'RETA',
#  'USFD',
#  'MSBI',
#  'CFCOU',
#  'SUPV',
#  'MRUS',
#  'PZRX',
#  'ACIA',
#  'ONSIU',
#  'SITE',
#  'NTLA',
#  'SBPH',
#  'YIN',
#  'SCWX',
#  'ARA',
#  'MGP',
#  'BATS',
#  'AGLE',
#  'CRVS',
#  'KLREU',
#  'JSYNU',
#  'SNDX',
#  'SRAQU',
#  'AVXS',
#  'PTI',
#  'BGNE',
#  'EDIT',
#  'YRD',
#  'TEAM',
#  'DLTH',
#  'AXSM',
#  'MIME',
#  'SQ',
#  'MTCH',
#  'INST',
#  'XCOM',
#  'AAAP',
#  'EQBK',
#  'VYGR',
#  'WVE',
#  'MYOK',
#  'IOTS',
#  'DMTX',
#  'RACE',
#  'MPSX',
#  'AFCO',
#  'CERCU',
#  'FDC',
#  'PMTS',
#  'ABTX',
#  'CTMX',
#  'ACRS',
#  'PSTG',
#  'NVCR',
#  'EDGE',
#  'MIRN',
#  'PFGC',
#  'SGRY',
#  'NBRV',
#  'PEN',
#  'RGNX',
#  'PACEU',
#  'CNFR',
#  'ECACU',
#  'HLI',
#  'GBT',
#  'AIMT',
#  'PLNT',
#  'BETR',
#  'RUN',
#  'ZYNE',
#  'GLBL',
#  'AQMS',
#  'EACQU',
#  'GPACU',
#  'VTV',
#  'NK',
#  'WYIGU',
#  'LOB',
#  'NEOS',
#  'BUFF',
#  'MCFT',
#  'OOMA',
#  'RPD',
#  'CHMA',
#  'JP',
#  'OLLI',
#  'DNAI',
#  'NTRA',
#  'CNXC',
#  'CFMS',
#  'TDOC',
#  'UFAB',
#  'ALRM',
#  'APPF',
#  'MCRB',
#  'XTLY',
#  'YECO',
#  'CATB',
#  'GNRT',
#  'GKOS',
#  'LNTH',
#  'MCRN',
#  'TRU',
#  'RTTR',
#  'CAFD',
#  'FOGO',
#  'MB',
#  'FIT',
#  'UNVR',
#  'NVLS',
#  'IVTY',
#  'WING',
#  'AXON',
#  'ELECU',
#  'PUB',
#  'DTEA',
#  'GI',
#  'PTXP',
#  'PGND',
#  'GPIAU',
#  'BKFS',
#  'RKDA',
#  'FTAI',
#  'FENX',
#  'JAGX',
#  'EQGP',
#  'BOJA',
#  'LIFE',
#  'COLL',
#  'TEGP',
#  'ADAP',
#  ...]

# %%
# Check length of IPO_list
len(IPO_list)
# Out:
# 3470

# %% [markdown]
# #### Create a loop to perform a filter on each statement for each stock

# %%
# Loop through all symbols in IPO_List

FileNotFoundError_List = []

for symbol in IPO_list:
    
    
    try: 

        symbol_df = IPO_df.loc[IPO_df['Symbol']==symbol]
        symbol_IPO_DATE = symbol_df['Trade Date']

        # Define range lower bound and upper bound
        delta_days = 45

        date_lower_bound = symbol_IPO_DATE - timedelta(days=delta_days)
        date_upper_bound = symbol_IPO_DATE + timedelta(days=delta_days)

        print(f'{symbol}: {symbol_IPO_DATE}')
        print(f'{symbol} lower bound: {date_lower_bound}')
        print(f'{symbol} upper bound: {date_upper_bound}')
        print(f'----------------------------------')

        # Define dynamic path for each symbol
        symbol_balance_sheet_path = f'../../raw_dataset/balance_sheet/{symbol}_balance_sheet.csv'

        # Read in each symbol's income statement
        d_parser = lambda x: pd.datetime.strptime(x,'%Y-%m-%d')
        symbol_balance_sheet_df = pd.read_csv(symbol_balance_sheet_path, parse_dates = ['fiscalDateEnding'], date_parser = d_parser, index_col=None)
        pd.set_option('display.max_columns',85)

        # To filter for dates within the IPO_date +/- 30 days range
        fiscalDate_filt = (symbol_balance_sheet_df['fiscalDateEnding'] >= date_lower_bound.squeeze()) & (symbol_balance_sheet_df['fiscalDateEnding'] <= date_upper_bound.squeeze())
        filtered_symbol_balance_sheet_df = symbol_balance_sheet_df.loc[fiscalDate_filt]

        # Exporting test income statement dataframe to csv file
        save_file_path = f'../../raw_dataset/filtered_balance_sheet/{symbol}_filtered_balance_sheet.csv'
        filtered_symbol_balance_sheet_df.to_csv(save_file_path, index=False)
        
    except FileNotFoundError:
        print(f"FileNotFoundError occured on {symbol}")
        print(f'----------------------------------')
        FileNotFoundError_List.append(symbol)
# Out:
# BSN.U: 0   2020-09-11
# Name: Trade Date, dtype: datetime64[ns]
# BSN.U lower bound: 0   2020-07-28
# Name: Trade Date, dtype: datetime64[ns]
# BSN.U upper bound: 0   2020-10-26
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on BSN.U
# ----------------------------------
# LEAP.U: 1   2020-09-11
# Name: Trade Date, dtype: datetime64[ns]
# LEAP.U lower bound: 1   2020-07-28
# Name: Trade Date, dtype: datetime64[ns]
# LEAP.U upper bound: 1   2020-10-26
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on LEAP.U
# ----------------------------------
# SNPR.U: 2   2020-09-11
# Name: Trade Date, dtype: datetime64[ns]
# SNPR.U lower bound: 2   2020-07-28
# Name: Trade Date, dtype: datetime64[ns]
# SNPR.U upper bound: 2   2020-10-26
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on SNPR.U
# ----------------------------------
# TWCTU: 3   2020-09-11
# Name: Trade Date, dtype: datetime64[ns]
# TWCTU lower bound: 3   2020-07-28
# Name: Trade Date, dtype: datetime64[ns]
# TWCTU upper bound: 3   2020-10-26
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# NSH.U: 4   2020-09-10
# Name: Trade Date, dtype: datetime64[ns]
# NSH.U lower bound: 4   2020-07-27
# Name: Trade Date, dtype: datetime64[ns]
# NSH.U upper bound: 4   2020-10-25
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on NSH.U
# ----------------------------------
# PIAI.U: 5   2020-09-10
# Name: Trade Date, dtype: datetime64[ns]
# PIAI.U lower bound: 5   2020-07-27
# Name: Trade Date, dtype: datetime64[ns]
# PIAI.U upper bound: 5   2020-10-25
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on PIAI.U
# ----------------------------------
# SVACU: 6   2020-09-10
# Name: Trade Date, dtype: datetime64[ns]
# SVACU lower bound: 6   2020-07-27
# Name: Trade Date, dtype: datetime64[ns]
# SVACU upper bound: 6   2020-10-25
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# CRHCU: 7   2020-09-09
# Name: Trade Date, dtype: datetime64[ns]
# CRHCU lower bound: 7   2020-07-26
# Name: Trade Date, dtype: datetime64[ns]
# CRHCU upper bound: 7   2020-10-24
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on CRHCU
# ----------------------------------
# ITACU: 8   2020-09-09
# Name: Trade Date, dtype: datetime64[ns]
# ITACU lower bound: 8   2020-07-26
# Name: Trade Date, dtype: datetime64[ns]
# ITACU upper bound: 8   2020-10-24
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# BCTG: 9   2020-09-03
# Name: Trade Date, dtype: datetime64[ns]
# BCTG lower bound: 9   2020-07-20
# Name: Trade Date, dtype: datetime64[ns]
# BCTG upper bound: 9   2020-10-18
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# CNLFU: 10   2020-09-02
# Name: Trade Date, dtype: datetime64[ns]
# CNLFU lower bound: 10   2020-07-19
# Name: Trade Date, dtype: datetime64[ns]
# CNLFU upper bound: 10   2020-10-17
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on CNLFU
# ----------------------------------
# INAQU: 11   2020-09-02
# Name: Trade Date, dtype: datetime64[ns]
# INAQU lower bound: 11   2020-07-19
# Name: Trade Date, dtype: datetime64[ns]
# INAQU upper bound: 11   2020-10-17
# Name: Trade Date, dtype: datetime64[ns]
# C:\Users\User\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:28: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
# ----------------------------------
# CAPAU: 12   2020-09-02
# Name: Trade Date, dtype: datetime64[ns]
# CAPAU lower bound: 12   2020-07-19
# Name: Trade Date, dtype: datetime64[ns]
# CAPAU upper bound: 12   2020-10-17
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# TWND.U: 13   2020-09-02
# Name: Trade Date, dtype: datetime64[ns]
# TWND.U lower bound: 13   2020-07-19
# Name: Trade Date, dtype: datetime64[ns]
# TWND.U upper bound: 13   2020-10-17
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on TWND.U
# ----------------------------------
# PRFX: 14   2020-09-01
# Name: Trade Date, dtype: datetime64[ns]
# PRFX lower bound: 14   2020-07-18
# Name: Trade Date, dtype: datetime64[ns]
# PRFX upper bound: 14   2020-10-16
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# AUVI: 15   2020-08-31
# Name: Trade Date, dtype: datetime64[ns]
# AUVI lower bound: 15   2020-07-17
# Name: Trade Date, dtype: datetime64[ns]
# AUVI upper bound: 15   2020-10-15
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# HCDI: 16   2020-08-28
# Name: Trade Date, dtype: datetime64[ns]
# HCDI lower bound: 16   2020-07-14
# Name: Trade Date, dtype: datetime64[ns]
# HCDI upper bound: 16   2020-10-12
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# BTAQU: 17   2020-08-27
# Name: Trade Date, dtype: datetime64[ns]
# BTAQU lower bound: 17   2020-07-13
# Name: Trade Date, dtype: datetime64[ns]
# BTAQU upper bound: 17   2020-10-11
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# CFIIU: 18   2020-08-27
# Name: Trade Date, dtype: datetime64[ns]
# CFIIU lower bound: 18   2020-07-13
# Name: Trade Date, dtype: datetime64[ns]
# CFIIU upper bound: 18   2020-10-11
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# XPEV: 19   2020-08-27
# Name: Trade Date, dtype: datetime64[ns]
# XPEV lower bound: 19   2020-07-13
# Name: Trade Date, dtype: datetime64[ns]
# XPEV upper bound: 19   2020-10-11
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FTOCU: 20   2020-08-26
# Name: Trade Date, dtype: datetime64[ns]
# FTOCU lower bound: 20   2020-07-12
# Name: Trade Date, dtype: datetime64[ns]
# FTOCU upper bound: 20   2020-10-10
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# CLA.U: 21   2020-08-21
# Name: Trade Date, dtype: datetime64[ns]
# CLA.U lower bound: 21   2020-07-07
# Name: Trade Date, dtype: datetime64[ns]
# CLA.U upper bound: 21   2020-10-05
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on CLA.U
# ----------------------------------
# FST.U: 22   2020-08-21
# Name: Trade Date, dtype: datetime64[ns]
# FST.U lower bound: 22   2020-07-07
# Name: Trade Date, dtype: datetime64[ns]
# FST.U upper bound: 22   2020-10-05
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on FST.U
# ----------------------------------
# BFT.U: 23   2020-08-21
# Name: Trade Date, dtype: datetime64[ns]
# BFT.U lower bound: 23   2020-07-07
# Name: Trade Date, dtype: datetime64[ns]
# BFT.U upper bound: 23   2020-10-05
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on BFT.U
# ----------------------------------
# FIII.U: 24   2020-08-21
# Name: Trade Date, dtype: datetime64[ns]
# FIII.U lower bound: 24   2020-07-07
# Name: Trade Date, dtype: datetime64[ns]
# FIII.U upper bound: 24   2020-10-05
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on FIII.U
# ----------------------------------
# HZAC.U: 25   2020-08-21
# Name: Trade Date, dtype: datetime64[ns]
# HZAC.U lower bound: 25   2020-07-07
# Name: Trade Date, dtype: datetime64[ns]
# HZAC.U upper bound: 25   2020-10-05
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on HZAC.U
# ----------------------------------
# KYMR: 26   2020-08-21
# Name: Trade Date, dtype: datetime64[ns]
# KYMR lower bound: 26   2020-07-07
# Name: Trade Date, dtype: datetime64[ns]
# KYMR upper bound: 26   2020-10-05
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# NNOX: 27   2020-08-21
# Name: Trade Date, dtype: datetime64[ns]
# NNOX lower bound: 27   2020-07-07
# Name: Trade Date, dtype: datetime64[ns]
# NNOX upper bound: 27   2020-10-05
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# HRMY: 28   2020-08-19
# Name: Trade Date, dtype: datetime64[ns]
# HRMY lower bound: 28   2020-07-05
# Name: Trade Date, dtype: datetime64[ns]
# HRMY upper bound: 28   2020-10-03
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# IBNX: 29   2020-08-19
# Name: Trade Date, dtype: datetime64[ns]
# IBNX lower bound: 29   2020-07-05
# Name: Trade Date, dtype: datetime64[ns]
# IBNX upper bound: 29   2020-10-03
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on IBNX
# ----------------------------------
# NGA.U: 30   2020-08-18
# Name: Trade Date, dtype: datetime64[ns]
# NGA.U lower bound: 30   2020-07-04
# Name: Trade Date, dtype: datetime64[ns]
# NGA.U upper bound: 30   2020-10-02
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on NGA.U
# ----------------------------------
# AONE.U: 31   2020-08-18
# Name: Trade Date, dtype: datetime64[ns]
# AONE.U lower bound: 31   2020-07-04
# Name: Trade Date, dtype: datetime64[ns]
# AONE.U upper bound: 31   2020-10-02
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on AONE.U
# ----------------------------------
# STPK.U: 32   2020-08-18
# Name: Trade Date, dtype: datetime64[ns]
# STPK.U lower bound: 32   2020-07-04
# Name: Trade Date, dtype: datetime64[ns]
# STPK.U upper bound: 32   2020-10-02
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on STPK.U
# ----------------------------------
# RBAC.U: 33   2020-08-14
# Name: Trade Date, dtype: datetime64[ns]
# RBAC.U lower bound: 33   2020-06-30
# Name: Trade Date, dtype: datetime64[ns]
# RBAC.U upper bound: 33   2020-09-28
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on RBAC.U
# ----------------------------------
# CVAC: 34   2020-08-14
# Name: Trade Date, dtype: datetime64[ns]
# CVAC lower bound: 34   2020-06-30
# Name: Trade Date, dtype: datetime64[ns]
# CVAC upper bound: 34   2020-09-28
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# DYM.U: 35   2020-08-14
# Name: Trade Date, dtype: datetime64[ns]
# DYM.U lower bound: 35   2020-06-30
# Name: Trade Date, dtype: datetime64[ns]
# DYM.U upper bound: 35   2020-09-28
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on DYM.U
# ----------------------------------
# DGNR.U: 36   2020-08-14
# Name: Trade Date, dtype: datetime64[ns]
# DGNR.U lower bound: 36   2020-06-30
# Name: Trade Date, dtype: datetime64[ns]
# DGNR.U upper bound: 36   2020-09-28
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on DGNR.U
# ----------------------------------
# LCAPU: 37   2020-08-14
# Name: Trade Date, dtype: datetime64[ns]
# LCAPU lower bound: 37   2020-06-30
# Name: Trade Date, dtype: datetime64[ns]
# LCAPU upper bound: 37   2020-09-28
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FSDC: 38   2020-08-13
# Name: Trade Date, dtype: datetime64[ns]
# FSDC lower bound: 38   2020-06-29
# Name: Trade Date, dtype: datetime64[ns]
# FSDC upper bound: 38   2020-09-27
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on FSDC
# ----------------------------------
# BEKE: 39   2020-08-13
# Name: Trade Date, dtype: datetime64[ns]
# BEKE lower bound: 39   2020-06-29
# Name: Trade Date, dtype: datetime64[ns]
# BEKE upper bound: 39   2020-09-27
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# NTST: 40   2020-08-13
# Name: Trade Date, dtype: datetime64[ns]
# NTST lower bound: 40   2020-06-29
# Name: Trade Date, dtype: datetime64[ns]
# NTST upper bound: 40   2020-09-27
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FAII.U: 41   2020-08-12
# Name: Trade Date, dtype: datetime64[ns]
# FAII.U lower bound: 41   2020-06-28
# Name: Trade Date, dtype: datetime64[ns]
# FAII.U upper bound: 41   2020-09-26
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on FAII.U
# ----------------------------------
# KBNT/KBnth: 42   2020-08-12
# Name: Trade Date, dtype: datetime64[ns]
# KBNT/KBnth lower bound: 42   2020-06-28
# Name: Trade Date, dtype: datetime64[ns]
# KBNT/KBnth upper bound: 42   2020-09-26
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on KBNT/KBnth
# ----------------------------------
# ARYA: 43   2020-08-07
# Name: Trade Date, dtype: datetime64[ns]
# ARYA lower bound: 43   2020-06-23
# Name: Trade Date, dtype: datetime64[ns]
# ARYA upper bound: 43   2020-09-21
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# CMPI: 44   2020-08-07
# Name: Trade Date, dtype: datetime64[ns]
# CMPI lower bound: 44   2020-06-23
# Name: Trade Date, dtype: datetime64[ns]
# CMPI upper bound: 44   2020-09-21
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FRLN: 45   2020-08-07
# Name: Trade Date, dtype: datetime64[ns]
# FRLN lower bound: 45   2020-06-23
# Name: Trade Date, dtype: datetime64[ns]
# FRLN upper bound: 45   2020-09-21
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# IBEX: 46   2020-08-07
# Name: Trade Date, dtype: datetime64[ns]
# IBEX lower bound: 46   2020-06-23
# Name: Trade Date, dtype: datetime64[ns]
# IBEX upper bound: 46   2020-09-21
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# VMACU: 47   2020-08-07
# Name: Trade Date, dtype: datetime64[ns]
# VMACU lower bound: 47   2020-06-23
# Name: Trade Date, dtype: datetime64[ns]
# VMACU upper bound: 47   2020-09-21
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# GRSVU: 48   2020-08-06
# Name: Trade Date, dtype: datetime64[ns]
# GRSVU lower bound: 48   2020-06-22
# Name: Trade Date, dtype: datetime64[ns]
# GRSVU upper bound: 48   2020-09-20
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# KSMTU: 49   2020-08-06
# Name: Trade Date, dtype: datetime64[ns]
# KSMTU lower bound: 49   2020-06-22
# Name: Trade Date, dtype: datetime64[ns]
# KSMTU upper bound: 49   2020-09-20
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# AFIB: 50   2020-08-06
# Name: Trade Date, dtype: datetime64[ns]
# AFIB lower bound: 50   2020-06-22
# Name: Trade Date, dtype: datetime64[ns]
# AFIB upper bound: 50   2020-09-20
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# OSH: 51   2020-08-06
# Name: Trade Date, dtype: datetime64[ns]
# OSH lower bound: 51   2020-06-22
# Name: Trade Date, dtype: datetime64[ns]
# OSH upper bound: 51   2020-09-20
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# RKT: 52   2020-08-06
# Name: Trade Date, dtype: datetime64[ns]
# RKT lower bound: 52   2020-06-22
# Name: Trade Date, dtype: datetime64[ns]
# RKT upper bound: 52   2020-09-20
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# BIGC: 53   2020-08-05
# Name: Trade Date, dtype: datetime64[ns]
# BIGC lower bound: 53   2020-06-21
# Name: Trade Date, dtype: datetime64[ns]
# BIGC upper bound: 53   2020-09-19
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# RXT: 54   2020-08-05
# Name: Trade Date, dtype: datetime64[ns]
# RXT lower bound: 54   2020-06-21
# Name: Trade Date, dtype: datetime64[ns]
# RXT upper bound: 54   2020-09-19
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# GOAC.U: 55   2020-08-05
# Name: Trade Date, dtype: datetime64[ns]
# GOAC.U lower bound: 55   2020-06-21
# Name: Trade Date, dtype: datetime64[ns]
# GOAC.U upper bound: 55   2020-09-19
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on GOAC.U
# ----------------------------------
# BOWXU: 56   2020-08-05
# Name: Trade Date, dtype: datetime64[ns]
# BOWXU lower bound: 56   2020-06-21
# Name: Trade Date, dtype: datetime64[ns]
# BOWXU upper bound: 56   2020-09-19
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# HOLUU: 57   2020-08-05
# Name: Trade Date, dtype: datetime64[ns]
# HOLUU lower bound: 57   2020-06-21
# Name: Trade Date, dtype: datetime64[ns]
# HOLUU upper bound: 57   2020-09-19
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# HSAQ: 58   2020-08-04
# Name: Trade Date, dtype: datetime64[ns]
# HSAQ lower bound: 58   2020-06-20
# Name: Trade Date, dtype: datetime64[ns]
# HSAQ upper bound: 58   2020-09-18
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# YAC,U: 59   2020-08-04
# Name: Trade Date, dtype: datetime64[ns]
# YAC,U lower bound: 59   2020-06-20
# Name: Trade Date, dtype: datetime64[ns]
# YAC,U upper bound: 59   2020-09-18
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on YAC,U
# ----------------------------------
# GOED: 60   2020-07-31
# Name: Trade Date, dtype: datetime64[ns]
# GOED lower bound: 60   2020-06-16
# Name: Trade Date, dtype: datetime64[ns]
# GOED upper bound: 60   2020-09-14
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# NHICU: 61   2020-07-31
# Name: Trade Date, dtype: datetime64[ns]
# NHICU lower bound: 61   2020-06-16
# Name: Trade Date, dtype: datetime64[ns]
# NHICU upper bound: 61   2020-09-14
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ETACU: 62   2020-07-31
# Name: Trade Date, dtype: datetime64[ns]
# ETACU lower bound: 62   2020-06-16
# Name: Trade Date, dtype: datetime64[ns]
# ETACU upper bound: 62   2020-09-14
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FTHM: 63   2020-07-31
# Name: Trade Date, dtype: datetime64[ns]
# FTHM lower bound: 63   2020-06-16
# Name: Trade Date, dtype: datetime64[ns]
# FTHM upper bound: 63   2020-09-14
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# PRPB.U: 64   2020-07-31
# Name: Trade Date, dtype: datetime64[ns]
# PRPB.U lower bound: 64   2020-06-16
# Name: Trade Date, dtype: datetime64[ns]
# PRPB.U upper bound: 64   2020-09-14
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on PRPB.U
# ----------------------------------
# VITL: 65   2020-07-31
# Name: Trade Date, dtype: datetime64[ns]
# VITL lower bound: 65   2020-06-16
# Name: Trade Date, dtype: datetime64[ns]
# VITL upper bound: 65   2020-09-14
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ALVR: 66   2020-07-30
# Name: Trade Date, dtype: datetime64[ns]
# ALVR lower bound: 66   2020-06-15
# Name: Trade Date, dtype: datetime64[ns]
# ALVR upper bound: 66   2020-09-13
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# CCIV.U: 67   2020-07-30
# Name: Trade Date, dtype: datetime64[ns]
# CCIV.U lower bound: 67   2020-06-15
# Name: Trade Date, dtype: datetime64[ns]
# CCIV.U upper bound: 67   2020-09-13
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on CCIV.U
# ----------------------------------
# LI: 68   2020-07-30
# Name: Trade Date, dtype: datetime64[ns]
# LI lower bound: 68   2020-06-15
# Name: Trade Date, dtype: datetime64[ns]
# LI upper bound: 68   2020-09-13
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# VERX: 69   2020-07-29
# Name: Trade Date, dtype: datetime64[ns]
# VERX lower bound: 69   2020-06-14
# Name: Trade Date, dtype: datetime64[ns]
# VERX upper bound: 69   2020-09-12
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ACEVU: 70   2020-07-28
# Name: Trade Date, dtype: datetime64[ns]
# ACEVU lower bound: 70   2020-06-13
# Name: Trade Date, dtype: datetime64[ns]
# ACEVU upper bound: 70   2020-09-11
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ANNX: 71   2020-07-24
# Name: Trade Date, dtype: datetime64[ns]
# ANNX lower bound: 71   2020-06-09
# Name: Trade Date, dtype: datetime64[ns]
# ANNX upper bound: 71   2020-09-07
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ACND.U: 72   2020-07-24
# Name: Trade Date, dtype: datetime64[ns]
# ACND.U lower bound: 72   2020-06-09
# Name: Trade Date, dtype: datetime64[ns]
# ACND.U upper bound: 72   2020-09-07
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on ACND.U
# ----------------------------------
# GRCYU: 73   2020-07-24
# Name: Trade Date, dtype: datetime64[ns]
# GRCYU lower bound: 73   2020-06-09
# Name: Trade Date, dtype: datetime64[ns]
# GRCYU upper bound: 73   2020-09-07
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# INZY: 74   2020-07-24
# Name: Trade Date, dtype: datetime64[ns]
# INZY lower bound: 74   2020-06-09
# Name: Trade Date, dtype: datetime64[ns]
# INZY upper bound: 74   2020-09-07
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ITOS: 75   2020-07-24
# Name: Trade Date, dtype: datetime64[ns]
# ITOS lower bound: 75   2020-06-09
# Name: Trade Date, dtype: datetime64[ns]
# ITOS upper bound: 75   2020-09-07
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# NRIX: 76   2020-07-24
# Name: Trade Date, dtype: datetime64[ns]
# NRIX lower bound: 76   2020-06-09
# Name: Trade Date, dtype: datetime64[ns]
# NRIX upper bound: 76   2020-09-07
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ERESU: 77   2020-07-23
# Name: Trade Date, dtype: datetime64[ns]
# ERESU lower bound: 77   2020-06-08
# Name: Trade Date, dtype: datetime64[ns]
# ERESU upper bound: 77   2020-09-06
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# MEG: 78   2020-07-23
# Name: Trade Date, dtype: datetime64[ns]
# MEG lower bound: 78   2020-06-08
# Name: Trade Date, dtype: datetime64[ns]
# MEG upper bound: 78   2020-09-06
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# EDTK: 79   2020-07-23
# Name: Trade Date, dtype: datetime64[ns]
# EDTK lower bound: 79   2020-06-08
# Name: Trade Date, dtype: datetime64[ns]
# EDTK upper bound: 79   2020-09-06
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# JAMF: 80   2020-07-22
# Name: Trade Date, dtype: datetime64[ns]
# JAMF lower bound: 80   2020-06-07
# Name: Trade Date, dtype: datetime64[ns]
# JAMF upper bound: 80   2020-09-05
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# PTH.U: 81   2020-07-22
# Name: Trade Date, dtype: datetime64[ns]
# PTH.U lower bound: 81   2020-06-07
# Name: Trade Date, dtype: datetime64[ns]
# PTH.U upper bound: 81   2020-09-05
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on PTH.U
# ----------------------------------
# PSACU: 82   2020-07-22
# Name: Trade Date, dtype: datetime64[ns]
# PSACU lower bound: 82   2020-06-07
# Name: Trade Date, dtype: datetime64[ns]
# PSACU upper bound: 82   2020-09-05
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ALXO: 83   2020-07-17
# Name: Trade Date, dtype: datetime64[ns]
# ALXO lower bound: 83   2020-06-02
# Name: Trade Date, dtype: datetime64[ns]
# ALXO upper bound: 83   2020-08-31
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# BLI: 84   2020-07-17
# Name: Trade Date, dtype: datetime64[ns]
# BLI lower bound: 84   2020-06-02
# Name: Trade Date, dtype: datetime64[ns]
# BLI upper bound: 84   2020-08-31
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# DFHTU: 85   2020-07-17
# Name: Trade Date, dtype: datetime64[ns]
# DFHTU lower bound: 85   2020-06-02
# Name: Trade Date, dtype: datetime64[ns]
# DFHTU upper bound: 85   2020-08-31
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# PAND: 86   2020-07-17
# Name: Trade Date, dtype: datetime64[ns]
# PAND lower bound: 86   2020-06-02
# Name: Trade Date, dtype: datetime64[ns]
# PAND upper bound: 86   2020-08-31
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# HPX.U: 87   2020-07-16
# Name: Trade Date, dtype: datetime64[ns]
# HPX.U lower bound: 87   2020-06-01
# Name: Trade Date, dtype: datetime64[ns]
# HPX.U upper bound: 87   2020-08-30
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on HPX.U
# ----------------------------------
# RLAY: 88   2020-07-16
# Name: Trade Date, dtype: datetime64[ns]
# RLAY lower bound: 88   2020-06-01
# Name: Trade Date, dtype: datetime64[ns]
# RLAY upper bound: 88   2020-08-30
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# TIG: 89   2020-07-16
# Name: Trade Date, dtype: datetime64[ns]
# TIG lower bound: 89   2020-06-01
# Name: Trade Date, dtype: datetime64[ns]
# TIG upper bound: 89   2020-08-30
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# DEH.U: 90   2020-07-15
# Name: Trade Date, dtype: datetime64[ns]
# DEH.U lower bound: 90   2020-05-31
# Name: Trade Date, dtype: datetime64[ns]
# DEH.U upper bound: 90   2020-08-29
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on DEH.U
# ----------------------------------
# GOCO: 91   2020-07-15
# Name: Trade Date, dtype: datetime64[ns]
# GOCO lower bound: 91   2020-05-31
# Name: Trade Date, dtype: datetime64[ns]
# GOCO upper bound: 91   2020-08-29
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# MLCU: 92   2020-07-15
# Name: Trade Date, dtype: datetime64[ns]
# MLCU lower bound: 92   2020-05-31
# Name: Trade Date, dtype: datetime64[ns]
# MLCU upper bound: 92   2020-08-29
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on MLCU
# ----------------------------------
# NCNO: 93   2020-07-14
# Name: Trade Date, dtype: datetime64[ns]
# NCNO lower bound: 93   2020-05-30
# Name: Trade Date, dtype: datetime64[ns]
# NCNO upper bound: 93   2020-08-28
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# PTK.U: 94   2020-07-13
# Name: Trade Date, dtype: datetime64[ns]
# PTK.U lower bound: 94   2020-05-29
# Name: Trade Date, dtype: datetime64[ns]
# PTK.U upper bound: 94   2020-08-27
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on PTK.U
# ----------------------------------
# NKTX: 95   2020-07-10
# Name: Trade Date, dtype: datetime64[ns]
# NKTX lower bound: 95   2020-05-26
# Name: Trade Date, dtype: datetime64[ns]
# NKTX upper bound: 95   2020-08-24
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# PSTX: 96   2020-07-10
# Name: Trade Date, dtype: datetime64[ns]
# PSTX lower bound: 96   2020-05-26
# Name: Trade Date, dtype: datetime64[ns]
# PSTX upper bound: 96   2020-08-24
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# QH: 97   2020-07-10
# Name: Trade Date, dtype: datetime64[ns]
# QH lower bound: 97   2020-05-26
# Name: Trade Date, dtype: datetime64[ns]
# QH upper bound: 97   2020-08-24
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# BLCT: 98   2020-07-08
# Name: Trade Date, dtype: datetime64[ns]
# BLCT lower bound: 98   2020-05-24
# Name: Trade Date, dtype: datetime64[ns]
# BLCT upper bound: 98   2020-08-22
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# TXAC: 99   2020-07-08
# Name: Trade Date, dtype: datetime64[ns]
# TXAC lower bound: 99   2020-05-24
# Name: Trade Date, dtype: datetime64[ns]
# TXAC upper bound: 99   2020-08-22
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on TXAC
# ----------------------------------
# CPSR.U: 100   2020-07-02
# Name: Trade Date, dtype: datetime64[ns]
# CPSR.U lower bound: 100   2020-05-18
# Name: Trade Date, dtype: datetime64[ns]
# CPSR.U upper bound: 100   2020-08-16
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on CPSR.U
# ----------------------------------
# LMND: 101   2020-07-02
# Name: Trade Date, dtype: datetime64[ns]
# LMND lower bound: 101   2020-05-18
# Name: Trade Date, dtype: datetime64[ns]
# LMND upper bound: 101   2020-08-16
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# DNB: 102   2020-07-01
# Name: Trade Date, dtype: datetime64[ns]
# DNB lower bound: 102   2020-05-17
# Name: Trade Date, dtype: datetime64[ns]
# DNB upper bound: 102   2020-08-15
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# PANA.U: 103   2020-07-01
# Name: Trade Date, dtype: datetime64[ns]
# PANA.U lower bound: 103   2020-05-17
# Name: Trade Date, dtype: datetime64[ns]
# PANA.U upper bound: 103   2020-08-15
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on PANA.U
# ----------------------------------
# GSAH.U: 104   2020-06-30
# Name: Trade Date, dtype: datetime64[ns]
# GSAH.U lower bound: 104   2020-05-16
# Name: Trade Date, dtype: datetime64[ns]
# GSAH.U upper bound: 104   2020-08-14
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on GSAH.U
# ----------------------------------
# API: 105   2020-06-26
# Name: Trade Date, dtype: datetime64[ns]
# API lower bound: 105   2020-05-12
# Name: Trade Date, dtype: datetime64[ns]
# API upper bound: 105   2020-08-10
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# AKUS: 106   2020-06-26
# Name: Trade Date, dtype: datetime64[ns]
# AKUS lower bound: 106   2020-05-12
# Name: Trade Date, dtype: datetime64[ns]
# AKUS upper bound: 106   2020-08-10
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ACI: 107   2020-06-26
# Name: Trade Date, dtype: datetime64[ns]
# ACI lower bound: 107   2020-05-12
# Name: Trade Date, dtype: datetime64[ns]
# ACI upper bound: 107   2020-08-10
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# EBON: 108   2020-06-26
# Name: Trade Date, dtype: datetime64[ns]
# EBON lower bound: 108   2020-05-12
# Name: Trade Date, dtype: datetime64[ns]
# EBON upper bound: 108   2020-08-10
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FUSE.U: 109   2020-06-26
# Name: Trade Date, dtype: datetime64[ns]
# FUSE.U lower bound: 109   2020-05-12
# Name: Trade Date, dtype: datetime64[ns]
# FUSE.U upper bound: 109   2020-08-10
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on FUSE.U
# ----------------------------------
# FUSN: 110   2020-06-26
# Name: Trade Date, dtype: datetime64[ns]
# FUSN lower bound: 110   2020-05-12
# Name: Trade Date, dtype: datetime64[ns]
# FUSN upper bound: 110   2020-08-10
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# KCAC.U: 111   2020-06-26
# Name: Trade Date, dtype: datetime64[ns]
# KCAC.U lower bound: 111   2020-05-12
# Name: Trade Date, dtype: datetime64[ns]
# KCAC.U upper bound: 111   2020-08-10
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on KCAC.U
# ----------------------------------
# PYPD: 112   2020-06-26
# Name: Trade Date, dtype: datetime64[ns]
# PYPD lower bound: 112   2020-05-12
# Name: Trade Date, dtype: datetime64[ns]
# PYPD upper bound: 112   2020-08-10
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# BRLIU: 113   2020-06-24
# Name: Trade Date, dtype: datetime64[ns]
# BRLIU lower bound: 113   2020-05-10
# Name: Trade Date, dtype: datetime64[ns]
# BRLIU upper bound: 113   2020-08-08
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FMTX: 114   2020-06-19
# Name: Trade Date, dtype: datetime64[ns]
# FMTX lower bound: 114   2020-05-05
# Name: Trade Date, dtype: datetime64[ns]
# FMTX upper bound: 114   2020-08-03
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# GTH: 115   2020-06-19
# Name: Trade Date, dtype: datetime64[ns]
# GTH lower bound: 115   2020-05-05
# Name: Trade Date, dtype: datetime64[ns]
# GTH upper bound: 115   2020-08-03
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# PROG: 116   2020-06-19
# Name: Trade Date, dtype: datetime64[ns]
# PROG lower bound: 116   2020-05-05
# Name: Trade Date, dtype: datetime64[ns]
# PROG upper bound: 116   2020-08-03
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# RPTX: 117   2020-06-19
# Name: Trade Date, dtype: datetime64[ns]
# RPTX lower bound: 117   2020-05-05
# Name: Trade Date, dtype: datetime64[ns]
# RPTX upper bound: 117   2020-08-03
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# TRE.U: 118   2020-06-17
# Name: Trade Date, dtype: datetime64[ns]
# TRE.U lower bound: 118   2020-05-03
# Name: Trade Date, dtype: datetime64[ns]
# TRE.U upper bound: 118   2020-08-01
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on TRE.U
# ----------------------------------
# RPRX: 119   2020-06-16
# Name: Trade Date, dtype: datetime64[ns]
# RPRX lower bound: 119   2020-05-02
# Name: Trade Date, dtype: datetime64[ns]
# RPRX upper bound: 119   2020-07-31
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# AZEK: 120   2020-06-12
# Name: Trade Date, dtype: datetime64[ns]
# AZEK lower bound: 120   2020-04-28
# Name: Trade Date, dtype: datetime64[ns]
# AZEK upper bound: 120   2020-07-27
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# BNR: 121   2020-06-12
# Name: Trade Date, dtype: datetime64[ns]
# BNR lower bound: 121   2020-04-28
# Name: Trade Date, dtype: datetime64[ns]
# BNR upper bound: 121   2020-07-27
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# GBIO: 122   2020-06-12
# Name: Trade Date, dtype: datetime64[ns]
# GBIO lower bound: 122   2020-04-28
# Name: Trade Date, dtype: datetime64[ns]
# GBIO upper bound: 122   2020-07-27
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# PCVX: 123   2020-06-12
# Name: Trade Date, dtype: datetime64[ns]
# PCVX lower bound: 123   2020-04-28
# Name: Trade Date, dtype: datetime64[ns]
# PCVX upper bound: 123   2020-07-27
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# LTRN: 124   2020-06-11
# Name: Trade Date, dtype: datetime64[ns]
# LTRN lower bound: 124   2020-04-27
# Name: Trade Date, dtype: datetime64[ns]
# LTRN upper bound: 124   2020-07-26
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# UCL: 125   2020-06-10
# Name: Trade Date, dtype: datetime64[ns]
# UCL lower bound: 125   2020-04-26
# Name: Trade Date, dtype: datetime64[ns]
# UCL upper bound: 125   2020-07-25
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# HECCU: 126   2020-06-09
# Name: Trade Date, dtype: datetime64[ns]
# HECCU lower bound: 126   2020-04-25
# Name: Trade Date, dtype: datetime64[ns]
# HECCU upper bound: 126   2020-07-24
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# VRM: 127   2020-06-09
# Name: Trade Date, dtype: datetime64[ns]
# VRM lower bound: 127   2020-04-25
# Name: Trade Date, dtype: datetime64[ns]
# VRM upper bound: 127   2020-07-24
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# AMTI: 128   2020-06-05
# Name: Trade Date, dtype: datetime64[ns]
# AMTI lower bound: 128   2020-04-21
# Name: Trade Date, dtype: datetime64[ns]
# AMTI upper bound: 128   2020-07-20
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ARYBU: 129   2020-06-05
# Name: Trade Date, dtype: datetime64[ns]
# ARYBU lower bound: 129   2020-04-21
# Name: Trade Date, dtype: datetime64[ns]
# ARYBU upper bound: 129   2020-07-20
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# DADA: 130   2020-06-05
# Name: Trade Date, dtype: datetime64[ns]
# DADA lower bound: 130   2020-04-21
# Name: Trade Date, dtype: datetime64[ns]
# DADA upper bound: 130   2020-07-20
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# LEGN: 131   2020-06-05
# Name: Trade Date, dtype: datetime64[ns]
# LEGN lower bound: 131   2020-04-21
# Name: Trade Date, dtype: datetime64[ns]
# LEGN upper bound: 131   2020-07-20
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# MCACU: 132   2020-06-05
# Name: Trade Date, dtype: datetime64[ns]
# MCACU lower bound: 132   2020-04-21
# Name: Trade Date, dtype: datetime64[ns]
# MCACU upper bound: 132   2020-07-20
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FOUR: 133   2020-06-05
# Name: Trade Date, dtype: datetime64[ns]
# FOUR lower bound: 133   2020-04-21
# Name: Trade Date, dtype: datetime64[ns]
# FOUR upper bound: 133   2020-07-20
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ZI: 134   2020-06-04
# Name: Trade Date, dtype: datetime64[ns]
# ZI lower bound: 134   2020-04-20
# Name: Trade Date, dtype: datetime64[ns]
# ZI upper bound: 134   2020-07-19
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# PLRX: 135   2020-06-03
# Name: Trade Date, dtype: datetime64[ns]
# PLRX lower bound: 135   2020-04-19
# Name: Trade Date, dtype: datetime64[ns]
# PLRX upper bound: 135   2020-07-18
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# WPF.U: 136   2020-05-27
# Name: Trade Date, dtype: datetime64[ns]
# WPF.U lower bound: 136   2020-04-12
# Name: Trade Date, dtype: datetime64[ns]
# WPF.U upper bound: 136   2020-07-11
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on WPF.U
# ----------------------------------
# NRAI: 137   2020-05-22
# Name: Trade Date, dtype: datetime64[ns]
# NRAI lower bound: 137   2020-04-07
# Name: Trade Date, dtype: datetime64[ns]
# NRAI upper bound: 137   2020-07-06
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on NRAI
# ----------------------------------
# LGVW.U: 138   2020-05-21
# Name: Trade Date, dtype: datetime64[ns]
# LGVW.U lower bound: 138   2020-04-06
# Name: Trade Date, dtype: datetime64[ns]
# LGVW.U upper bound: 138   2020-07-05
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on LGVW.U
# ----------------------------------
# SLQT: 139   2020-05-21
# Name: Trade Date, dtype: datetime64[ns]
# SLQT lower bound: 139   2020-04-06
# Name: Trade Date, dtype: datetime64[ns]
# SLQT upper bound: 139   2020-07-05
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# BMRG.U: 140   2020-05-20
# Name: Trade Date, dtype: datetime64[ns]
# BMRG.U lower bound: 140   2020-04-05
# Name: Trade Date, dtype: datetime64[ns]
# BMRG.U upper bound: 140   2020-07-04
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on BMRG.U
# ----------------------------------
# ADCI: 141   2020-05-15
# Name: Trade Date, dtype: datetime64[ns]
# ADCI lower bound: 141   2020-03-31
# Name: Trade Date, dtype: datetime64[ns]
# ADCI upper bound: 141   2020-06-29
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on ADCI
# ----------------------------------
# NOVSU: 142   2020-05-15
# Name: Trade Date, dtype: datetime64[ns]
# NOVSU lower bound: 142   2020-03-31
# Name: Trade Date, dtype: datetime64[ns]
# NOVSU upper bound: 142   2020-06-29
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# GIK.U: 143   2020-05-14
# Name: Trade Date, dtype: datetime64[ns]
# GIK.U lower bound: 143   2020-03-30
# Name: Trade Date, dtype: datetime64[ns]
# GIK.U upper bound: 143   2020-06-28
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on GIK.U
# ----------------------------------
# JWS.U: 144   2020-05-14
# Name: Trade Date, dtype: datetime64[ns]
# JWS.U lower bound: 144   2020-03-30
# Name: Trade Date, dtype: datetime64[ns]
# JWS.U upper bound: 144   2020-06-28
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on JWS.U
# ----------------------------------
# AYLA: 145   2020-05-08
# Name: Trade Date, dtype: datetime64[ns]
# AYLA lower bound: 145   2020-03-24
# Name: Trade Date, dtype: datetime64[ns]
# AYLA upper bound: 145   2020-06-22
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# CLEU: 146   2020-05-08
# Name: Trade Date, dtype: datetime64[ns]
# CLEU lower bound: 146   2020-03-24
# Name: Trade Date, dtype: datetime64[ns]
# CLEU upper bound: 146   2020-06-22
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# KC: 147   2020-05-08
# Name: Trade Date, dtype: datetime64[ns]
# KC lower bound: 147   2020-03-24
# Name: Trade Date, dtype: datetime64[ns]
# KC upper bound: 147   2020-06-22
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# LOAK.U: 148   2020-05-06
# Name: Trade Date, dtype: datetime64[ns]
# LOAK.U lower bound: 148   2020-03-22
# Name: Trade Date, dtype: datetime64[ns]
# LOAK.U upper bound: 148   2020-06-20
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on LOAK.U
# ----------------------------------
# SOAC.U: 149   2020-05-06
# Name: Trade Date, dtype: datetime64[ns]
# SOAC.U lower bound: 149   2020-03-22
# Name: Trade Date, dtype: datetime64[ns]
# SOAC.U upper bound: 149   2020-06-20
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on SOAC.U
# ----------------------------------
# ROCHU: 150   2020-05-05
# Name: Trade Date, dtype: datetime64[ns]
# ROCHU lower bound: 150   2020-03-21
# Name: Trade Date, dtype: datetime64[ns]
# ROCHU upper bound: 150   2020-06-19
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on ROCHU
# ----------------------------------
# CGROU: 151   2020-05-01
# Name: Trade Date, dtype: datetime64[ns]
# CGROU lower bound: 151   2020-03-17
# Name: Trade Date, dtype: datetime64[ns]
# CGROU upper bound: 151   2020-06-15
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# LYRA: 152   2020-05-01
# Name: Trade Date, dtype: datetime64[ns]
# LYRA lower bound: 152   2020-03-17
# Name: Trade Date, dtype: datetime64[ns]
# LYRA upper bound: 152   2020-06-15
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FVAC.U: 153   2020-04-30
# Name: Trade Date, dtype: datetime64[ns]
# FVAC.U lower bound: 153   2020-03-16
# Name: Trade Date, dtype: datetime64[ns]
# FVAC.U upper bound: 153   2020-06-14
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on FVAC.U
# ----------------------------------
# IPOB.U: 154   2020-04-28
# Name: Trade Date, dtype: datetime64[ns]
# IPOB.U lower bound: 154   2020-03-14
# Name: Trade Date, dtype: datetime64[ns]
# IPOB.U upper bound: 154   2020-06-12
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on IPOB.U
# ----------------------------------
# PCPL.U: 155   2020-04-24
# Name: Trade Date, dtype: datetime64[ns]
# PCPL.U lower bound: 155   2020-03-10
# Name: Trade Date, dtype: datetime64[ns]
# PCPL.U upper bound: 155   2020-06-08
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on PCPL.U
# ----------------------------------
# CHAQ.U: 156   2020-04-24
# Name: Trade Date, dtype: datetime64[ns]
# CHAQ.U lower bound: 156   2020-03-10
# Name: Trade Date, dtype: datetime64[ns]
# CHAQ.U upper bound: 156   2020-06-08
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on CHAQ.U
# ----------------------------------
# ORIC: 157   2020-04-24
# Name: Trade Date, dtype: datetime64[ns]
# ORIC lower bound: 157   2020-03-10
# Name: Trade Date, dtype: datetime64[ns]
# ORIC upper bound: 157   2020-06-08
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# IPOC.U: 158   2020-04-22
# Name: Trade Date, dtype: datetime64[ns]
# IPOC.U lower bound: 158   2020-03-08
# Name: Trade Date, dtype: datetime64[ns]
# IPOC.U upper bound: 158   2020-06-06
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on IPOC.U
# ----------------------------------
# KROS: 159   2020-04-08
# Name: Trade Date, dtype: datetime64[ns]
# KROS lower bound: 159   2020-02-23
# Name: Trade Date, dtype: datetime64[ns]
# KROS upper bound: 159   2020-05-23
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ZNTL: 160   2020-04-03
# Name: Trade Date, dtype: datetime64[ns]
# ZNTL lower bound: 160   2020-02-18
# Name: Trade Date, dtype: datetime64[ns]
# ZNTL upper bound: 160   2020-05-18
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# WIMI: 161   2020-04-01
# Name: Trade Date, dtype: datetime64[ns]
# WIMI lower bound: 161   2020-02-16
# Name: Trade Date, dtype: datetime64[ns]
# WIMI upper bound: 161   2020-05-16
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# IMRA: 162   2020-03-12
# Name: Trade Date, dtype: datetime64[ns]
# IMRA lower bound: 162   2020-01-27
# Name: Trade Date, dtype: datetime64[ns]
# IMRA upper bound: 162   2020-04-26
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# DFPHU: 163   2020-03-11
# Name: Trade Date, dtype: datetime64[ns]
# DFPHU lower bound: 163   2020-01-26
# Name: Trade Date, dtype: datetime64[ns]
# DFPHU upper bound: 163   2020-04-25
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FEAC.U: 164   2020-03-06
# Name: Trade Date, dtype: datetime64[ns]
# FEAC.U lower bound: 164   2020-01-21
# Name: Trade Date, dtype: datetime64[ns]
# FEAC.U upper bound: 164   2020-04-20
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on FEAC.U
# ----------------------------------
# LSACU: 165   2020-03-06
# Name: Trade Date, dtype: datetime64[ns]
# LSACU lower bound: 165   2020-01-21
# Name: Trade Date, dtype: datetime64[ns]
# LSACU upper bound: 165   2020-04-20
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on LSACU
# ----------------------------------
# GFL: 166   2020-03-03
# Name: Trade Date, dtype: datetime64[ns]
# GFL lower bound: 166   2020-01-18
# Name: Trade Date, dtype: datetime64[ns]
# GFL upper bound: 166   2020-04-17
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# PASG: 167   2020-02-28
# Name: Trade Date, dtype: datetime64[ns]
# PASG lower bound: 167   2020-01-14
# Name: Trade Date, dtype: datetime64[ns]
# PASG upper bound: 167   2020-04-13
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ZCMD: 168   2020-02-24
# Name: Trade Date, dtype: datetime64[ns]
# ZCMD lower bound: 168   2020-01-10
# Name: Trade Date, dtype: datetime64[ns]
# ZCMD upper bound: 168   2020-04-09
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# DMYT.U: 169   2020-02-21
# Name: Trade Date, dtype: datetime64[ns]
# DMYT.U lower bound: 169   2020-01-07
# Name: Trade Date, dtype: datetime64[ns]
# DMYT.U upper bound: 169   2020-04-06
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on DMYT.U
# ----------------------------------
# ESSCU: 170   2020-02-20
# Name: Trade Date, dtype: datetime64[ns]
# ESSCU lower bound: 170   2020-01-06
# Name: Trade Date, dtype: datetime64[ns]
# ESSCU upper bound: 170   2020-04-05
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# CCXX.U: 171   2020-02-14
# Name: Trade Date, dtype: datetime64[ns]
# CCXX.U lower bound: 171   2019-12-31
# Name: Trade Date, dtype: datetime64[ns]
# CCXX.U upper bound: 171   2020-03-30
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on CCXX.U
# ----------------------------------
# NBACU: 172   2020-02-14
# Name: Trade Date, dtype: datetime64[ns]
# NBACU lower bound: 172   2019-12-31
# Name: Trade Date, dtype: datetime64[ns]
# NBACU upper bound: 172   2020-03-30
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ZGYHU: 173   2020-02-13
# Name: Trade Date, dtype: datetime64[ns]
# ZGYHU lower bound: 173   2019-12-30
# Name: Trade Date, dtype: datetime64[ns]
# ZGYHU upper bound: 173   2020-03-29
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# GRIL: 174   2020-02-13
# Name: Trade Date, dtype: datetime64[ns]
# GRIL lower bound: 174   2019-12-30
# Name: Trade Date, dtype: datetime64[ns]
# GRIL upper bound: 174   2020-03-29
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# RVMD: 175   2020-02-13
# Name: Trade Date, dtype: datetime64[ns]
# RVMD lower bound: 175   2019-12-30
# Name: Trade Date, dtype: datetime64[ns]
# RVMD upper bound: 175   2020-03-29
# Name: Trade Date, dtype: datetime64[ns]
# ...
# ----------------------------------
# FileNotFoundError occured on PTIE
# ----------------------------------
# IMNY: 3411   2000-07-13
# Name: Trade Date, dtype: datetime64[ns]
# IMNY lower bound: 3411   2000-05-29
# Name: Trade Date, dtype: datetime64[ns]
# IMNY upper bound: 3411   2000-08-27
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# NENG: 3412   2000-07-13
# Name: Trade Date, dtype: datetime64[ns]
# NENG lower bound: 3412   2000-05-29
# Name: Trade Date, dtype: datetime64[ns]
# NENG upper bound: 3412   2000-08-27
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on NENG
# ----------------------------------
# SRTI: 3413   2000-07-13
# Name: Trade Date, dtype: datetime64[ns]
# SRTI lower bound: 3413   2000-05-29
# Name: Trade Date, dtype: datetime64[ns]
# SRTI upper bound: 3413   2000-08-27
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on SRTI
# ----------------------------------
# TNSI: 3414   2000-07-13
# Name: Trade Date, dtype: datetime64[ns]
# TNSI lower bound: 3414   2000-05-29
# Name: Trade Date, dtype: datetime64[ns]
# TNSI upper bound: 3414   2000-08-27
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# DVIN: 3415   2000-07-12
# Name: Trade Date, dtype: datetime64[ns]
# DVIN lower bound: 3415   2000-05-28
# Name: Trade Date, dtype: datetime64[ns]
# DVIN upper bound: 3415   2000-08-26
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on DVIN
# ----------------------------------
# SOHU: 3416   2000-07-12
# Name: Trade Date, dtype: datetime64[ns]
# SOHU lower bound: 3416   2000-05-28
# Name: Trade Date, dtype: datetime64[ns]
# SOHU upper bound: 3416   2000-08-26
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ASTT: 3417   2000-07-11
# Name: Trade Date, dtype: datetime64[ns]
# ASTT lower bound: 3417   2000-05-27
# Name: Trade Date, dtype: datetime64[ns]
# ASTT upper bound: 3417   2000-08-25
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on ASTT
# ----------------------------------
# ACLS: 3418   2000-07-11
# Name: Trade Date, dtype: datetime64[ns]
# ACLS lower bound: 3418   2000-05-27
# Name: Trade Date, dtype: datetime64[ns]
# ACLS upper bound: 3418   2000-08-25
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ENTG: 3419   2000-07-11
# Name: Trade Date, dtype: datetime64[ns]
# ENTG lower bound: 3419   2000-05-27
# Name: Trade Date, dtype: datetime64[ns]
# ENTG upper bound: 3419   2000-08-25
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# TKC: 3420   2000-07-11
# Name: Trade Date, dtype: datetime64[ns]
# TKC lower bound: 3420   2000-05-27
# Name: Trade Date, dtype: datetime64[ns]
# TKC upper bound: 3420   2000-08-25
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# IVTA: 3421   2000-07-07
# Name: Trade Date, dtype: datetime64[ns]
# IVTA lower bound: 3421   2000-05-23
# Name: Trade Date, dtype: datetime64[ns]
# IVTA upper bound: 3421   2000-08-21
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on IVTA
# ----------------------------------
# NTES: 3422   2000-06-30
# Name: Trade Date, dtype: datetime64[ns]
# NTES lower bound: 3422   2000-05-16
# Name: Trade Date, dtype: datetime64[ns]
# NTES upper bound: 3422   2000-08-14
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# MBT: 3423   2000-06-30
# Name: Trade Date, dtype: datetime64[ns]
# MBT lower bound: 3423   2000-05-16
# Name: Trade Date, dtype: datetime64[ns]
# MBT upper bound: 3423   2000-08-14
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# MOBE: 3424   2000-06-30
# Name: Trade Date, dtype: datetime64[ns]
# MOBE lower bound: 3424   2000-05-16
# Name: Trade Date, dtype: datetime64[ns]
# MOBE upper bound: 3424   2000-08-14
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on MOBE
# ----------------------------------
# EXFO: 3425   2000-06-30
# Name: Trade Date, dtype: datetime64[ns]
# EXFO lower bound: 3425   2000-05-16
# Name: Trade Date, dtype: datetime64[ns]
# EXFO upper bound: 3425   2000-08-14
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# PRSE: 3426   2000-06-30
# Name: Trade Date, dtype: datetime64[ns]
# PRSE lower bound: 3426   2000-05-16
# Name: Trade Date, dtype: datetime64[ns]
# PRSE upper bound: 3426   2000-08-14
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# CARE: 3427   2000-06-29
# Name: Trade Date, dtype: datetime64[ns]
# CARE lower bound: 3427   2000-05-15
# Name: Trade Date, dtype: datetime64[ns]
# CARE upper bound: 3427   2000-08-13
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# CPST: 3428   2000-06-29
# Name: Trade Date, dtype: datetime64[ns]
# CPST lower bound: 3428   2000-05-15
# Name: Trade Date, dtype: datetime64[ns]
# CPST upper bound: 3428   2000-08-13
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# VRGE: 3429   2000-06-29
# Name: Trade Date, dtype: datetime64[ns]
# VRGE lower bound: 3429   2000-05-15
# Name: Trade Date, dtype: datetime64[ns]
# VRGE upper bound: 3429   2000-08-13
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# GENU: 3430   2000-06-28
# Name: Trade Date, dtype: datetime64[ns]
# GENU lower bound: 3430   2000-05-14
# Name: Trade Date, dtype: datetime64[ns]
# GENU upper bound: 3430   2000-08-12
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on GENU
# ----------------------------------
# EFDS: 3431   2000-06-27
# Name: Trade Date, dtype: datetime64[ns]
# EFDS lower bound: 3431   2000-05-13
# Name: Trade Date, dtype: datetime64[ns]
# EFDS upper bound: 3431   2000-08-11
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on EFDS
# ----------------------------------
# CKCM: 3432   2000-06-27
# Name: Trade Date, dtype: datetime64[ns]
# CKCM lower bound: 3432   2000-05-13
# Name: Trade Date, dtype: datetime64[ns]
# CKCM upper bound: 3432   2000-08-11
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# MRVL: 3433   2000-06-27
# Name: Trade Date, dtype: datetime64[ns]
# MRVL lower bound: 3433   2000-05-13
# Name: Trade Date, dtype: datetime64[ns]
# MRVL upper bound: 3433   2000-08-11
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# STLW: 3434   2000-06-27
# Name: Trade Date, dtype: datetime64[ns]
# STLW lower bound: 3434   2000-05-13
# Name: Trade Date, dtype: datetime64[ns]
# STLW upper bound: 3434   2000-08-11
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# CRL: 3435   2000-06-23
# Name: Trade Date, dtype: datetime64[ns]
# CRL lower bound: 3435   2000-05-09
# Name: Trade Date, dtype: datetime64[ns]
# CRL upper bound: 3435   2000-08-07
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ACCL: 3436   2000-06-23
# Name: Trade Date, dtype: datetime64[ns]
# ACCL lower bound: 3436   2000-05-09
# Name: Trade Date, dtype: datetime64[ns]
# ACCL upper bound: 3436   2000-08-07
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# MSV: 3437   2000-06-23
# Name: Trade Date, dtype: datetime64[ns]
# MSV lower bound: 3437   2000-05-09
# Name: Trade Date, dtype: datetime64[ns]
# MSV upper bound: 3437   2000-08-07
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on MSV
# ----------------------------------
# QBAK: 3438   2000-06-23
# Name: Trade Date, dtype: datetime64[ns]
# QBAK lower bound: 3438   2000-05-09
# Name: Trade Date, dtype: datetime64[ns]
# QBAK upper bound: 3438   2000-08-07
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on QBAK
# ----------------------------------
# CKSW: 3439   2000-06-22
# Name: Trade Date, dtype: datetime64[ns]
# CKSW lower bound: 3439   2000-05-08
# Name: Trade Date, dtype: datetime64[ns]
# CKSW upper bound: 3439   2000-08-06
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# CHU: 3440   2000-06-21
# Name: Trade Date, dtype: datetime64[ns]
# CHU lower bound: 3440   2000-05-07
# Name: Trade Date, dtype: datetime64[ns]
# CHU upper bound: 3440   2000-08-05
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# CPHD: 3441   2000-06-21
# Name: Trade Date, dtype: datetime64[ns]
# CPHD lower bound: 3441   2000-05-07
# Name: Trade Date, dtype: datetime64[ns]
# CPHD upper bound: 3441   2000-08-05
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# HAND: 3442   2000-06-21
# Name: Trade Date, dtype: datetime64[ns]
# HAND lower bound: 3442   2000-05-07
# Name: Trade Date, dtype: datetime64[ns]
# HAND upper bound: 3442   2000-08-05
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# SLT: 3443   2000-06-20
# Name: Trade Date, dtype: datetime64[ns]
# SLT lower bound: 3443   2000-05-06
# Name: Trade Date, dtype: datetime64[ns]
# SLT upper bound: 3443   2000-08-04
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on SLT
# ----------------------------------
# DNDN: 3444   2000-06-16
# Name: Trade Date, dtype: datetime64[ns]
# DNDN lower bound: 3444   2000-05-02
# Name: Trade Date, dtype: datetime64[ns]
# DNDN upper bound: 3444   2000-07-31
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# OSCA: 3445   2000-06-15
# Name: Trade Date, dtype: datetime64[ns]
# OSCA lower bound: 3445   2000-05-01
# Name: Trade Date, dtype: datetime64[ns]
# OSCA upper bound: 3445   2000-07-30
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# AUGT: 3446   2000-06-14
# Name: Trade Date, dtype: datetime64[ns]
# AUGT lower bound: 3446   2000-04-30
# Name: Trade Date, dtype: datetime64[ns]
# AUGT upper bound: 3446   2000-07-29
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# REDF: 3447   2000-06-14
# Name: Trade Date, dtype: datetime64[ns]
# REDF lower bound: 3447   2000-04-30
# Name: Trade Date, dtype: datetime64[ns]
# REDF upper bound: 3447   2000-07-29
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ISRG: 3448   2000-06-13
# Name: Trade Date, dtype: datetime64[ns]
# ISRG lower bound: 3448   2000-04-29
# Name: Trade Date, dtype: datetime64[ns]
# ISRG upper bound: 3448   2000-07-28
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# TTA: 3449   2000-06-13
# Name: Trade Date, dtype: datetime64[ns]
# TTA lower bound: 3449   2000-04-29
# Name: Trade Date, dtype: datetime64[ns]
# TTA upper bound: 3449   2000-07-28
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on TTA
# ----------------------------------
# CYH: 3450   2000-06-09
# Name: Trade Date, dtype: datetime64[ns]
# CYH lower bound: 3450   2000-04-25
# Name: Trade Date, dtype: datetime64[ns]
# CYH upper bound: 3450   2000-07-24
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# UPCS: 3451   2000-06-07
# Name: Trade Date, dtype: datetime64[ns]
# UPCS lower bound: 3451   2000-04-23
# Name: Trade Date, dtype: datetime64[ns]
# UPCS upper bound: 3451   2000-07-22
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# EXLT: 3452   2000-06-02
# Name: Trade Date, dtype: datetime64[ns]
# EXLT lower bound: 3452   2000-04-18
# Name: Trade Date, dtype: datetime64[ns]
# EXLT upper bound: 3452   2000-07-17
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on EXLT
# ----------------------------------
# CWLD: 3453   2000-06-01
# Name: Trade Date, dtype: datetime64[ns]
# CWLD lower bound: 3453   2000-04-17
# Name: Trade Date, dtype: datetime64[ns]
# CWLD upper bound: 3453   2000-07-16
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ONIS: 3454   2000-06-01
# Name: Trade Date, dtype: datetime64[ns]
# ONIS lower bound: 3454   2000-04-17
# Name: Trade Date, dtype: datetime64[ns]
# ONIS upper bound: 3454   2000-07-16
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FHRX: 3455   2000-05-31
# Name: Trade Date, dtype: datetime64[ns]
# FHRX lower bound: 3455   2000-04-16
# Name: Trade Date, dtype: datetime64[ns]
# FHRX upper bound: 3455   2000-07-15
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on FHRX
# ----------------------------------
# NRG: 3456   2000-05-31
# Name: Trade Date, dtype: datetime64[ns]
# NRG lower bound: 3456   2000-04-16
# Name: Trade Date, dtype: datetime64[ns]
# NRG upper bound: 3456   2000-07-15
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# SMDI: 3457   2000-05-25
# Name: Trade Date, dtype: datetime64[ns]
# SMDI lower bound: 3457   2000-04-10
# Name: Trade Date, dtype: datetime64[ns]
# SMDI upper bound: 3457   2000-07-09
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# SONS: 3458   2000-05-25
# Name: Trade Date, dtype: datetime64[ns]
# SONS lower bound: 3458   2000-04-10
# Name: Trade Date, dtype: datetime64[ns]
# SONS upper bound: 3458   2000-07-09
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# UCO: 3459   2000-05-24
# Name: Trade Date, dtype: datetime64[ns]
# UCO lower bound: 3459   2000-04-09
# Name: Trade Date, dtype: datetime64[ns]
# UCO upper bound: 3459   2000-07-08
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on UCO
# ----------------------------------
# CTLM: 3460   2000-05-24
# Name: Trade Date, dtype: datetime64[ns]
# CTLM lower bound: 3460   2000-04-09
# Name: Trade Date, dtype: datetime64[ns]
# CTLM upper bound: 3460   2000-07-08
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# ICST: 3461   2000-05-23
# Name: Trade Date, dtype: datetime64[ns]
# ICST lower bound: 3461   2000-04-08
# Name: Trade Date, dtype: datetime64[ns]
# ICST upper bound: 3461   2000-07-07
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# CSAV: 3462   2000-05-19
# Name: Trade Date, dtype: datetime64[ns]
# CSAV lower bound: 3462   2000-04-04
# Name: Trade Date, dtype: datetime64[ns]
# CSAV upper bound: 3462   2000-07-03
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# PXLW: 3463   2000-05-19
# Name: Trade Date, dtype: datetime64[ns]
# PXLW lower bound: 3463   2000-04-04
# Name: Trade Date, dtype: datetime64[ns]
# PXLW upper bound: 3463   2000-07-03
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# PRTH: 3464   2000-05-19
# Name: Trade Date, dtype: datetime64[ns]
# PRTH lower bound: 3464   2000-04-04
# Name: Trade Date, dtype: datetime64[ns]
# PRTH upper bound: 3464   2000-07-03
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# UNWR: 3465   2000-05-18
# Name: Trade Date, dtype: datetime64[ns]
# UNWR lower bound: 3465   2000-04-03
# Name: Trade Date, dtype: datetime64[ns]
# UNWR upper bound: 3465   2000-07-02
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# FileNotFoundError occured on UNWR
# ----------------------------------
# NGTC: 3466   2000-05-18
# Name: Trade Date, dtype: datetime64[ns]
# NGTC lower bound: 3466   2000-04-03
# Name: Trade Date, dtype: datetime64[ns]
# NGTC upper bound: 3466   2000-07-02
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# IBEM: 3467   2000-05-18
# Name: Trade Date, dtype: datetime64[ns]
# IBEM lower bound: 3467   2000-04-03
# Name: Trade Date, dtype: datetime64[ns]
# IBEM upper bound: 3467   2000-07-02
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# NUFO: 3468   2000-05-18
# Name: Trade Date, dtype: datetime64[ns]
# NUFO lower bound: 3468   2000-04-03
# Name: Trade Date, dtype: datetime64[ns]
# NUFO upper bound: 3468   2000-07-02
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------
# SQSW: 3469   2000-05-12
# Name: Trade Date, dtype: datetime64[ns]
# SQSW lower bound: 3469   2000-03-28
# Name: Trade Date, dtype: datetime64[ns]
# SQSW upper bound: 3469   2000-06-26
# Name: Trade Date, dtype: datetime64[ns]
# ----------------------------------

# %%
# Print length of FileNotFoundError List
len(FileNotFoundError_List)
# Out:
# 785

# %% [markdown]
# This is expected.
