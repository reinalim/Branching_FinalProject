# %%
import pandas as pd

# %%
df = pd.read_csv(r'company_overview.csv')

# %%
df
# Out:
#      SYMBOL    ASSET_TYPE                               NAME EXCHANGE  \
# 0     TWCTU  Common Stock          TWC Tech Holdings II Corp   NASDAQ
# 1     SVACU  Common Stock   Starboard Value Acquisition Corp   NASDAQ
# 2     ITACU  Common Stock  Industrial Tech Acquisitions, Inc   NASDAQ
# 3      BCTG  Common Stock              BCTG Acquisition Corp   NASDAQ
# 4     INAQU  Common Stock          INSU Acquisition Corp. II   NASDAQ
# ...     ...           ...                                ...      ...
# 2680   PRTH  Common Stock  Priority Technology Holdings, Inc   NASDAQ
# 2681   NGTC  Common Stock                       Nogatech Inc   NASDAQ
# 2682   IBEM  Common Stock            Ibeam Broadcasting Corp   NASDAQ
# 2683   NUFO  Common Stock                      New Focus Inc   NASDAQ
# 2684   SQSW  Common Stock              Sequoia Software Corp   NASDAQ
#
#      CURRENCY COUNTRY              SECTOR                         INDUSTRY  \
# 0         USD     USA                 NaN                              NaN
# 1         USD     USA  Financial Services                  Shell Companies
# 2         USD     USA  Financial Services                  Shell Companies
# 3         USD     USA  Financial Services                  Shell Companies
# 4         USD     USA  Financial Services                  Shell Companies
# ...       ...     ...                 ...                              ...
# 2680      USD     USA          Technology  Information Technology Services
# 2681      USD     USA               Other                            Other
# 2682      USD     USA               Other                            Other
# 2683      USD     USA               Other                            Other
# 2684      USD     USA               Other                            Other
#
#                                                 ADDRESS
# 0     Four Embarcadero Center, San Francisco, CA, Un...
# 1     777 Third Avenue, New York, NY, United States,...
# 2     5090 Richmond Avenue, Houston, TX, United Stat...
# 3     11682 El Camino Real, San Diego, CA, United St...
# 4     2929 Arch Street, Philadelphia, PA, United Sta...
# ...                                                 ...
# 2680  2001 Westside Parkway, Alpharetta, GA, United ...
# 2681                                               None
# 2682                                               None
# 2683                                               None
# 2684                                               None
#
# [2685 rows x 9 columns]

# %%
from geopandas.tools import geocode

# %%
def custom_geocoder(address):
    dataframe = geocode(address , provider="nominatim" , user_agent = 'my_request')
    point = dataframe.geometry.iloc[0]
    return pd.Series({'Latitude': point.y, 'Longitude': point.x})

# %%
df[['latitude' , 'longitude']]= df.ADDRESS.apply( lambda x: custom_geocoder(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-c7c7da8fbb18> in <module>
# ----> 1 df[['latitude' , 'longitude']]= df.ADDRESS.apply( lambda x: custom_geocoder(x))
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-7-c7c7da8fbb18> in <lambda>(x)
# ----> 1 df[['latitude' , 'longitude']]= df.ADDRESS.apply( lambda x: custom_geocoder(x))
#
# <ipython-input-5-028c6feec6cf> in custom_geocoder(address)
#       1 def custom_geocoder(address):
# ----> 2     dataframe = geocode(address , provider="nominatim" , user_agent = 'my_request')
#       3     point = dataframe.geometry.iloc[0]
#       4     return pd.Series({'Latitude': point.y, 'Longitude': point.x})
#
# ~\anaconda3\envs\PythonData\lib\site-packages\geopandas\tools\geocoding.py in geocode(strings, provider, **kwargs)
#      73         throttle_time = _get_throttle_time(provider)
#      74
# ---> 75     return _query(strings, True, provider, throttle_time, **kwargs)
#      76
#      77
#
# ~\anaconda3\envs\PythonData\lib\site-packages\geopandas\tools\geocoding.py in _query(data, forward, provider, throttle_time, **kwargs)
#     155         time.sleep(throttle_time)
#     156
# --> 157     df = _prepare_geocode_result(results)
#     158     return df
#     159
#
# ~\anaconda3\envs\PythonData\lib\site-packages\geopandas\tools\geocoding.py in _prepare_geocode_result(results)
#     172
#     173     for i, s in iteritems(results):
# --> 174         address, loc = s
#     175
#     176         # loc is lat, lon and we want lon, lat
#
# TypeError: cannot unpack non-iterable NoneType object
